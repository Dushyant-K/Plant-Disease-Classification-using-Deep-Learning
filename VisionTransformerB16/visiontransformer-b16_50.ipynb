# %% [markdown]
# ### Importing all libraries

# %%
import torch, torchvision, torchmetrics
from torchmetrics import ConfusionMatrix
from torch import nn
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import requests
from sklearn.model_selection import train_test_split
from torchmetrics import Accuracy
from torchvision import transforms
from torchvision import models
from torchvision import datasets
from torchvision.transforms import ToTensor
from torch.utils.data import DataLoader
from torchinfo import summary
from timeit import default_timer as timer
from pathlib import Path
from tqdm.auto import tqdm
from torchmetrics import ConfusionMatrix
from mlxtend.plotting import plot_confusion_matrix
import random
from PIL import Image
import os
import torchinfo
from torchvision.datasets import ImageFolder
import albumentations as A
from typing import Dict, List
import seaborn as sns
import torch.optim.lr_scheduler as lr_scheduler
print("All packages imported!")
# Out:
# All packages imported!

# %%
# GPU information
# !nvidia-smi
# Out:
# Sun Apr 21 01:26:21 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.129.03             Driver Version: 535.129.03   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   38C    P8               9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
# |   1  Tesla T4                       Off | 00000000:00:05.0 Off |                    0 |
# | N/A   39C    P8               9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |  No running processes found                                                           |
# +---------------------------------------------------------------------------------------+

# %%
device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')
device
# Out:
# device(type='cuda')

# %% [markdown]
# ### Importing data from our folder

# %%
# Setup path tod data folder
dataset_dir = Path("../input/new-plant-diseases-dataset/New Plant Diseases Dataset(Augmented)/New Plant Diseases Dataset(Augmented)/")

# chek if path exists
if dataset_dir.is_dir():
    print("Dataset directory exists\n")
else:
    print("Dataset directory doesnt exist\n")

file_list = list(dataset_dir.glob("*"))
print("Files in the dataset directory")
for file_path in file_list:
    print(file_path.name)
# Out:
# Dataset directory exists
#
# Files in the dataset directory
# valid
# train

# %% [markdown]
# ### Defining training and testing directories

# %%
train_dir = dataset_dir / "train"
test_dir = dataset_dir / "valid"
train_dir, test_dir
# Out:
# (PosixPath('../input/new-plant-diseases-dataset/New Plant Diseases Dataset(Augmented)/New Plant Diseases Dataset(Augmented)/train'),
#  PosixPath('../input/new-plant-diseases-dataset/New Plant Diseases Dataset(Augmented)/New Plant Diseases Dataset(Augmented)/valid'))

# %%
data ='../input/new-plant-diseases-dataset/'
os.listdir(data)
# Out:
# ['New Plant Diseases Dataset(Augmented)',
#  'new plant diseases dataset(augmented)',
#  'test']

# %% [markdown]
# ### Coverting our train and test directories into datasets

# %%
from albumentations.pytorch import ToTensorV2

# %%
# Custom dataset class with Albumentations transformations
class CustomDataset(torch.utils.data.Dataset):
    def __init__(self, root_dir, transform=None):
        self.root_dir = root_dir
        self.transform = transform
        self.images = []
        self.labels = []
        self.class_names = []  # Store class names
        
        # Iterate through each class folder
        for label, class_name in enumerate(os.listdir(root_dir)):
            class_dir = os.path.join(root_dir, class_name)
            if os.path.isdir(class_dir):
                self.class_names.append(class_name)  # Append class name
                # Iterate through each image in the class folder
                for image_name in os.listdir(class_dir):
                    image_path = os.path.join(class_dir, image_name)
                    self.images.append(image_path)
                    self.labels.append(label)
    
    def __len__(self):
        return len(self.images)
    
    def __getitem__(self, idx):
        image_path = self.images[idx]
        label = self.labels[idx]
        image = Image.open(image_path).convert('RGB')
        
        if self.transform:
            transformed = self.transform(image=np.array(image))
            image = transformed['image']
        
        return image, label, self.class_names[label]

# Define additional transformations
additional_transforms = A.Compose([
    A.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.2, p=0.5),
    A.Blur(blur_limit=3, p=0.2),
    A.ElasticTransform(alpha=120, sigma=120 * 0.05, alpha_affine=120 * 0.03, p=0.2),
    A.GridDistortion(p=0.2),
])

# Define transformations using Albumentations for training data
train_transform = A.Compose([
    A.Resize(width=224, height=224),
    A.HorizontalFlip(p=0.5),
    A.Rotate(limit=30),
    A.RandomBrightnessContrast(p=0.2),
    A.RandomGamma(p=0.2),
    A.GaussNoise(p=0.2),
    additional_transforms,  # Add the new transformations here
    A.Normalize(mean=(0.46738179, 0.46738179, 0.46738179), std=(0.19342914, 0.19342914, 0.19342914)),
    A.pytorch.ToTensorV2(),
])

# Define transformations for validation/test data (no augmentation)
val_transform = A.Compose([
    A.Resize(width=224, height=224),
    A.Normalize(mean=(0.46738179, 0.46738179, 0.46738179), std=(0.19342914, 0.19342914, 0.19342914)),
    A.pytorch.ToTensorV2(),  # Convert the image to PyTorch tensor without augmentation
])

# Create custom datasets
train_data = CustomDataset(root_dir=train_dir, transform=train_transform)
test_data = CustomDataset(root_dir=test_dir, transform=val_transform)

# %%
class_names = train_data.class_names
class_names
# Out:
# ['Tomato___Late_blight',
#  'Tomato___healthy',
#  'Grape___healthy',
#  'Orange___Haunglongbing_(Citrus_greening)',
#  'Soybean___healthy',
#  'Squash___Powdery_mildew',
#  'Potato___healthy',
#  'Corn_(maize)___Northern_Leaf_Blight',
#  'Tomato___Early_blight',
#  'Tomato___Septoria_leaf_spot',
#  'Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot',
#  'Strawberry___Leaf_scorch',
#  'Peach___healthy',
#  'Apple___Apple_scab',
#  'Tomato___Tomato_Yellow_Leaf_Curl_Virus',
#  'Tomato___Bacterial_spot',
#  'Apple___Black_rot',
#  'Blueberry___healthy',
#  'Cherry_(including_sour)___Powdery_mildew',
#  'Peach___Bacterial_spot',
#  'Apple___Cedar_apple_rust',
#  'Tomato___Target_Spot',
#  'Pepper,_bell___healthy',
#  'Grape___Leaf_blight_(Isariopsis_Leaf_Spot)',
#  'Potato___Late_blight',
#  'Tomato___Tomato_mosaic_virus',
#  'Strawberry___healthy',
#  'Apple___healthy',
#  'Grape___Black_rot',
#  'Potato___Early_blight',
#  'Cherry_(including_sour)___healthy',
#  'Corn_(maize)___Common_rust_',
#  'Grape___Esca_(Black_Measles)',
#  'Raspberry___healthy',
#  'Tomato___Leaf_Mold',
#  'Tomato___Spider_mites Two-spotted_spider_mite',
#  'Pepper,_bell___Bacterial_spot',
#  'Corn_(maize)___healthy']

# %%
# Create a dictionary to store class-to-index mapping
class_to_idx = {}

# Assign consecutive indices starting from 0
for idx, class_name in enumerate(class_names):
    class_to_idx[class_name] = idx

# Now you can use the class-to-index mapping
print(class_to_idx)
# Out:
# {'Tomato___Late_blight': 0, 'Tomato___healthy': 1, 'Grape___healthy': 2, 'Orange___Haunglongbing_(Citrus_greening)': 3, 'Soybean___healthy': 4, 'Squash___Powdery_mildew': 5, 'Potato___healthy': 6, 'Corn_(maize)___Northern_Leaf_Blight': 7, 'Tomato___Early_blight': 8, 'Tomato___Septoria_leaf_spot': 9, 'Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot': 10, 'Strawberry___Leaf_scorch': 11, 'Peach___healthy': 12, 'Apple___Apple_scab': 13, 'Tomato___Tomato_Yellow_Leaf_Curl_Virus': 14, 'Tomato___Bacterial_spot': 15, 'Apple___Black_rot': 16, 'Blueberry___healthy': 17, 'Cherry_(including_sour)___Powdery_mildew': 18, 'Peach___Bacterial_spot': 19, 'Apple___Cedar_apple_rust': 20, 'Tomato___Target_Spot': 21, 'Pepper,_bell___healthy': 22, 'Grape___Leaf_blight_(Isariopsis_Leaf_Spot)': 23, 'Potato___Late_blight': 24, 'Tomato___Tomato_mosaic_virus': 25, 'Strawberry___healthy': 26, 'Apple___healthy': 27, 'Grape___Black_rot': 28, 'Potato___Early_blight': 29, 'Cherry_(including_sour)___healthy': 30, 'Corn_(maize)___Common_rust_': 31, 'Grape___Esca_(Black_Measles)': 32, 'Raspberry___healthy': 33, 'Tomato___Leaf_Mold': 34, 'Tomato___Spider_mites Two-spotted_spider_mite': 35, 'Pepper,_bell___Bacterial_spot': 36, 'Corn_(maize)___healthy': 37}

# %%
print(f"Length of train_data: {len(train_data)}\nLength of test_data : {len(test_data)}")
# Out:
# Length of train_data: 70295
# Length of test_data : 17572

# %%
# Number of cores available on the device
os.cpu_count()
# Out:
# 4

# %% [markdown]
# ### Creating train and test dataloaders

# %%
# Setup BATCH_SIZE hyper-parameter
BATCH_SIZE = 32
train_dataloader = DataLoader(dataset = train_data,
                             batch_size = BATCH_SIZE,
                             num_workers = 2,
                             shuffle=True)
test_dataloader = DataLoader(dataset = test_data,
                             batch_size = BATCH_SIZE,
                             num_workers = 2,
                             shuffle=False)

train_dataloader, test_dataloader
# Out:
# (<torch.utils.data.dataloader.DataLoader at 0x79bc8e561900>,
#  <torch.utils.data.dataloader.DataLoader at 0x79bc8e5608b0>)

# %%
print(next(iter(train_dataloader))[0].device)
print(next(iter(test_dataloader))[0].device)
# Out:
# cpu
# cpu

# %%
print(f"Number of train batches: {len(train_dataloader)}\nNumber of test batches : {len(test_dataloader)}")
# Out:
# Number of train batches: 2197
# Number of test batches : 550

# %%
# img, label = next(iter(train_dataloader))

# # Batch size will now be 1, you can change the batch size if you like
# print(f"Image shape: {img.shape} -> [Batch size, color channels, height, width]")
# print(f"Label shape: {label.shape}")

# %% [markdown]
# ### Defining a simple model

# %%
# setting up device agnostic code
torch.manual_seed(42)
torch.cuda.manual_seed(42)

model = models.vit_b_16(weights='IMAGENET1K_V1')
# Out:
# Downloading: "https://download.pytorch.org/models/vit_b_16-c867db91.pth" to /root/.cache/torch/hub/checkpoints/vit_b_16-c867db91.pth
# 100%|██████████| 330M/330M [00:02<00:00, 156MB/s]

# %%
model
# Out:
# VisionTransformer(
#   (conv_proj): Conv2d(3, 768, kernel_size=(16, 16), stride=(16, 16))
#   (encoder): Encoder(
#     (dropout): Dropout(p=0.0, inplace=False)
#     (layers): Sequential(
#       (encoder_layer_0): EncoderBlock(
#         (ln_1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#         (self_attention): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=768, out_features=768, bias=True)
#         )
#         (dropout): Dropout(p=0.0, inplace=False)
#         (ln_2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#         (mlp): MLPBlock(
#           (0): Linear(in_features=768, out_features=3072, bias=True)
#           (1): GELU(approximate='none')
#           (2): Dropout(p=0.0, inplace=False)
#           (3): Linear(in_features=3072, out_features=768, bias=True)
#           (4): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (encoder_layer_1): EncoderBlock(
#         (ln_1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#         (self_attention): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=768, out_features=768, bias=True)
#         )
#         (dropout): Dropout(p=0.0, inplace=False)
#         (ln_2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#         (mlp): MLPBlock(
#           (0): Linear(in_features=768, out_features=3072, bias=True)
#           (1): GELU(approximate='none')
#           (2): Dropout(p=0.0, inplace=False)
#           (3): Linear(in_features=3072, out_features=768, bias=True)
#           (4): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (encoder_layer_2): EncoderBlock(
#         (ln_1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#         (self_attention): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=768, out_features=768, bias=True)
#         )
#         (dropout): Dropout(p=0.0, inplace=False)
#         (ln_2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#         (mlp): MLPBlock(
#           (0): Linear(in_features=768, out_features=3072, bias=True)
#           (1): GELU(approximate='none')
#           (2): Dropout(p=0.0, inplace=False)
#           (3): Linear(in_features=3072, out_features=768, bias=True)
#           (4): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (encoder_layer_3): EncoderBlock(
#         (ln_1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#         (self_attention): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=768, out_features=768, bias=True)
#         )
#         (dropout): Dropout(p=0.0, inplace=False)
#         (ln_2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#         (mlp): MLPBlock(
#           (0): Linear(in_features=768, out_features=3072, bias=True)
#           (1): GELU(approximate='none')
#           (2): Dropout(p=0.0, inplace=False)
#           (3): Linear(in_features=3072, out_features=768, bias=True)
#           (4): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (encoder_layer_4): EncoderBlock(
#         (ln_1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#         (self_attention): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=768, out_features=768, bias=True)
#         )
#         (dropout): Dropout(p=0.0, inplace=False)
#         (ln_2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#         (mlp): MLPBlock(
#           (0): Linear(in_features=768, out_features=3072, bias=True)
#           (1): GELU(approximate='none')
#           (2): Dropout(p=0.0, inplace=False)
#           (3): Linear(in_features=3072, out_features=768, bias=True)
#           (4): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (encoder_layer_5): EncoderBlock(
#         (ln_1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#         (self_attention): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=768, out_features=768, bias=True)
#         )
#         (dropout): Dropout(p=0.0, inplace=False)
#         (ln_2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#         (mlp): MLPBlock(
#           (0): Linear(in_features=768, out_features=3072, bias=True)
#           (1): GELU(approximate='none')
#           (2): Dropout(p=0.0, inplace=False)
#           (3): Linear(in_features=3072, out_features=768, bias=True)
#           (4): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (encoder_layer_6): EncoderBlock(
#         (ln_1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#         (self_attention): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=768, out_features=768, bias=True)
#         )
#         (dropout): Dropout(p=0.0, inplace=False)
#         (ln_2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#         (mlp): MLPBlock(
#           (0): Linear(in_features=768, out_features=3072, bias=True)
#           (1): GELU(approximate='none')
#           (2): Dropout(p=0.0, inplace=False)
#           (3): Linear(in_features=3072, out_features=768, bias=True)
#           (4): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (encoder_layer_7): EncoderBlock(
#         (ln_1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#         (self_attention): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=768, out_features=768, bias=True)
#         )
#         (dropout): Dropout(p=0.0, inplace=False)
#         (ln_2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#         (mlp): MLPBlock(
#           (0): Linear(in_features=768, out_features=3072, bias=True)
#           (1): GELU(approximate='none')
#           (2): Dropout(p=0.0, inplace=False)
#           (3): Linear(in_features=3072, out_features=768, bias=True)
#           (4): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (encoder_layer_8): EncoderBlock(
#         (ln_1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#         (self_attention): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=768, out_features=768, bias=True)
#         )
#         (dropout): Dropout(p=0.0, inplace=False)
#         (ln_2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#         (mlp): MLPBlock(
#           (0): Linear(in_features=768, out_features=3072, bias=True)
#           (1): GELU(approximate='none')
#           (2): Dropout(p=0.0, inplace=False)
#           (3): Linear(in_features=3072, out_features=768, bias=True)
#           (4): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (encoder_layer_9): EncoderBlock(
#         (ln_1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#         (self_attention): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=768, out_features=768, bias=True)
#         )
#         (dropout): Dropout(p=0.0, inplace=False)
#         (ln_2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#         (mlp): MLPBlock(
#           (0): Linear(in_features=768, out_features=3072, bias=True)
#           (1): GELU(approximate='none')
#           (2): Dropout(p=0.0, inplace=False)
#           (3): Linear(in_features=3072, out_features=768, bias=True)
#           (4): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (encoder_layer_10): EncoderBlock(
#         (ln_1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#         (self_attention): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=768, out_features=768, bias=True)
#         )
#         (dropout): Dropout(p=0.0, inplace=False)
#         (ln_2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#         (mlp): MLPBlock(
#           (0): Linear(in_features=768, out_features=3072, bias=True)
#           (1): GELU(approximate='none')
#           (2): Dropout(p=0.0, inplace=False)
#           (3): Linear(in_features=3072, out_features=768, bias=True)
#           (4): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (encoder_layer_11): EncoderBlock(
#         (ln_1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#         (self_attention): MultiheadAttention(
#           (out_proj): NonDynamicallyQuantizableLinear(in_features=768, out_features=768, bias=True)
#         )
#         (dropout): Dropout(p=0.0, inplace=False)
#         (ln_2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#         (mlp): MLPBlock(
#           (0): Linear(in_features=768, out_features=3072, bias=True)
#           (1): GELU(approximate='none')
#           (2): Dropout(p=0.0, inplace=False)
#           (3): Linear(in_features=3072, out_features=768, bias=True)
#           (4): Dropout(p=0.0, inplace=False)
#         )
#       )
#     )
#     (ln): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#   )
#   (heads): Sequential(
#     (head): Linear(in_features=768, out_features=1000, bias=True)
#   )
# )

# %%
summary(model, [1,3,224,224])
# Out:
# ===============================================================================================
# Layer (type:depth-idx)                        Output Shape              Param #
# ===============================================================================================
# VisionTransformer                             [1, 1000]                 768
# ├─Conv2d: 1-1                                 [1, 768, 14, 14]          590,592
# ├─Encoder: 1-2                                [1, 197, 768]             151,296
# │    └─Dropout: 2-1                           [1, 197, 768]             --
# │    └─Sequential: 2-2                        [1, 197, 768]             --
# │    │    └─EncoderBlock: 3-1                 [1, 197, 768]             7,087,872
# │    │    └─EncoderBlock: 3-2                 [1, 197, 768]             7,087,872
# │    │    └─EncoderBlock: 3-3                 [1, 197, 768]             7,087,872
# │    │    └─EncoderBlock: 3-4                 [1, 197, 768]             7,087,872
# │    │    └─EncoderBlock: 3-5                 [1, 197, 768]             7,087,872
# │    │    └─EncoderBlock: 3-6                 [1, 197, 768]             7,087,872
# │    │    └─EncoderBlock: 3-7                 [1, 197, 768]             7,087,872
# │    │    └─EncoderBlock: 3-8                 [1, 197, 768]             7,087,872
# │    │    └─EncoderBlock: 3-9                 [1, 197, 768]             7,087,872
# │    │    └─EncoderBlock: 3-10                [1, 197, 768]             7,087,872
# │    │    └─EncoderBlock: 3-11                [1, 197, 768]             7,087,872
# │    │    └─EncoderBlock: 3-12                [1, 197, 768]             7,087,872
# │    └─LayerNorm: 2-3                         [1, 197, 768]             1,536
# ├─Sequential: 1-3                             [1, 1000]                 --
# │    └─Linear: 2-4                            [1, 1000]                 769,000
# ===============================================================================================
# Total params: 86,567,656
# Trainable params: 86,567,656
# Non-trainable params: 0
# Total mult-adds (M): 173.23
# ===============================================================================================
# Input size (MB): 0.60
# Forward/backward pass size (MB): 104.09
# Params size (MB): 232.27
# Estimated Total Size (MB): 336.96
# ===============================================================================================

# %%
# Freeze parameters of pre-trained layers to prevent overwriting during fine-tuning:
for param in model.parameters():
    param.requires_grad = False

# %%
# Replace the final classification head with a new one for 38 classes
num_classes = 38  # Adjust to your actual number of classes

model.heads = nn.Sequential(
  # Replace the original linear layer with one for your num_classes
  nn.Linear(in_features=768, out_features=num_classes, bias=True)
)

model = torch.nn.DataParallel(model, device_ids = [0,1]).to(device)

# %%
summary(model, [1,3,224,224])
# Out:
# ====================================================================================================
# Layer (type:depth-idx)                             Output Shape              Param #
# ====================================================================================================
# DataParallel                                       [1, 38]                   --
# ├─VisionTransformer: 1-1                           [1, 38]                   85,827,878
# ├─VisionTransformer: 1-2                           --                        --
# │    └─Conv2d: 2-1                                 [1, 768, 14, 14]          (590,592)
# │    └─Encoder: 2-2                                [1, 197, 768]             85,207,296
# │    └─Encoder: 2-3                                --                        --
# │    │    └─Dropout: 3-1                           [1, 197, 768]             --
# │    │    └─Sequential: 3-2                        [1, 197, 768]             (85,054,464)
# │    │    └─Sequential: 3-3                        --                        (85,054,464)
# │    │    └─LayerNorm: 3-4                         [1, 197, 768]             (1,536)
# │    └─Sequential: 2-4                             [1, 38]                   29,222
# │    └─Sequential: 2-5                             --                        --
# │    │    └─Linear: 3-5                            [1, 38]                   29,222
# ====================================================================================================
# Total params: 483,518,322
# Trainable params: 87,666
# Non-trainable params: 483,430,656
# Total mult-adds (M): 172.49
# ====================================================================================================
# Input size (MB): 0.60
# Forward/backward pass size (MB): 104.09
# Params size (MB): 229.31
# Estimated Total Size (MB): 334.00
# ====================================================================================================

# %%
###############################################################################################
model_state_dict_path = "/kaggle/input/vt16-30/vt16_model_state_dict_30.pth"  # Adjust the filename if needed

# Check if the state dictionary file exists
if os.path.isfile(model_state_dict_path):
    print("Found state dictionary file:", model_state_dict_path)

    # Load the state dictionary
    try:
        model_state_dict = torch.load(model_state_dict_path)
        model.load_state_dict(model_state_dict)
        print("Loaded state dictionary successfully!")
    except Exception as e:
        print(f"Error loading state dictionary: {e}")
else:
    print("No state dictionary file found at", model_state_dict_path)
    
###############################################################################################
# Out:
# Found state dictionary file: /kaggle/input/vt16-30/vt16_model_state_dict_30.pth
# Loaded state dictionary successfully!

# %%
loss_fn = torch.nn.CrossEntropyLoss()  # Common choice for multi-class classification
optimizer = torch.optim.SGD(model.parameters(), lr=0.001, momentum=0.9)  # Only optimize unfrozen layers, By default it will be requires_grad=True

# %%
model
# Out:
# DataParallel(
#   (module): VisionTransformer(
#     (conv_proj): Conv2d(3, 768, kernel_size=(16, 16), stride=(16, 16))
#     (encoder): Encoder(
#       (dropout): Dropout(p=0.0, inplace=False)
#       (layers): Sequential(
#         (encoder_layer_0): EncoderBlock(
#           (ln_1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#           (self_attention): MultiheadAttention(
#             (out_proj): NonDynamicallyQuantizableLinear(in_features=768, out_features=768, bias=True)
#           )
#           (dropout): Dropout(p=0.0, inplace=False)
#           (ln_2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#           (mlp): MLPBlock(
#             (0): Linear(in_features=768, out_features=3072, bias=True)
#             (1): GELU(approximate='none')
#             (2): Dropout(p=0.0, inplace=False)
#             (3): Linear(in_features=3072, out_features=768, bias=True)
#             (4): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (encoder_layer_1): EncoderBlock(
#           (ln_1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#           (self_attention): MultiheadAttention(
#             (out_proj): NonDynamicallyQuantizableLinear(in_features=768, out_features=768, bias=True)
#           )
#           (dropout): Dropout(p=0.0, inplace=False)
#           (ln_2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#           (mlp): MLPBlock(
#             (0): Linear(in_features=768, out_features=3072, bias=True)
#             (1): GELU(approximate='none')
#             (2): Dropout(p=0.0, inplace=False)
#             (3): Linear(in_features=3072, out_features=768, bias=True)
#             (4): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (encoder_layer_2): EncoderBlock(
#           (ln_1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#           (self_attention): MultiheadAttention(
#             (out_proj): NonDynamicallyQuantizableLinear(in_features=768, out_features=768, bias=True)
#           )
#           (dropout): Dropout(p=0.0, inplace=False)
#           (ln_2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#           (mlp): MLPBlock(
#             (0): Linear(in_features=768, out_features=3072, bias=True)
#             (1): GELU(approximate='none')
#             (2): Dropout(p=0.0, inplace=False)
#             (3): Linear(in_features=3072, out_features=768, bias=True)
#             (4): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (encoder_layer_3): EncoderBlock(
#           (ln_1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#           (self_attention): MultiheadAttention(
#             (out_proj): NonDynamicallyQuantizableLinear(in_features=768, out_features=768, bias=True)
#           )
#           (dropout): Dropout(p=0.0, inplace=False)
#           (ln_2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#           (mlp): MLPBlock(
#             (0): Linear(in_features=768, out_features=3072, bias=True)
#             (1): GELU(approximate='none')
#             (2): Dropout(p=0.0, inplace=False)
#             (3): Linear(in_features=3072, out_features=768, bias=True)
#             (4): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (encoder_layer_4): EncoderBlock(
#           (ln_1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#           (self_attention): MultiheadAttention(
#             (out_proj): NonDynamicallyQuantizableLinear(in_features=768, out_features=768, bias=True)
#           )
#           (dropout): Dropout(p=0.0, inplace=False)
#           (ln_2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#           (mlp): MLPBlock(
#             (0): Linear(in_features=768, out_features=3072, bias=True)
#             (1): GELU(approximate='none')
#             (2): Dropout(p=0.0, inplace=False)
#             (3): Linear(in_features=3072, out_features=768, bias=True)
#             (4): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (encoder_layer_5): EncoderBlock(
#           (ln_1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#           (self_attention): MultiheadAttention(
#             (out_proj): NonDynamicallyQuantizableLinear(in_features=768, out_features=768, bias=True)
#           )
#           (dropout): Dropout(p=0.0, inplace=False)
#           (ln_2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#           (mlp): MLPBlock(
#             (0): Linear(in_features=768, out_features=3072, bias=True)
#             (1): GELU(approximate='none')
#             (2): Dropout(p=0.0, inplace=False)
#             (3): Linear(in_features=3072, out_features=768, bias=True)
#             (4): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (encoder_layer_6): EncoderBlock(
#           (ln_1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#           (self_attention): MultiheadAttention(
#             (out_proj): NonDynamicallyQuantizableLinear(in_features=768, out_features=768, bias=True)
#           )
#           (dropout): Dropout(p=0.0, inplace=False)
#           (ln_2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#           (mlp): MLPBlock(
#             (0): Linear(in_features=768, out_features=3072, bias=True)
#             (1): GELU(approximate='none')
#             (2): Dropout(p=0.0, inplace=False)
#             (3): Linear(in_features=3072, out_features=768, bias=True)
#             (4): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (encoder_layer_7): EncoderBlock(
#           (ln_1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#           (self_attention): MultiheadAttention(
#             (out_proj): NonDynamicallyQuantizableLinear(in_features=768, out_features=768, bias=True)
#           )
#           (dropout): Dropout(p=0.0, inplace=False)
#           (ln_2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#           (mlp): MLPBlock(
#             (0): Linear(in_features=768, out_features=3072, bias=True)
#             (1): GELU(approximate='none')
#             (2): Dropout(p=0.0, inplace=False)
#             (3): Linear(in_features=3072, out_features=768, bias=True)
#             (4): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (encoder_layer_8): EncoderBlock(
#           (ln_1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#           (self_attention): MultiheadAttention(
#             (out_proj): NonDynamicallyQuantizableLinear(in_features=768, out_features=768, bias=True)
#           )
#           (dropout): Dropout(p=0.0, inplace=False)
#           (ln_2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#           (mlp): MLPBlock(
#             (0): Linear(in_features=768, out_features=3072, bias=True)
#             (1): GELU(approximate='none')
#             (2): Dropout(p=0.0, inplace=False)
#             (3): Linear(in_features=3072, out_features=768, bias=True)
#             (4): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (encoder_layer_9): EncoderBlock(
#           (ln_1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#           (self_attention): MultiheadAttention(
#             (out_proj): NonDynamicallyQuantizableLinear(in_features=768, out_features=768, bias=True)
#           )
#           (dropout): Dropout(p=0.0, inplace=False)
#           (ln_2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#           (mlp): MLPBlock(
#             (0): Linear(in_features=768, out_features=3072, bias=True)
#             (1): GELU(approximate='none')
#             (2): Dropout(p=0.0, inplace=False)
#             (3): Linear(in_features=3072, out_features=768, bias=True)
#             (4): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (encoder_layer_10): EncoderBlock(
#           (ln_1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#           (self_attention): MultiheadAttention(
#             (out_proj): NonDynamicallyQuantizableLinear(in_features=768, out_features=768, bias=True)
#           )
#           (dropout): Dropout(p=0.0, inplace=False)
#           (ln_2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#           (mlp): MLPBlock(
#             (0): Linear(in_features=768, out_features=3072, bias=True)
#             (1): GELU(approximate='none')
#             (2): Dropout(p=0.0, inplace=False)
#             (3): Linear(in_features=3072, out_features=768, bias=True)
#             (4): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (encoder_layer_11): EncoderBlock(
#           (ln_1): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#           (self_attention): MultiheadAttention(
#             (out_proj): NonDynamicallyQuantizableLinear(in_features=768, out_features=768, bias=True)
#           )
#           (dropout): Dropout(p=0.0, inplace=False)
#           (ln_2): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#           (mlp): MLPBlock(
#             (0): Linear(in_features=768, out_features=3072, bias=True)
#             (1): GELU(approximate='none')
#             (2): Dropout(p=0.0, inplace=False)
#             (3): Linear(in_features=3072, out_features=768, bias=True)
#             (4): Dropout(p=0.0, inplace=False)
#           )
#         )
#       )
#       (ln): LayerNorm((768,), eps=1e-06, elementwise_affine=True)
#     )
#     (heads): Sequential(
#       (0): Linear(in_features=768, out_features=38, bias=True)
#     )
#   )
# )

# %%
summary(model, [1,3,224,224])
# Out:
# ====================================================================================================
# Layer (type:depth-idx)                             Output Shape              Param #
# ====================================================================================================
# DataParallel                                       [1, 38]                   --
# ├─VisionTransformer: 1-1                           [1, 38]                   85,827,878
# ├─VisionTransformer: 1-2                           --                        --
# │    └─Conv2d: 2-1                                 [1, 768, 14, 14]          (590,592)
# │    └─Encoder: 2-2                                [1, 197, 768]             85,207,296
# │    └─Encoder: 2-3                                --                        --
# │    │    └─Dropout: 3-1                           [1, 197, 768]             --
# │    │    └─Sequential: 3-2                        [1, 197, 768]             (85,054,464)
# │    │    └─Sequential: 3-3                        --                        (85,054,464)
# │    │    └─LayerNorm: 3-4                         [1, 197, 768]             (1,536)
# │    └─Sequential: 2-4                             [1, 38]                   29,222
# │    └─Sequential: 2-5                             --                        --
# │    │    └─Linear: 3-5                            [1, 38]                   29,222
# ====================================================================================================
# Total params: 483,518,322
# Trainable params: 87,666
# Non-trainable params: 483,430,656
# Total mult-adds (M): 172.49
# ====================================================================================================
# Input size (MB): 0.60
# Forward/backward pass size (MB): 104.09
# Params size (MB): 229.31
# Estimated Total Size (MB): 334.00
# ====================================================================================================

# %%
def check_requires_grad(model):
  """
  This function iterates through the model and prints information
  about requires_grad for each module and its parameters.
  """
  for name, param in model.named_parameters():
    if param.requires_grad:
      print(f"{name}: requires_grad=True")
    else:
      print(f"{name}: requires_grad=False")

# Example usage
check_requires_grad(model)
# Out:
# module.class_token: requires_grad=False
# module.conv_proj.weight: requires_grad=False
# module.conv_proj.bias: requires_grad=False
# module.encoder.pos_embedding: requires_grad=False
# module.encoder.layers.encoder_layer_0.ln_1.weight: requires_grad=False
# module.encoder.layers.encoder_layer_0.ln_1.bias: requires_grad=False
# module.encoder.layers.encoder_layer_0.self_attention.in_proj_weight: requires_grad=False
# module.encoder.layers.encoder_layer_0.self_attention.in_proj_bias: requires_grad=False
# module.encoder.layers.encoder_layer_0.self_attention.out_proj.weight: requires_grad=False
# module.encoder.layers.encoder_layer_0.self_attention.out_proj.bias: requires_grad=False
# module.encoder.layers.encoder_layer_0.ln_2.weight: requires_grad=False
# module.encoder.layers.encoder_layer_0.ln_2.bias: requires_grad=False
# module.encoder.layers.encoder_layer_0.mlp.0.weight: requires_grad=False
# module.encoder.layers.encoder_layer_0.mlp.0.bias: requires_grad=False
# module.encoder.layers.encoder_layer_0.mlp.3.weight: requires_grad=False
# module.encoder.layers.encoder_layer_0.mlp.3.bias: requires_grad=False
# module.encoder.layers.encoder_layer_1.ln_1.weight: requires_grad=False
# module.encoder.layers.encoder_layer_1.ln_1.bias: requires_grad=False
# module.encoder.layers.encoder_layer_1.self_attention.in_proj_weight: requires_grad=False
# module.encoder.layers.encoder_layer_1.self_attention.in_proj_bias: requires_grad=False
# module.encoder.layers.encoder_layer_1.self_attention.out_proj.weight: requires_grad=False
# module.encoder.layers.encoder_layer_1.self_attention.out_proj.bias: requires_grad=False
# module.encoder.layers.encoder_layer_1.ln_2.weight: requires_grad=False
# module.encoder.layers.encoder_layer_1.ln_2.bias: requires_grad=False
# module.encoder.layers.encoder_layer_1.mlp.0.weight: requires_grad=False
# module.encoder.layers.encoder_layer_1.mlp.0.bias: requires_grad=False
# module.encoder.layers.encoder_layer_1.mlp.3.weight: requires_grad=False
# module.encoder.layers.encoder_layer_1.mlp.3.bias: requires_grad=False
# module.encoder.layers.encoder_layer_2.ln_1.weight: requires_grad=False
# module.encoder.layers.encoder_layer_2.ln_1.bias: requires_grad=False
# module.encoder.layers.encoder_layer_2.self_attention.in_proj_weight: requires_grad=False
# module.encoder.layers.encoder_layer_2.self_attention.in_proj_bias: requires_grad=False
# module.encoder.layers.encoder_layer_2.self_attention.out_proj.weight: requires_grad=False
# module.encoder.layers.encoder_layer_2.self_attention.out_proj.bias: requires_grad=False
# module.encoder.layers.encoder_layer_2.ln_2.weight: requires_grad=False
# module.encoder.layers.encoder_layer_2.ln_2.bias: requires_grad=False
# module.encoder.layers.encoder_layer_2.mlp.0.weight: requires_grad=False
# module.encoder.layers.encoder_layer_2.mlp.0.bias: requires_grad=False
# module.encoder.layers.encoder_layer_2.mlp.3.weight: requires_grad=False
# module.encoder.layers.encoder_layer_2.mlp.3.bias: requires_grad=False
# module.encoder.layers.encoder_layer_3.ln_1.weight: requires_grad=False
# module.encoder.layers.encoder_layer_3.ln_1.bias: requires_grad=False
# module.encoder.layers.encoder_layer_3.self_attention.in_proj_weight: requires_grad=False
# module.encoder.layers.encoder_layer_3.self_attention.in_proj_bias: requires_grad=False
# module.encoder.layers.encoder_layer_3.self_attention.out_proj.weight: requires_grad=False
# module.encoder.layers.encoder_layer_3.self_attention.out_proj.bias: requires_grad=False
# module.encoder.layers.encoder_layer_3.ln_2.weight: requires_grad=False
# module.encoder.layers.encoder_layer_3.ln_2.bias: requires_grad=False
# module.encoder.layers.encoder_layer_3.mlp.0.weight: requires_grad=False
# module.encoder.layers.encoder_layer_3.mlp.0.bias: requires_grad=False
# module.encoder.layers.encoder_layer_3.mlp.3.weight: requires_grad=False
# module.encoder.layers.encoder_layer_3.mlp.3.bias: requires_grad=False
# module.encoder.layers.encoder_layer_4.ln_1.weight: requires_grad=False
# module.encoder.layers.encoder_layer_4.ln_1.bias: requires_grad=False
# module.encoder.layers.encoder_layer_4.self_attention.in_proj_weight: requires_grad=False
# module.encoder.layers.encoder_layer_4.self_attention.in_proj_bias: requires_grad=False
# module.encoder.layers.encoder_layer_4.self_attention.out_proj.weight: requires_grad=False
# module.encoder.layers.encoder_layer_4.self_attention.out_proj.bias: requires_grad=False
# module.encoder.layers.encoder_layer_4.ln_2.weight: requires_grad=False
# module.encoder.layers.encoder_layer_4.ln_2.bias: requires_grad=False
# module.encoder.layers.encoder_layer_4.mlp.0.weight: requires_grad=False
# module.encoder.layers.encoder_layer_4.mlp.0.bias: requires_grad=False
# module.encoder.layers.encoder_layer_4.mlp.3.weight: requires_grad=False
# module.encoder.layers.encoder_layer_4.mlp.3.bias: requires_grad=False
# module.encoder.layers.encoder_layer_5.ln_1.weight: requires_grad=False
# module.encoder.layers.encoder_layer_5.ln_1.bias: requires_grad=False
# module.encoder.layers.encoder_layer_5.self_attention.in_proj_weight: requires_grad=False
# module.encoder.layers.encoder_layer_5.self_attention.in_proj_bias: requires_grad=False
# module.encoder.layers.encoder_layer_5.self_attention.out_proj.weight: requires_grad=False
# module.encoder.layers.encoder_layer_5.self_attention.out_proj.bias: requires_grad=False
# module.encoder.layers.encoder_layer_5.ln_2.weight: requires_grad=False
# module.encoder.layers.encoder_layer_5.ln_2.bias: requires_grad=False
# module.encoder.layers.encoder_layer_5.mlp.0.weight: requires_grad=False
# module.encoder.layers.encoder_layer_5.mlp.0.bias: requires_grad=False
# module.encoder.layers.encoder_layer_5.mlp.3.weight: requires_grad=False
# module.encoder.layers.encoder_layer_5.mlp.3.bias: requires_grad=False
# module.encoder.layers.encoder_layer_6.ln_1.weight: requires_grad=False
# module.encoder.layers.encoder_layer_6.ln_1.bias: requires_grad=False
# module.encoder.layers.encoder_layer_6.self_attention.in_proj_weight: requires_grad=False
# module.encoder.layers.encoder_layer_6.self_attention.in_proj_bias: requires_grad=False
# module.encoder.layers.encoder_layer_6.self_attention.out_proj.weight: requires_grad=False
# module.encoder.layers.encoder_layer_6.self_attention.out_proj.bias: requires_grad=False
# module.encoder.layers.encoder_layer_6.ln_2.weight: requires_grad=False
# module.encoder.layers.encoder_layer_6.ln_2.bias: requires_grad=False
# module.encoder.layers.encoder_layer_6.mlp.0.weight: requires_grad=False
# module.encoder.layers.encoder_layer_6.mlp.0.bias: requires_grad=False
# module.encoder.layers.encoder_layer_6.mlp.3.weight: requires_grad=False
# module.encoder.layers.encoder_layer_6.mlp.3.bias: requires_grad=False
# module.encoder.layers.encoder_layer_7.ln_1.weight: requires_grad=False
# module.encoder.layers.encoder_layer_7.ln_1.bias: requires_grad=False
# module.encoder.layers.encoder_layer_7.self_attention.in_proj_weight: requires_grad=False
# module.encoder.layers.encoder_layer_7.self_attention.in_proj_bias: requires_grad=False
# module.encoder.layers.encoder_layer_7.self_attention.out_proj.weight: requires_grad=False
# module.encoder.layers.encoder_layer_7.self_attention.out_proj.bias: requires_grad=False
# module.encoder.layers.encoder_layer_7.ln_2.weight: requires_grad=False
# module.encoder.layers.encoder_layer_7.ln_2.bias: requires_grad=False
# module.encoder.layers.encoder_layer_7.mlp.0.weight: requires_grad=False
# module.encoder.layers.encoder_layer_7.mlp.0.bias: requires_grad=False
# module.encoder.layers.encoder_layer_7.mlp.3.weight: requires_grad=False
# module.encoder.layers.encoder_layer_7.mlp.3.bias: requires_grad=False
# module.encoder.layers.encoder_layer_8.ln_1.weight: requires_grad=False
# module.encoder.layers.encoder_layer_8.ln_1.bias: requires_grad=False
# module.encoder.layers.encoder_layer_8.self_attention.in_proj_weight: requires_grad=False
# module.encoder.layers.encoder_layer_8.self_attention.in_proj_bias: requires_grad=False
# module.encoder.layers.encoder_layer_8.self_attention.out_proj.weight: requires_grad=False
# module.encoder.layers.encoder_layer_8.self_attention.out_proj.bias: requires_grad=False
# module.encoder.layers.encoder_layer_8.ln_2.weight: requires_grad=False
# module.encoder.layers.encoder_layer_8.ln_2.bias: requires_grad=False
# module.encoder.layers.encoder_layer_8.mlp.0.weight: requires_grad=False
# module.encoder.layers.encoder_layer_8.mlp.0.bias: requires_grad=False
# module.encoder.layers.encoder_layer_8.mlp.3.weight: requires_grad=False
# module.encoder.layers.encoder_layer_8.mlp.3.bias: requires_grad=False
# module.encoder.layers.encoder_layer_9.ln_1.weight: requires_grad=False
# module.encoder.layers.encoder_layer_9.ln_1.bias: requires_grad=False
# module.encoder.layers.encoder_layer_9.self_attention.in_proj_weight: requires_grad=False
# module.encoder.layers.encoder_layer_9.self_attention.in_proj_bias: requires_grad=False
# module.encoder.layers.encoder_layer_9.self_attention.out_proj.weight: requires_grad=False
# module.encoder.layers.encoder_layer_9.self_attention.out_proj.bias: requires_grad=False
# module.encoder.layers.encoder_layer_9.ln_2.weight: requires_grad=False
# module.encoder.layers.encoder_layer_9.ln_2.bias: requires_grad=False
# module.encoder.layers.encoder_layer_9.mlp.0.weight: requires_grad=False
# module.encoder.layers.encoder_layer_9.mlp.0.bias: requires_grad=False
# module.encoder.layers.encoder_layer_9.mlp.3.weight: requires_grad=False
# module.encoder.layers.encoder_layer_9.mlp.3.bias: requires_grad=False
# module.encoder.layers.encoder_layer_10.ln_1.weight: requires_grad=False
# module.encoder.layers.encoder_layer_10.ln_1.bias: requires_grad=False
# module.encoder.layers.encoder_layer_10.self_attention.in_proj_weight: requires_grad=False
# module.encoder.layers.encoder_layer_10.self_attention.in_proj_bias: requires_grad=False
# module.encoder.layers.encoder_layer_10.self_attention.out_proj.weight: requires_grad=False
# module.encoder.layers.encoder_layer_10.self_attention.out_proj.bias: requires_grad=False
# module.encoder.layers.encoder_layer_10.ln_2.weight: requires_grad=False
# module.encoder.layers.encoder_layer_10.ln_2.bias: requires_grad=False
# module.encoder.layers.encoder_layer_10.mlp.0.weight: requires_grad=False
# module.encoder.layers.encoder_layer_10.mlp.0.bias: requires_grad=False
# module.encoder.layers.encoder_layer_10.mlp.3.weight: requires_grad=False
# module.encoder.layers.encoder_layer_10.mlp.3.bias: requires_grad=False
# module.encoder.layers.encoder_layer_11.ln_1.weight: requires_grad=False
# module.encoder.layers.encoder_layer_11.ln_1.bias: requires_grad=False
# module.encoder.layers.encoder_layer_11.self_attention.in_proj_weight: requires_grad=False
# module.encoder.layers.encoder_layer_11.self_attention.in_proj_bias: requires_grad=False
# module.encoder.layers.encoder_layer_11.self_attention.out_proj.weight: requires_grad=False
# module.encoder.layers.encoder_layer_11.self_attention.out_proj.bias: requires_grad=False
# module.encoder.layers.encoder_layer_11.ln_2.weight: requires_grad=False
# module.encoder.layers.encoder_layer_11.ln_2.bias: requires_grad=False
# module.encoder.layers.encoder_layer_11.mlp.0.weight: requires_grad=False
# module.encoder.layers.encoder_layer_11.mlp.0.bias: requires_grad=False
# module.encoder.layers.encoder_layer_11.mlp.3.weight: requires_grad=False
# module.encoder.layers.encoder_layer_11.mlp.3.bias: requires_grad=False
# module.encoder.ln.weight: requires_grad=False
# module.encoder.ln.bias: requires_grad=False
# module.heads.0.weight: requires_grad=True
# module.heads.0.bias: requires_grad=True

# %% [markdown]
# ### Creating `train_step()` & `test_step()` functions

# %%
def train_step(model: torch.nn.Module,
               dataloader: torch.utils.data.DataLoader,
               loss_fn: torch.nn.Module,
               optimizer: torch.optim.Optimizer):
  # Put the model on the training mode
  model.train()

  # setup train loss and accuracy(evaluation metrics)
  train_loss, train_acc = 0, 0

  # loop through the dataloader
  for batch, (X, y, _) in enumerate(dataloader):
    # send data to the target device
    X, y = X.to(device), y.to(device)

    # 1. Forward pass
    y_pred = model(X)

    # 2. Calculate the loss
    loss = loss_fn(y_pred, y)
    train_loss += loss.item()

    # 3. Optimizer zero grad
    optimizer.zero_grad()

    # 4. backprop
    loss.backward()

    # 5. optimizer step
    optimizer.step()

    # Calculate the accuracy
    y_pred_class = torch.argmax(torch.softmax(y_pred,dim=1),dim=1)
    train_acc += (y_pred_class == y).sum().item() / len(y_pred)

  # Adjust the train_loss and train_acc per batch
  train_loss /= len(dataloader)
  train_acc /= len(dataloader)

  return train_loss, train_acc

# %%
# Create a test step
def test_step(model: torch.nn.Module,
              dataloader: torch.utils.data.DataLoader,
              loss_fn: torch.nn.Module):

  # setup evaluation metrics
  test_loss, test_acc = 0, 0
  cm = ConfusionMatrix(task='multiclass',num_classes=len(class_names)).to(device)

  # set to training mode
  model.eval()
  with torch.inference_mode():
    for batch, (X, y, _) in enumerate(dataloader):
      # put data on target device
      X, y = X.to(device), y.to(device)

      # forward pass
      test_pred_logits = model(X)

      # calculate the loss
      loss = loss_fn(test_pred_logits, y)
      test_loss += loss.item()

      # calculate the accuracy
      test_pred_labels = test_pred_logits.argmax(dim=1)
      test_acc += ((test_pred_labels == y).sum().item()/len(test_pred_labels))
        
      # confusion matrix
      cm.update(test_pred_labels, y)

  # Normalize the confusion matrix
  cm = cm.compute().cpu().numpy()
    
  # Calculate precision, recall, and F1-score
  precision = np.diag(cm) / np.sum(cm, axis=0)
  recall = np.diag(cm) / np.sum(cm, axis=1)
  f1 = 2 * (precision * recall) / (precision + recall)
    
  # Average precision, recall, and F1-score across classes
  avg_precision = np.mean(precision)
  avg_recall = np.mean(recall)
  avg_f1 = np.mean(f1)

  # adjust test_loss and test_acc to batch
  test_loss /= len(dataloader)
  test_acc /= len(dataloader)

  return test_loss, test_acc, cm, avg_precision, avg_recall, avg_f1

# %%
num_classes=len(class_names)

# %%
num_classes
# Out:
# 38

# %%
def plot_confusion_matrix(cm, class_names):
    """
    Plots the confusion matrix using Seaborn's heatmap function.
    
    Parameters:
        cm (numpy.ndarray): Confusion matrix.
        class_names (list): List of class names.
    """
    plt.figure(figsize=(10, 8))
    sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=class_names, yticklabels=class_names)
    plt.xlabel('Predicted Labels')
    plt.ylabel('True Labels')
    plt.title('Confusion Matrix')
    plt.show()

# %% [markdown]
# ### Creating a `train()` function to combine `train_step()` & `test_step()`

# %%
from tqdm.auto import tqdm

def train(model: torch.nn.Module,
          train_dataloader: torch.utils.data.DataLoader,
          test_dataloader: torch.utils.data.DataLoader,
          optimizer: torch.optim.Optimizer,
          loss_fn: torch.nn.Module = nn.CrossEntropyLoss(),
          epochs: int=5):
    
  #scheduler = lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.1, patience=lr_scheduler_patience, verbose=True)

  # Create empty results dictionary
  results = {"train_loss":[],
             "train_acc":[],
             "test_loss":[],
             "test_acc":[]}
  
  test_confusion_matrices = []  # List to store confusion matrices for each epoch

  # loop through train and test loops for no. of epochs
  for epoch in tqdm(range(epochs)):
    train_loss, train_acc = train_step(model=model,
                                       dataloader=train_dataloader,
                                       loss_fn=loss_fn,
                                       optimizer=optimizer)
    test_loss, test_acc, cm, precision, recall, f1  = test_step(model=model,
                                                                dataloader=test_dataloader,
                                                                loss_fn=loss_fn)
    
    
        
    # Update the learning rate based on the test loss
    #scheduler.step(test_loss)
            
    # Print out whats happening
    print(f"Epoch: {epoch+1} | Train loss: {train_loss:.4f} | Train acc: {train_acc:.4f} | Test loss: {test_loss:.4f} | Test acc: {test_acc:.4f} | Test Precision: {precision.mean():.4f} | Test Recall: {recall.mean():.4f} | Test F1 Score: {f1.mean():.4f}")
    
    # update the results dictionary
    results["train_loss"].append(train_loss),
    results["train_acc"].append(train_acc),
    results["test_loss"].append(test_loss),
    results["test_acc"].append(test_acc),
    
    # Store confusion matrix for this epoch
    test_confusion_matrices.append(cm)
    

  # Print the final confusion matrix
  print("Final Test Confusion Matrix:\n")
  plot_confusion_matrix(test_confusion_matrices[-1], class_names)

  # Return filled results at the end of the epoch
  return results

# %%
# set random seeds
torch.manual_seed(42)
torch.cuda.manual_seed(42)

# set the no. of epochs
EPOCHS = 20

# optimizer and loss function are already set way above

# start the timer
from timeit import default_timer as timer
start_time = timer()

# Train model_0
model_0_results = train(model = model,
          train_dataloader = train_dataloader,
          test_dataloader =  test_dataloader,
          optimizer = optimizer,
          loss_fn = loss_fn,
          epochs = EPOCHS)

# End the timer and print how long it took
end_time = timer()
print(f"Total training time: {end_time - start_time: .3f} seconds")
# Out:
#   0%|          | 0/20 [00:00<?, ?it/s]
# Epoch: 1 | Train loss: 0.1333 | Train acc: 0.9652 | Test loss: 0.0678 | Test acc: 0.9836 | Test Precision: 0.9834 | Test Recall: 0.9835 | Test F1 Score: 0.9834
# Epoch: 2 | Train loss: 0.1340 | Train acc: 0.9642 | Test loss: 0.0664 | Test acc: 0.9840 | Test Precision: 0.9838 | Test Recall: 0.9838 | Test F1 Score: 0.9838
# Epoch: 3 | Train loss: 0.1314 | Train acc: 0.9648 | Test loss: 0.0661 | Test acc: 0.9834 | Test Precision: 0.9831 | Test Recall: 0.9833 | Test F1 Score: 0.9832
# Epoch: 4 | Train loss: 0.1301 | Train acc: 0.9657 | Test loss: 0.0651 | Test acc: 0.9840 | Test Precision: 0.9838 | Test Recall: 0.9839 | Test F1 Score: 0.9838
# Epoch: 5 | Train loss: 0.1304 | Train acc: 0.9651 | Test loss: 0.0644 | Test acc: 0.9842 | Test Precision: 0.9839 | Test Recall: 0.9841 | Test F1 Score: 0.9840
# Epoch: 6 | Train loss: 0.1289 | Train acc: 0.9651 | Test loss: 0.0639 | Test acc: 0.9847 | Test Precision: 0.9844 | Test Recall: 0.9845 | Test F1 Score: 0.9845
# Epoch: 7 | Train loss: 0.1255 | Train acc: 0.9665 | Test loss: 0.0636 | Test acc: 0.9840 | Test Precision: 0.9837 | Test Recall: 0.9839 | Test F1 Score: 0.9838
# Epoch: 8 | Train loss: 0.1253 | Train acc: 0.9666 | Test loss: 0.0629 | Test acc: 0.9844 | Test Precision: 0.9842 | Test Recall: 0.9844 | Test F1 Score: 0.9843
# Epoch: 9 | Train loss: 0.1222 | Train acc: 0.9678 | Test loss: 0.0621 | Test acc: 0.9843 | Test Precision: 0.9841 | Test Recall: 0.9842 | Test F1 Score: 0.9841
# Epoch: 10 | Train loss: 0.1235 | Train acc: 0.9670 | Test loss: 0.0613 | Test acc: 0.9849 | Test Precision: 0.9847 | Test Recall: 0.9848 | Test F1 Score: 0.9847
# Epoch: 11 | Train loss: 0.1213 | Train acc: 0.9675 | Test loss: 0.0607 | Test acc: 0.9847 | Test Precision: 0.9845 | Test Recall: 0.9846 | Test F1 Score: 0.9845
# Epoch: 12 | Train loss: 0.1198 | Train acc: 0.9675 | Test loss: 0.0607 | Test acc: 0.9852 | Test Precision: 0.9851 | Test Recall: 0.9850 | Test F1 Score: 0.9850
# Epoch: 13 | Train loss: 0.1187 | Train acc: 0.9686 | Test loss: 0.0597 | Test acc: 0.9852 | Test Precision: 0.9850 | Test Recall: 0.9851 | Test F1 Score: 0.9850
# Epoch: 14 | Train loss: 0.1182 | Train acc: 0.9686 | Test loss: 0.0591 | Test acc: 0.9852 | Test Precision: 0.9851 | Test Recall: 0.9850 | Test F1 Score: 0.9850
# Epoch: 15 | Train loss: 0.1184 | Train acc: 0.9678 | Test loss: 0.0590 | Test acc: 0.9852 | Test Precision: 0.9851 | Test Recall: 0.9851 | Test F1 Score: 0.9850
# Epoch: 16 | Train loss: 0.1187 | Train acc: 0.9677 | Test loss: 0.0585 | Test acc: 0.9847 | Test Precision: 0.9845 | Test Recall: 0.9846 | Test F1 Score: 0.9845
# Epoch: 17 | Train loss: 0.1153 | Train acc: 0.9690 | Test loss: 0.0576 | Test acc: 0.9853 | Test Precision: 0.9851 | Test Recall: 0.9852 | Test F1 Score: 0.9852
# Epoch: 18 | Train loss: 0.1155 | Train acc: 0.9682 | Test loss: 0.0575 | Test acc: 0.9852 | Test Precision: 0.9849 | Test Recall: 0.9851 | Test F1 Score: 0.9850
# Epoch: 19 | Train loss: 0.1134 | Train acc: 0.9696 | Test loss: 0.0569 | Test acc: 0.9857 | Test Precision: 0.9855 | Test Recall: 0.9856 | Test F1 Score: 0.9855
# Epoch: 20 | Train loss: 0.1140 | Train acc: 0.9692 | Test loss: 0.0560 | Test acc: 0.9859 | Test Precision: 0.9857 | Test Recall: 0.9857 | Test F1 Score: 0.9857
# Final Test Confusion Matrix:
# Total training time:  22548.731 seconds

# %%
for batch_data in train_dataloader:
    inputs, labels, class_labels = batch_data
    print("Input tensor shape:", inputs.shape)
    print("Labels tensor shape:", labels.shape)
    print("Class labels:", class_labels)
    break  # Only print the first batch
# Out:
# Input tensor shape: torch.Size([32, 3, 224, 224])
# Labels tensor shape: torch.Size([32])
# Class labels: ('Peach___Bacterial_spot', 'Tomato___Bacterial_spot', 'Tomato___Tomato_Yellow_Leaf_Curl_Virus', 'Pepper,_bell___healthy', 'Corn_(maize)___healthy', 'Squash___Powdery_mildew', 'Peach___healthy', 'Tomato___Bacterial_spot', 'Pepper,_bell___Bacterial_spot', 'Corn_(maize)___Northern_Leaf_Blight', 'Pepper,_bell___healthy', 'Corn_(maize)___Northern_Leaf_Blight', 'Tomato___Septoria_leaf_spot', 'Peach___healthy', 'Apple___healthy', 'Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot', 'Tomato___Late_blight', 'Orange___Haunglongbing_(Citrus_greening)', 'Orange___Haunglongbing_(Citrus_greening)', 'Tomato___Tomato_Yellow_Leaf_Curl_Virus', 'Tomato___Spider_mites Two-spotted_spider_mite', 'Potato___Early_blight', 'Squash___Powdery_mildew', 'Grape___healthy', 'Potato___Late_blight', 'Tomato___Leaf_Mold', 'Peach___healthy', 'Cherry_(including_sour)___healthy', 'Blueberry___healthy', 'Squash___Powdery_mildew', 'Potato___Early_blight', 'Squash___Powdery_mildew')

# %%
def plot_curves(results: Dict[str, List[float]]):
  """  plots training curves of a results dictionary  """
  # Get the loss values of the results dictionary (training and testing)
  loss = results["train_loss"]
  test_loss = results["test_loss"]

  # get the accuract values of the results dictionary
  accuracy = results["train_acc"]
  test_accuracy = results["test_acc"]

  # Figure out how many epochs there were
  epochs = range(len(results["train_loss"]))

  # setup a plot
  plt.figure(figsize=(15,7))

  # plot the loss
  plt.subplot(1,2,1)
  plt.plot(epochs, loss, label="Train loss")
  plt.plot(epochs, test_loss, label="Test loss")
  plt.title("Loss")
  plt.xlabel("Epochs")
  plt.legend()

  # Plot the accuracy
  plt.subplot(1,2,2)
  plt.plot(epochs, accuracy, label="Train Accuracy")
  plt.plot(epochs, test_accuracy, label="Test Accuracy")
  plt.title("Accuracy")
  plt.xlabel("Epochs")
  plt.legend()

# %%
plot_curves(model_0_results)

# %%
model_0_results
# Out:
# {'train_loss': [0.133349544329261,
#   0.13398512501335708,
#   0.13138289063784023,
#   0.13006608136096595,
#   0.13042637399488083,
#   0.12887063662661005,
#   0.12553186968060503,
#   0.1253167999536138,
#   0.12221306313802545,
#   0.12347861402742243,
#   0.12133228274475161,
#   0.11979546207865945,
#   0.1186737596730519,
#   0.11821363365949963,
#   0.118387441999081,
#   0.11872735128915603,
#   0.11533689031120548,
#   0.11548685518372762,
#   0.11342729934316144,
#   0.11403194270836436],
#  'train_acc': [0.9652026726168095,
#   0.9641927727533594,
#   0.9648099681383705,
#   0.9657147345194039,
#   0.9650888810828996,
#   0.9651228948566226,
#   0.9664970513150344,
#   0.9666164087391899,
#   0.9678000880647524,
#   0.9669577833409194,
#   0.9674729374047615,
#   0.9674982931269913,
#   0.9686306425758445,
#   0.9686448665175833,
#   0.9677629821297817,
#   0.9677258761948111,
#   0.9689664512873286,
#   0.9682094902139281,
#   0.969592304723833,
#   0.9691909421939008],
#  'test_loss': [0.06776136624658564,
#   0.06643406812337078,
#   0.06606043130609164,
#   0.06508877667683093,
#   0.06439061051710847,
#   0.06394916237218157,
#   0.06364065653378599,
#   0.06287971793025711,
#   0.0620876934035914,
#   0.0613259217786518,
#   0.060689463988660874,
#   0.06072832337384832,
#   0.059693900006254394,
#   0.05905974426007808,
#   0.0589961399374244,
#   0.05845872038299355,
#   0.05761962878217508,
#   0.057522642870158465,
#   0.05689512291464119,
#   0.056029956602962394],
#  'test_acc': [0.9835795454545454,
#   0.9839772727272728,
#   0.9833522727272728,
#   0.9840340909090909,
#   0.9842045454545455,
#   0.9846590909090909,
#   0.9839772727272728,
#   0.9844318181818181,
#   0.9843181818181819,
#   0.9848863636363636,
#   0.9847159090909091,
#   0.9851704545454546,
#   0.9852272727272727,
#   0.9851704545454546,
#   0.9852272727272727,
#   0.9847159090909091,
#   0.9853409090909091,
#   0.9851704545454546,
#   0.9856818181818182,
#   0.9858522727272727]}

# %%
#####################################################################
model_filename = "/kaggle/working/vt16_model_state_dict_50.pth"

torch.save(model.state_dict(), model_filename)
print("Model state dictionary exported successfully to", model_filename)
#####################################################################
# Out:
# Model state dictionary exported successfully to /kaggle/working/vt16_model_state_dict_50.pth
