# %% [markdown]
# ### Importing all libraries

# %%
import torch, torchvision, torchmetrics
from torchmetrics import ConfusionMatrix
from torch import nn
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import requests
from sklearn.model_selection import train_test_split
from torchmetrics import Accuracy
from torchvision import transforms
from torchvision import models
from torchvision import datasets
from torchvision.transforms import ToTensor
from torch.utils.data import DataLoader
from torchinfo import summary
from timeit import default_timer as timer
from pathlib import Path
from tqdm.auto import tqdm
from torchmetrics import ConfusionMatrix
from mlxtend.plotting import plot_confusion_matrix
import random
from PIL import Image
import os
import torchinfo
from torchvision.datasets import ImageFolder
import albumentations as A
from typing import Dict, List
import seaborn as sns
import torch.optim.lr_scheduler as lr_scheduler
print("All packages imported!")
# Out:
# All packages imported!

# %%
# GPU information
# !nvidia-smi
# Out:
# Tue Apr 23 04:44:07 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.129.03             Driver Version: 535.129.03   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   33C    P8               9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
# |   1  Tesla T4                       Off | 00000000:00:05.0 Off |                    0 |
# | N/A   34C    P8               9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |  No running processes found                                                           |
# +---------------------------------------------------------------------------------------+

# %%
device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')
device
# Out:
# device(type='cuda')

# %% [markdown]
# ### Importing data from our folder

# %%
# Setup path tod data folder
dataset_dir = Path("../input/new-plant-diseases-dataset/New Plant Diseases Dataset(Augmented)/New Plant Diseases Dataset(Augmented)/")

# chek if path exists
if dataset_dir.is_dir():
    print("Dataset directory exists\n")
else:
    print("Dataset directory doesnt exist\n")

file_list = list(dataset_dir.glob("*"))
print("Files in the dataset directory")
for file_path in file_list:
    print(file_path.name)
# Out:
# Dataset directory exists
#
# Files in the dataset directory
# valid
# train

# %% [markdown]
# ### Defining training and testing directories

# %%
train_dir = dataset_dir / "train"
test_dir = dataset_dir / "valid"
train_dir, test_dir
# Out:
# (PosixPath('../input/new-plant-diseases-dataset/New Plant Diseases Dataset(Augmented)/New Plant Diseases Dataset(Augmented)/train'),
#  PosixPath('../input/new-plant-diseases-dataset/New Plant Diseases Dataset(Augmented)/New Plant Diseases Dataset(Augmented)/valid'))

# %%
data ='../input/new-plant-diseases-dataset/'
os.listdir(data)
# Out:
# ['New Plant Diseases Dataset(Augmented)',
#  'new plant diseases dataset(augmented)',
#  'test']

# %% [markdown]
# ### Coverting our train and test directories into datasets

# %%
from albumentations.pytorch import ToTensorV2

# %%
# Custom dataset class with Albumentations transformations
class CustomDataset(torch.utils.data.Dataset):
    def __init__(self, root_dir, transform=None):
        self.root_dir = root_dir
        self.transform = transform
        self.images = []
        self.labels = []
        self.class_names = []  # Store class names
        
        # Iterate through each class folder
        for label, class_name in enumerate(os.listdir(root_dir)):
            class_dir = os.path.join(root_dir, class_name)
            if os.path.isdir(class_dir):
                self.class_names.append(class_name)  # Append class name
                # Iterate through each image in the class folder
                for image_name in os.listdir(class_dir):
                    image_path = os.path.join(class_dir, image_name)
                    self.images.append(image_path)
                    self.labels.append(label)
    
    def __len__(self):
        return len(self.images)
    
    def __getitem__(self, idx):
        image_path = self.images[idx]
        label = self.labels[idx]
        image = Image.open(image_path).convert('RGB')
        
        if self.transform:
            transformed = self.transform(image=np.array(image))
            image = transformed['image']
        
        return image, label, self.class_names[label]

# Define additional transformations
additional_transforms = A.Compose([
    A.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.2, p=0.5),
    A.Blur(blur_limit=3, p=0.2),
    A.ElasticTransform(alpha=120, sigma=120 * 0.05, alpha_affine=120 * 0.03, p=0.2),
    A.GridDistortion(p=0.2),
])

# Define transformations using Albumentations for training data
train_transform = A.Compose([
    A.RandomResizedCrop(width=256, height=256, scale=(0.8, 1.0)),
    A.HorizontalFlip(p=0.5),
    A.Rotate(limit=30),
    A.RandomBrightnessContrast(p=0.2),
    A.RandomGamma(p=0.2),
    A.GaussNoise(p=0.2),
    additional_transforms,  # Add the new transformations here
    A.Normalize(mean=(0.46738179, 0.46738179, 0.46738179), std=(0.19342914, 0.19342914, 0.19342914)),
    A.pytorch.ToTensorV2(),
])

# Define transformations for validation/test data (no augmentation)
val_transform = A.Compose([
    A.Normalize(mean=(0.46738179, 0.46738179, 0.46738179), std=(0.19342914, 0.19342914, 0.19342914)),
    A.pytorch.ToTensorV2(),  # Convert the image to PyTorch tensor without augmentation
])

# Create custom datasets
train_data = CustomDataset(root_dir=train_dir, transform=train_transform)
test_data = CustomDataset(root_dir=test_dir, transform=val_transform)

# %%
class_names = train_data.class_names
class_names
# Out:
# ['Tomato___Late_blight',
#  'Tomato___healthy',
#  'Grape___healthy',
#  'Orange___Haunglongbing_(Citrus_greening)',
#  'Soybean___healthy',
#  'Squash___Powdery_mildew',
#  'Potato___healthy',
#  'Corn_(maize)___Northern_Leaf_Blight',
#  'Tomato___Early_blight',
#  'Tomato___Septoria_leaf_spot',
#  'Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot',
#  'Strawberry___Leaf_scorch',
#  'Peach___healthy',
#  'Apple___Apple_scab',
#  'Tomato___Tomato_Yellow_Leaf_Curl_Virus',
#  'Tomato___Bacterial_spot',
#  'Apple___Black_rot',
#  'Blueberry___healthy',
#  'Cherry_(including_sour)___Powdery_mildew',
#  'Peach___Bacterial_spot',
#  'Apple___Cedar_apple_rust',
#  'Tomato___Target_Spot',
#  'Pepper,_bell___healthy',
#  'Grape___Leaf_blight_(Isariopsis_Leaf_Spot)',
#  'Potato___Late_blight',
#  'Tomato___Tomato_mosaic_virus',
#  'Strawberry___healthy',
#  'Apple___healthy',
#  'Grape___Black_rot',
#  'Potato___Early_blight',
#  'Cherry_(including_sour)___healthy',
#  'Corn_(maize)___Common_rust_',
#  'Grape___Esca_(Black_Measles)',
#  'Raspberry___healthy',
#  'Tomato___Leaf_Mold',
#  'Tomato___Spider_mites Two-spotted_spider_mite',
#  'Pepper,_bell___Bacterial_spot',
#  'Corn_(maize)___healthy']

# %%
# Create a dictionary to store class-to-index mapping
class_to_idx = {}

# Assign consecutive indices starting from 0
for idx, class_name in enumerate(class_names):
    class_to_idx[class_name] = idx

# Now you can use the class-to-index mapping
print(class_to_idx)
# Out:
# {'Tomato___Late_blight': 0, 'Tomato___healthy': 1, 'Grape___healthy': 2, 'Orange___Haunglongbing_(Citrus_greening)': 3, 'Soybean___healthy': 4, 'Squash___Powdery_mildew': 5, 'Potato___healthy': 6, 'Corn_(maize)___Northern_Leaf_Blight': 7, 'Tomato___Early_blight': 8, 'Tomato___Septoria_leaf_spot': 9, 'Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot': 10, 'Strawberry___Leaf_scorch': 11, 'Peach___healthy': 12, 'Apple___Apple_scab': 13, 'Tomato___Tomato_Yellow_Leaf_Curl_Virus': 14, 'Tomato___Bacterial_spot': 15, 'Apple___Black_rot': 16, 'Blueberry___healthy': 17, 'Cherry_(including_sour)___Powdery_mildew': 18, 'Peach___Bacterial_spot': 19, 'Apple___Cedar_apple_rust': 20, 'Tomato___Target_Spot': 21, 'Pepper,_bell___healthy': 22, 'Grape___Leaf_blight_(Isariopsis_Leaf_Spot)': 23, 'Potato___Late_blight': 24, 'Tomato___Tomato_mosaic_virus': 25, 'Strawberry___healthy': 26, 'Apple___healthy': 27, 'Grape___Black_rot': 28, 'Potato___Early_blight': 29, 'Cherry_(including_sour)___healthy': 30, 'Corn_(maize)___Common_rust_': 31, 'Grape___Esca_(Black_Measles)': 32, 'Raspberry___healthy': 33, 'Tomato___Leaf_Mold': 34, 'Tomato___Spider_mites Two-spotted_spider_mite': 35, 'Pepper,_bell___Bacterial_spot': 36, 'Corn_(maize)___healthy': 37}

# %%
print(f"Length of train_data: {len(train_data)}\nLength of test_data : {len(test_data)}")
# Out:
# Length of train_data: 70295
# Length of test_data : 17572

# %%
# Number of cores available on the device
os.cpu_count()
# Out:
# 4

# %% [markdown]
# ### Creating train and test dataloaders

# %%
# Setup BATCH_SIZE hyper-parameter
BATCH_SIZE = 32
train_dataloader = DataLoader(dataset = train_data,
                             batch_size = BATCH_SIZE,
                             num_workers = 2,
                             shuffle=True)
test_dataloader = DataLoader(dataset = test_data,
                             batch_size = BATCH_SIZE,
                             num_workers = 2,
                             shuffle=False)

train_dataloader, test_dataloader
# Out:
# (<torch.utils.data.dataloader.DataLoader at 0x7b1b9748e710>,
#  <torch.utils.data.dataloader.DataLoader at 0x7b1b9748cc40>)

# %%
print(next(iter(train_dataloader))[0].device)
print(next(iter(test_dataloader))[0].device)
# Out:
# cpu
# cpu

# %%
print(f"Number of train batches: {len(train_dataloader)}\nNumber of test batches : {len(test_dataloader)}")
# Out:
# Number of train batches: 2197
# Number of test batches : 550

# %%
# img, label = next(iter(train_dataloader))

# # Batch size will now be 1, you can change the batch size if you like
# print(f"Image shape: {img.shape} -> [Batch size, color channels, height, width]")
# print(f"Label shape: {label.shape}")

# %% [markdown]
# ### Defining a simple model

# %%
# setting up device agnostic code
torch.manual_seed(42)
torch.cuda.manual_seed(42)

model = models.densenet161(weights=models.DenseNet161_Weights.IMAGENET1K_V1)
# Out:
# Downloading: "https://download.pytorch.org/models/densenet161-8d451a50.pth" to /root/.cache/torch/hub/checkpoints/densenet161-8d451a50.pth
# 100%|██████████| 110M/110M [00:00<00:00, 156MB/s]

# %%
model
# Out:
# DenseNet(
#   (features): Sequential(
#     (conv0): Conv2d(3, 96, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (norm0): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu0): ReLU(inplace=True)
#     (pool0): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (denseblock1): _DenseBlock(
#       (denselayer1): _DenseLayer(
#         (norm1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(96, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer2): _DenseLayer(
#         (norm1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(144, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer3): _DenseLayer(
#         (norm1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(192, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer4): _DenseLayer(
#         (norm1): BatchNorm2d(240, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(240, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer5): _DenseLayer(
#         (norm1): BatchNorm2d(288, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(288, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer6): _DenseLayer(
#         (norm1): BatchNorm2d(336, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(336, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (transition1): _Transition(
#       (norm): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv): Conv2d(384, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (pool): AvgPool2d(kernel_size=2, stride=2, padding=0)
#     )
#     (denseblock2): _DenseBlock(
#       (denselayer1): _DenseLayer(
#         (norm1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(192, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer2): _DenseLayer(
#         (norm1): BatchNorm2d(240, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(240, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer3): _DenseLayer(
#         (norm1): BatchNorm2d(288, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(288, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer4): _DenseLayer(
#         (norm1): BatchNorm2d(336, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(336, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer5): _DenseLayer(
#         (norm1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(384, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer6): _DenseLayer(
#         (norm1): BatchNorm2d(432, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(432, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer7): _DenseLayer(
#         (norm1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(480, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer8): _DenseLayer(
#         (norm1): BatchNorm2d(528, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(528, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer9): _DenseLayer(
#         (norm1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(576, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer10): _DenseLayer(
#         (norm1): BatchNorm2d(624, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(624, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer11): _DenseLayer(
#         (norm1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(672, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer12): _DenseLayer(
#         (norm1): BatchNorm2d(720, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(720, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (transition2): _Transition(
#       (norm): BatchNorm2d(768, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv): Conv2d(768, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (pool): AvgPool2d(kernel_size=2, stride=2, padding=0)
#     )
#     (denseblock3): _DenseBlock(
#       (denselayer1): _DenseLayer(
#         (norm1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(384, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer2): _DenseLayer(
#         (norm1): BatchNorm2d(432, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(432, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer3): _DenseLayer(
#         (norm1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(480, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer4): _DenseLayer(
#         (norm1): BatchNorm2d(528, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(528, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer5): _DenseLayer(
#         (norm1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(576, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer6): _DenseLayer(
#         (norm1): BatchNorm2d(624, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(624, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer7): _DenseLayer(
#         (norm1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(672, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer8): _DenseLayer(
#         (norm1): BatchNorm2d(720, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(720, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer9): _DenseLayer(
#         (norm1): BatchNorm2d(768, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer10): _DenseLayer(
#         (norm1): BatchNorm2d(816, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(816, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer11): _DenseLayer(
#         (norm1): BatchNorm2d(864, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(864, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer12): _DenseLayer(
#         (norm1): BatchNorm2d(912, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(912, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer13): _DenseLayer(
#         (norm1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(960, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer14): _DenseLayer(
#         (norm1): BatchNorm2d(1008, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1008, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer15): _DenseLayer(
#         (norm1): BatchNorm2d(1056, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1056, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer16): _DenseLayer(
#         (norm1): BatchNorm2d(1104, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1104, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer17): _DenseLayer(
#         (norm1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1152, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer18): _DenseLayer(
#         (norm1): BatchNorm2d(1200, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1200, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer19): _DenseLayer(
#         (norm1): BatchNorm2d(1248, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1248, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer20): _DenseLayer(
#         (norm1): BatchNorm2d(1296, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1296, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer21): _DenseLayer(
#         (norm1): BatchNorm2d(1344, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1344, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer22): _DenseLayer(
#         (norm1): BatchNorm2d(1392, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1392, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer23): _DenseLayer(
#         (norm1): BatchNorm2d(1440, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1440, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer24): _DenseLayer(
#         (norm1): BatchNorm2d(1488, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1488, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer25): _DenseLayer(
#         (norm1): BatchNorm2d(1536, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1536, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer26): _DenseLayer(
#         (norm1): BatchNorm2d(1584, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1584, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer27): _DenseLayer(
#         (norm1): BatchNorm2d(1632, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1632, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer28): _DenseLayer(
#         (norm1): BatchNorm2d(1680, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1680, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer29): _DenseLayer(
#         (norm1): BatchNorm2d(1728, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1728, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer30): _DenseLayer(
#         (norm1): BatchNorm2d(1776, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1776, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer31): _DenseLayer(
#         (norm1): BatchNorm2d(1824, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1824, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer32): _DenseLayer(
#         (norm1): BatchNorm2d(1872, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1872, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer33): _DenseLayer(
#         (norm1): BatchNorm2d(1920, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1920, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer34): _DenseLayer(
#         (norm1): BatchNorm2d(1968, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1968, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer35): _DenseLayer(
#         (norm1): BatchNorm2d(2016, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(2016, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer36): _DenseLayer(
#         (norm1): BatchNorm2d(2064, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(2064, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (transition3): _Transition(
#       (norm): BatchNorm2d(2112, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv): Conv2d(2112, 1056, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (pool): AvgPool2d(kernel_size=2, stride=2, padding=0)
#     )
#     (denseblock4): _DenseBlock(
#       (denselayer1): _DenseLayer(
#         (norm1): BatchNorm2d(1056, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1056, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer2): _DenseLayer(
#         (norm1): BatchNorm2d(1104, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1104, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer3): _DenseLayer(
#         (norm1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1152, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer4): _DenseLayer(
#         (norm1): BatchNorm2d(1200, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1200, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer5): _DenseLayer(
#         (norm1): BatchNorm2d(1248, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1248, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer6): _DenseLayer(
#         (norm1): BatchNorm2d(1296, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1296, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer7): _DenseLayer(
#         (norm1): BatchNorm2d(1344, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1344, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer8): _DenseLayer(
#         (norm1): BatchNorm2d(1392, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1392, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer9): _DenseLayer(
#         (norm1): BatchNorm2d(1440, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1440, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer10): _DenseLayer(
#         (norm1): BatchNorm2d(1488, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1488, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer11): _DenseLayer(
#         (norm1): BatchNorm2d(1536, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1536, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer12): _DenseLayer(
#         (norm1): BatchNorm2d(1584, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1584, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer13): _DenseLayer(
#         (norm1): BatchNorm2d(1632, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1632, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer14): _DenseLayer(
#         (norm1): BatchNorm2d(1680, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1680, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer15): _DenseLayer(
#         (norm1): BatchNorm2d(1728, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1728, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer16): _DenseLayer(
#         (norm1): BatchNorm2d(1776, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1776, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer17): _DenseLayer(
#         (norm1): BatchNorm2d(1824, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1824, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer18): _DenseLayer(
#         (norm1): BatchNorm2d(1872, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1872, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer19): _DenseLayer(
#         (norm1): BatchNorm2d(1920, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1920, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer20): _DenseLayer(
#         (norm1): BatchNorm2d(1968, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(1968, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer21): _DenseLayer(
#         (norm1): BatchNorm2d(2016, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(2016, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer22): _DenseLayer(
#         (norm1): BatchNorm2d(2064, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(2064, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer23): _DenseLayer(
#         (norm1): BatchNorm2d(2112, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(2112, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#       (denselayer24): _DenseLayer(
#         (norm1): BatchNorm2d(2160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu1): ReLU(inplace=True)
#         (conv1): Conv2d(2160, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu2): ReLU(inplace=True)
#         (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       )
#     )
#     (norm5): BatchNorm2d(2208, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (classifier): Linear(in_features=2208, out_features=1000, bias=True)
# )

# %%
summary(model, [1,3,256,256])
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# DenseNet                                 [1, 1000]                 --
# ├─Sequential: 1-1                        [1, 2208, 8, 8]           --
# │    └─Conv2d: 2-1                       [1, 96, 128, 128]         14,112
# │    └─BatchNorm2d: 2-2                  [1, 96, 128, 128]         192
# │    └─ReLU: 2-3                         [1, 96, 128, 128]         --
# │    └─MaxPool2d: 2-4                    [1, 96, 64, 64]           --
# │    └─_DenseBlock: 2-5                  [1, 384, 64, 64]          --
# │    │    └─_DenseLayer: 3-1             [1, 48, 64, 64]           101,952
# │    │    └─_DenseLayer: 3-2             [1, 48, 64, 64]           111,264
# │    │    └─_DenseLayer: 3-3             [1, 48, 64, 64]           120,576
# │    │    └─_DenseLayer: 3-4             [1, 48, 64, 64]           129,888
# │    │    └─_DenseLayer: 3-5             [1, 48, 64, 64]           139,200
# │    │    └─_DenseLayer: 3-6             [1, 48, 64, 64]           148,512
# │    └─_Transition: 2-6                  [1, 192, 32, 32]          --
# │    │    └─BatchNorm2d: 3-7             [1, 384, 64, 64]          768
# │    │    └─ReLU: 3-8                    [1, 384, 64, 64]          --
# │    │    └─Conv2d: 3-9                  [1, 192, 64, 64]          73,728
# │    │    └─AvgPool2d: 3-10              [1, 192, 32, 32]          --
# │    └─_DenseBlock: 2-7                  [1, 768, 32, 32]          --
# │    │    └─_DenseLayer: 3-11            [1, 48, 32, 32]           120,576
# │    │    └─_DenseLayer: 3-12            [1, 48, 32, 32]           129,888
# │    │    └─_DenseLayer: 3-13            [1, 48, 32, 32]           139,200
# │    │    └─_DenseLayer: 3-14            [1, 48, 32, 32]           148,512
# │    │    └─_DenseLayer: 3-15            [1, 48, 32, 32]           157,824
# │    │    └─_DenseLayer: 3-16            [1, 48, 32, 32]           167,136
# │    │    └─_DenseLayer: 3-17            [1, 48, 32, 32]           176,448
# │    │    └─_DenseLayer: 3-18            [1, 48, 32, 32]           185,760
# │    │    └─_DenseLayer: 3-19            [1, 48, 32, 32]           195,072
# │    │    └─_DenseLayer: 3-20            [1, 48, 32, 32]           204,384
# │    │    └─_DenseLayer: 3-21            [1, 48, 32, 32]           213,696
# │    │    └─_DenseLayer: 3-22            [1, 48, 32, 32]           223,008
# │    └─_Transition: 2-8                  [1, 384, 16, 16]          --
# │    │    └─BatchNorm2d: 3-23            [1, 768, 32, 32]          1,536
# │    │    └─ReLU: 3-24                   [1, 768, 32, 32]          --
# │    │    └─Conv2d: 3-25                 [1, 384, 32, 32]          294,912
# │    │    └─AvgPool2d: 3-26              [1, 384, 16, 16]          --
# │    └─_DenseBlock: 2-9                  [1, 2112, 16, 16]         --
# │    │    └─_DenseLayer: 3-27            [1, 48, 16, 16]           157,824
# │    │    └─_DenseLayer: 3-28            [1, 48, 16, 16]           167,136
# │    │    └─_DenseLayer: 3-29            [1, 48, 16, 16]           176,448
# │    │    └─_DenseLayer: 3-30            [1, 48, 16, 16]           185,760
# │    │    └─_DenseLayer: 3-31            [1, 48, 16, 16]           195,072
# │    │    └─_DenseLayer: 3-32            [1, 48, 16, 16]           204,384
# │    │    └─_DenseLayer: 3-33            [1, 48, 16, 16]           213,696
# │    │    └─_DenseLayer: 3-34            [1, 48, 16, 16]           223,008
# │    │    └─_DenseLayer: 3-35            [1, 48, 16, 16]           232,320
# │    │    └─_DenseLayer: 3-36            [1, 48, 16, 16]           241,632
# │    │    └─_DenseLayer: 3-37            [1, 48, 16, 16]           250,944
# │    │    └─_DenseLayer: 3-38            [1, 48, 16, 16]           260,256
# │    │    └─_DenseLayer: 3-39            [1, 48, 16, 16]           269,568
# │    │    └─_DenseLayer: 3-40            [1, 48, 16, 16]           278,880
# │    │    └─_DenseLayer: 3-41            [1, 48, 16, 16]           288,192
# │    │    └─_DenseLayer: 3-42            [1, 48, 16, 16]           297,504
# │    │    └─_DenseLayer: 3-43            [1, 48, 16, 16]           306,816
# │    │    └─_DenseLayer: 3-44            [1, 48, 16, 16]           316,128
# │    │    └─_DenseLayer: 3-45            [1, 48, 16, 16]           325,440
# │    │    └─_DenseLayer: 3-46            [1, 48, 16, 16]           334,752
# │    │    └─_DenseLayer: 3-47            [1, 48, 16, 16]           344,064
# │    │    └─_DenseLayer: 3-48            [1, 48, 16, 16]           353,376
# │    │    └─_DenseLayer: 3-49            [1, 48, 16, 16]           362,688
# │    │    └─_DenseLayer: 3-50            [1, 48, 16, 16]           372,000
# │    │    └─_DenseLayer: 3-51            [1, 48, 16, 16]           381,312
# │    │    └─_DenseLayer: 3-52            [1, 48, 16, 16]           390,624
# │    │    └─_DenseLayer: 3-53            [1, 48, 16, 16]           399,936
# │    │    └─_DenseLayer: 3-54            [1, 48, 16, 16]           409,248
# │    │    └─_DenseLayer: 3-55            [1, 48, 16, 16]           418,560
# │    │    └─_DenseLayer: 3-56            [1, 48, 16, 16]           427,872
# │    │    └─_DenseLayer: 3-57            [1, 48, 16, 16]           437,184
# │    │    └─_DenseLayer: 3-58            [1, 48, 16, 16]           446,496
# │    │    └─_DenseLayer: 3-59            [1, 48, 16, 16]           455,808
# │    │    └─_DenseLayer: 3-60            [1, 48, 16, 16]           465,120
# │    │    └─_DenseLayer: 3-61            [1, 48, 16, 16]           474,432
# │    │    └─_DenseLayer: 3-62            [1, 48, 16, 16]           483,744
# │    └─_Transition: 2-10                 [1, 1056, 8, 8]           --
# │    │    └─BatchNorm2d: 3-63            [1, 2112, 16, 16]         4,224
# │    │    └─ReLU: 3-64                   [1, 2112, 16, 16]         --
# │    │    └─Conv2d: 3-65                 [1, 1056, 16, 16]         2,230,272
# │    │    └─AvgPool2d: 3-66              [1, 1056, 8, 8]           --
# │    └─_DenseBlock: 2-11                 [1, 2208, 8, 8]           --
# │    │    └─_DenseLayer: 3-67            [1, 48, 8, 8]             288,192
# │    │    └─_DenseLayer: 3-68            [1, 48, 8, 8]             297,504
# │    │    └─_DenseLayer: 3-69            [1, 48, 8, 8]             306,816
# │    │    └─_DenseLayer: 3-70            [1, 48, 8, 8]             316,128
# │    │    └─_DenseLayer: 3-71            [1, 48, 8, 8]             325,440
# │    │    └─_DenseLayer: 3-72            [1, 48, 8, 8]             334,752
# │    │    └─_DenseLayer: 3-73            [1, 48, 8, 8]             344,064
# │    │    └─_DenseLayer: 3-74            [1, 48, 8, 8]             353,376
# │    │    └─_DenseLayer: 3-75            [1, 48, 8, 8]             362,688
# │    │    └─_DenseLayer: 3-76            [1, 48, 8, 8]             372,000
# │    │    └─_DenseLayer: 3-77            [1, 48, 8, 8]             381,312
# │    │    └─_DenseLayer: 3-78            [1, 48, 8, 8]             390,624
# │    │    └─_DenseLayer: 3-79            [1, 48, 8, 8]             399,936
# │    │    └─_DenseLayer: 3-80            [1, 48, 8, 8]             409,248
# │    │    └─_DenseLayer: 3-81            [1, 48, 8, 8]             418,560
# │    │    └─_DenseLayer: 3-82            [1, 48, 8, 8]             427,872
# │    │    └─_DenseLayer: 3-83            [1, 48, 8, 8]             437,184
# │    │    └─_DenseLayer: 3-84            [1, 48, 8, 8]             446,496
# │    │    └─_DenseLayer: 3-85            [1, 48, 8, 8]             455,808
# │    │    └─_DenseLayer: 3-86            [1, 48, 8, 8]             465,120
# │    │    └─_DenseLayer: 3-87            [1, 48, 8, 8]             474,432
# │    │    └─_DenseLayer: 3-88            [1, 48, 8, 8]             483,744
# │    │    └─_DenseLayer: 3-89            [1, 48, 8, 8]             493,056
# │    │    └─_DenseLayer: 3-90            [1, 48, 8, 8]             502,368
# │    └─BatchNorm2d: 2-12                 [1, 2208, 8, 8]           4,416
# ├─Linear: 1-2                            [1, 1000]                 2,209,000
# ==========================================================================================
# Total params: 28,681,000
# Trainable params: 28,681,000
# Non-trainable params: 0
# Total mult-adds (G): 10.09
# ==========================================================================================
# Input size (MB): 0.79
# Forward/backward pass size (MB): 422.96
# Params size (MB): 114.72
# Estimated Total Size (MB): 538.47
# ==========================================================================================

# %%
# Freeze parameters of pre-trained layers to prevent overwriting during fine-tuning:
for param in model.parameters():
    param.requires_grad = False

# %%
# Replace the final classifier layer with a new one for your 38 classes:
num_classes = 38  # Adjust to your actual number of classes

# Create a new classifier module with appropriate input features:
model.classifier = nn.Sequential(
    nn.Linear(2208, num_classes),  # Ensure input features match model output
)

model = torch.nn.DataParallel(model, device_ids = [0,1]).to(device)

# %%
###############################################################################################
model_state_dict_path = "/kaggle/input/densenet75/densenet161_model_state_dict_75.pth"  # Adjust the filename if needed

# Check if the state dictionary file exists
if os.path.isfile(model_state_dict_path):
    print("Found state dictionary file:", model_state_dict_path)

    # Load the state dictionary
    try:
        model_state_dict = torch.load(model_state_dict_path)
        model.load_state_dict(model_state_dict)
        print("Loaded state dictionary successfully!")
    except Exception as e:
        print(f"Error loading state dictionary: {e}")
else:
    print("No state dictionary file found at", model_state_dict_path)
    
###############################################################################################
# Out:
# Found state dictionary file: /kaggle/input/densenet75/densenet161_model_state_dict_75.pth
# Loaded state dictionary successfully!

# %%
#model.module.classifier[6].in_features

# %%
loss_fn = torch.nn.CrossEntropyLoss()  # Common choice for multi-class classification
optimizer = torch.optim.SGD(model.parameters(), lr=0.001, momentum=0.9)  # Only optimize unfrozen layers, By default it will be requires_grad=True

# %%
model
# Out:
# DataParallel(
#   (module): DenseNet(
#     (features): Sequential(
#       (conv0): Conv2d(3, 96, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#       (norm0): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu0): ReLU(inplace=True)
#       (pool0): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#       (denseblock1): _DenseBlock(
#         (denselayer1): _DenseLayer(
#           (norm1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(96, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer2): _DenseLayer(
#           (norm1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(144, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer3): _DenseLayer(
#           (norm1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(192, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer4): _DenseLayer(
#           (norm1): BatchNorm2d(240, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(240, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer5): _DenseLayer(
#           (norm1): BatchNorm2d(288, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(288, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer6): _DenseLayer(
#           (norm1): BatchNorm2d(336, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(336, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#       )
#       (transition1): _Transition(
#         (norm): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv): Conv2d(384, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (pool): AvgPool2d(kernel_size=2, stride=2, padding=0)
#       )
#       (denseblock2): _DenseBlock(
#         (denselayer1): _DenseLayer(
#           (norm1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(192, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer2): _DenseLayer(
#           (norm1): BatchNorm2d(240, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(240, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer3): _DenseLayer(
#           (norm1): BatchNorm2d(288, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(288, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer4): _DenseLayer(
#           (norm1): BatchNorm2d(336, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(336, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer5): _DenseLayer(
#           (norm1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(384, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer6): _DenseLayer(
#           (norm1): BatchNorm2d(432, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(432, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer7): _DenseLayer(
#           (norm1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(480, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer8): _DenseLayer(
#           (norm1): BatchNorm2d(528, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(528, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer9): _DenseLayer(
#           (norm1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(576, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer10): _DenseLayer(
#           (norm1): BatchNorm2d(624, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(624, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer11): _DenseLayer(
#           (norm1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(672, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer12): _DenseLayer(
#           (norm1): BatchNorm2d(720, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(720, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#       )
#       (transition2): _Transition(
#         (norm): BatchNorm2d(768, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv): Conv2d(768, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (pool): AvgPool2d(kernel_size=2, stride=2, padding=0)
#       )
#       (denseblock3): _DenseBlock(
#         (denselayer1): _DenseLayer(
#           (norm1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(384, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer2): _DenseLayer(
#           (norm1): BatchNorm2d(432, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(432, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer3): _DenseLayer(
#           (norm1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(480, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer4): _DenseLayer(
#           (norm1): BatchNorm2d(528, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(528, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer5): _DenseLayer(
#           (norm1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(576, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer6): _DenseLayer(
#           (norm1): BatchNorm2d(624, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(624, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer7): _DenseLayer(
#           (norm1): BatchNorm2d(672, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(672, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer8): _DenseLayer(
#           (norm1): BatchNorm2d(720, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(720, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer9): _DenseLayer(
#           (norm1): BatchNorm2d(768, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer10): _DenseLayer(
#           (norm1): BatchNorm2d(816, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(816, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer11): _DenseLayer(
#           (norm1): BatchNorm2d(864, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(864, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer12): _DenseLayer(
#           (norm1): BatchNorm2d(912, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(912, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer13): _DenseLayer(
#           (norm1): BatchNorm2d(960, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(960, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer14): _DenseLayer(
#           (norm1): BatchNorm2d(1008, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(1008, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer15): _DenseLayer(
#           (norm1): BatchNorm2d(1056, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(1056, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer16): _DenseLayer(
#           (norm1): BatchNorm2d(1104, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(1104, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer17): _DenseLayer(
#           (norm1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(1152, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer18): _DenseLayer(
#           (norm1): BatchNorm2d(1200, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(1200, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer19): _DenseLayer(
#           (norm1): BatchNorm2d(1248, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(1248, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer20): _DenseLayer(
#           (norm1): BatchNorm2d(1296, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(1296, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer21): _DenseLayer(
#           (norm1): BatchNorm2d(1344, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(1344, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer22): _DenseLayer(
#           (norm1): BatchNorm2d(1392, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(1392, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer23): _DenseLayer(
#           (norm1): BatchNorm2d(1440, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(1440, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer24): _DenseLayer(
#           (norm1): BatchNorm2d(1488, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(1488, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer25): _DenseLayer(
#           (norm1): BatchNorm2d(1536, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(1536, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer26): _DenseLayer(
#           (norm1): BatchNorm2d(1584, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(1584, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer27): _DenseLayer(
#           (norm1): BatchNorm2d(1632, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(1632, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer28): _DenseLayer(
#           (norm1): BatchNorm2d(1680, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(1680, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer29): _DenseLayer(
#           (norm1): BatchNorm2d(1728, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(1728, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer30): _DenseLayer(
#           (norm1): BatchNorm2d(1776, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(1776, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer31): _DenseLayer(
#           (norm1): BatchNorm2d(1824, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(1824, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer32): _DenseLayer(
#           (norm1): BatchNorm2d(1872, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(1872, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer33): _DenseLayer(
#           (norm1): BatchNorm2d(1920, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(1920, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer34): _DenseLayer(
#           (norm1): BatchNorm2d(1968, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(1968, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer35): _DenseLayer(
#           (norm1): BatchNorm2d(2016, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(2016, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer36): _DenseLayer(
#           (norm1): BatchNorm2d(2064, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(2064, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#       )
#       (transition3): _Transition(
#         (norm): BatchNorm2d(2112, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv): Conv2d(2112, 1056, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (pool): AvgPool2d(kernel_size=2, stride=2, padding=0)
#       )
#       (denseblock4): _DenseBlock(
#         (denselayer1): _DenseLayer(
#           (norm1): BatchNorm2d(1056, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(1056, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer2): _DenseLayer(
#           (norm1): BatchNorm2d(1104, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(1104, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer3): _DenseLayer(
#           (norm1): BatchNorm2d(1152, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(1152, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer4): _DenseLayer(
#           (norm1): BatchNorm2d(1200, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(1200, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer5): _DenseLayer(
#           (norm1): BatchNorm2d(1248, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(1248, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer6): _DenseLayer(
#           (norm1): BatchNorm2d(1296, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(1296, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer7): _DenseLayer(
#           (norm1): BatchNorm2d(1344, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(1344, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer8): _DenseLayer(
#           (norm1): BatchNorm2d(1392, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(1392, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer9): _DenseLayer(
#           (norm1): BatchNorm2d(1440, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(1440, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer10): _DenseLayer(
#           (norm1): BatchNorm2d(1488, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(1488, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer11): _DenseLayer(
#           (norm1): BatchNorm2d(1536, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(1536, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer12): _DenseLayer(
#           (norm1): BatchNorm2d(1584, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(1584, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer13): _DenseLayer(
#           (norm1): BatchNorm2d(1632, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(1632, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer14): _DenseLayer(
#           (norm1): BatchNorm2d(1680, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(1680, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer15): _DenseLayer(
#           (norm1): BatchNorm2d(1728, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(1728, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer16): _DenseLayer(
#           (norm1): BatchNorm2d(1776, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(1776, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer17): _DenseLayer(
#           (norm1): BatchNorm2d(1824, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(1824, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer18): _DenseLayer(
#           (norm1): BatchNorm2d(1872, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(1872, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer19): _DenseLayer(
#           (norm1): BatchNorm2d(1920, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(1920, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer20): _DenseLayer(
#           (norm1): BatchNorm2d(1968, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(1968, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer21): _DenseLayer(
#           (norm1): BatchNorm2d(2016, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(2016, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer22): _DenseLayer(
#           (norm1): BatchNorm2d(2064, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(2064, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer23): _DenseLayer(
#           (norm1): BatchNorm2d(2112, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(2112, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#         (denselayer24): _DenseLayer(
#           (norm1): BatchNorm2d(2160, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu1): ReLU(inplace=True)
#           (conv1): Conv2d(2160, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (norm2): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#           (relu2): ReLU(inplace=True)
#           (conv2): Conv2d(192, 48, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         )
#       )
#       (norm5): BatchNorm2d(2208, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (classifier): Sequential(
#       (0): Linear(in_features=2208, out_features=38, bias=True)
#     )
#   )
# )

# %%
summary(model, [1,3,256,256])
# Out:
# ===============================================================================================
# Layer (type:depth-idx)                        Output Shape              Param #
# ===============================================================================================
# DataParallel                                  [1, 38]                   --
# ├─DenseNet: 1-1                               [1, 38]                   26,555,942
# ├─DenseNet: 1-2                               --                        --
# │    └─Sequential: 2-1                        [1, 2208, 8, 8]           26,472,000
# │    └─Sequential: 2-2                        --                        --
# │    │    └─Conv2d: 3-1                       [1, 96, 128, 128]         (14,112)
# │    │    └─BatchNorm2d: 3-2                  [1, 96, 128, 128]         (192)
# │    │    └─ReLU: 3-3                         [1, 96, 128, 128]         --
# │    │    └─MaxPool2d: 3-4                    [1, 96, 64, 64]           --
# │    │    └─_DenseBlock: 3-5                  [1, 384, 64, 64]          (751,392)
# │    │    └─_DenseBlock: 3-6                  --                        (751,392)
# │    │    └─_Transition: 3-7                  [1, 192, 32, 32]          (74,496)
# │    │    └─_Transition: 3-8                  --                        (74,496)
# │    │    └─_DenseBlock: 3-9                  [1, 768, 32, 32]          (2,061,504)
# │    │    └─_DenseBlock: 3-10                 --                        (2,061,504)
# │    │    └─_Transition: 3-11                 [1, 384, 16, 16]          (296,448)
# │    │    └─_Transition: 3-12                 --                        (296,448)
# │    │    └─_DenseBlock: 3-13                 [1, 2112, 16, 16]         (11,548,224)
# │    │    └─_DenseBlock: 3-14                 --                        (11,548,224)
# │    │    └─_Transition: 3-15                 [1, 1056, 8, 8]           (2,234,496)
# │    │    └─_Transition: 3-16                 --                        (2,234,496)
# │    │    └─_DenseBlock: 3-17                 [1, 2208, 8, 8]           (9,486,720)
# │    │    └─_DenseBlock: 3-18                 --                        (9,486,720)
# │    │    └─BatchNorm2d: 3-19                 [1, 2208, 8, 8]           (4,416)
# │    └─Sequential: 2-3                        [1, 38]                   83,942
# │    └─Sequential: 2-4                        --                        --
# │    │    └─Linear: 3-20                      [1, 38]                   83,942
# ===============================================================================================
# Total params: 129,968,946
# Trainable params: 251,826
# Non-trainable params: 129,717,120
# Total mult-adds (G): 10.09
# ===============================================================================================
# Input size (MB): 0.79
# Forward/backward pass size (MB): 422.95
# Params size (MB): 106.22
# Estimated Total Size (MB): 529.96
# ===============================================================================================

# %%
def check_requires_grad(model):
  """
  This function iterates through the model and prints information
  about requires_grad for each module and its parameters.
  """
  for name, param in model.named_parameters():
    if param.requires_grad:
      print(f"{name}: requires_grad=True")
    else:
      print(f"{name}: requires_grad=False")

# Example usage
check_requires_grad(model)
# Out:
# module.features.conv0.weight: requires_grad=False
# module.features.norm0.weight: requires_grad=False
# module.features.norm0.bias: requires_grad=False
# module.features.denseblock1.denselayer1.norm1.weight: requires_grad=False
# module.features.denseblock1.denselayer1.norm1.bias: requires_grad=False
# module.features.denseblock1.denselayer1.conv1.weight: requires_grad=False
# module.features.denseblock1.denselayer1.norm2.weight: requires_grad=False
# module.features.denseblock1.denselayer1.norm2.bias: requires_grad=False
# module.features.denseblock1.denselayer1.conv2.weight: requires_grad=False
# module.features.denseblock1.denselayer2.norm1.weight: requires_grad=False
# module.features.denseblock1.denselayer2.norm1.bias: requires_grad=False
# module.features.denseblock1.denselayer2.conv1.weight: requires_grad=False
# module.features.denseblock1.denselayer2.norm2.weight: requires_grad=False
# module.features.denseblock1.denselayer2.norm2.bias: requires_grad=False
# module.features.denseblock1.denselayer2.conv2.weight: requires_grad=False
# module.features.denseblock1.denselayer3.norm1.weight: requires_grad=False
# module.features.denseblock1.denselayer3.norm1.bias: requires_grad=False
# module.features.denseblock1.denselayer3.conv1.weight: requires_grad=False
# module.features.denseblock1.denselayer3.norm2.weight: requires_grad=False
# module.features.denseblock1.denselayer3.norm2.bias: requires_grad=False
# module.features.denseblock1.denselayer3.conv2.weight: requires_grad=False
# module.features.denseblock1.denselayer4.norm1.weight: requires_grad=False
# module.features.denseblock1.denselayer4.norm1.bias: requires_grad=False
# module.features.denseblock1.denselayer4.conv1.weight: requires_grad=False
# module.features.denseblock1.denselayer4.norm2.weight: requires_grad=False
# module.features.denseblock1.denselayer4.norm2.bias: requires_grad=False
# module.features.denseblock1.denselayer4.conv2.weight: requires_grad=False
# module.features.denseblock1.denselayer5.norm1.weight: requires_grad=False
# module.features.denseblock1.denselayer5.norm1.bias: requires_grad=False
# module.features.denseblock1.denselayer5.conv1.weight: requires_grad=False
# module.features.denseblock1.denselayer5.norm2.weight: requires_grad=False
# module.features.denseblock1.denselayer5.norm2.bias: requires_grad=False
# module.features.denseblock1.denselayer5.conv2.weight: requires_grad=False
# module.features.denseblock1.denselayer6.norm1.weight: requires_grad=False
# module.features.denseblock1.denselayer6.norm1.bias: requires_grad=False
# module.features.denseblock1.denselayer6.conv1.weight: requires_grad=False
# module.features.denseblock1.denselayer6.norm2.weight: requires_grad=False
# module.features.denseblock1.denselayer6.norm2.bias: requires_grad=False
# module.features.denseblock1.denselayer6.conv2.weight: requires_grad=False
# module.features.transition1.norm.weight: requires_grad=False
# module.features.transition1.norm.bias: requires_grad=False
# module.features.transition1.conv.weight: requires_grad=False
# module.features.denseblock2.denselayer1.norm1.weight: requires_grad=False
# module.features.denseblock2.denselayer1.norm1.bias: requires_grad=False
# module.features.denseblock2.denselayer1.conv1.weight: requires_grad=False
# module.features.denseblock2.denselayer1.norm2.weight: requires_grad=False
# module.features.denseblock2.denselayer1.norm2.bias: requires_grad=False
# module.features.denseblock2.denselayer1.conv2.weight: requires_grad=False
# module.features.denseblock2.denselayer2.norm1.weight: requires_grad=False
# module.features.denseblock2.denselayer2.norm1.bias: requires_grad=False
# module.features.denseblock2.denselayer2.conv1.weight: requires_grad=False
# module.features.denseblock2.denselayer2.norm2.weight: requires_grad=False
# module.features.denseblock2.denselayer2.norm2.bias: requires_grad=False
# module.features.denseblock2.denselayer2.conv2.weight: requires_grad=False
# module.features.denseblock2.denselayer3.norm1.weight: requires_grad=False
# module.features.denseblock2.denselayer3.norm1.bias: requires_grad=False
# module.features.denseblock2.denselayer3.conv1.weight: requires_grad=False
# module.features.denseblock2.denselayer3.norm2.weight: requires_grad=False
# module.features.denseblock2.denselayer3.norm2.bias: requires_grad=False
# module.features.denseblock2.denselayer3.conv2.weight: requires_grad=False
# module.features.denseblock2.denselayer4.norm1.weight: requires_grad=False
# module.features.denseblock2.denselayer4.norm1.bias: requires_grad=False
# module.features.denseblock2.denselayer4.conv1.weight: requires_grad=False
# module.features.denseblock2.denselayer4.norm2.weight: requires_grad=False
# module.features.denseblock2.denselayer4.norm2.bias: requires_grad=False
# module.features.denseblock2.denselayer4.conv2.weight: requires_grad=False
# module.features.denseblock2.denselayer5.norm1.weight: requires_grad=False
# module.features.denseblock2.denselayer5.norm1.bias: requires_grad=False
# module.features.denseblock2.denselayer5.conv1.weight: requires_grad=False
# module.features.denseblock2.denselayer5.norm2.weight: requires_grad=False
# module.features.denseblock2.denselayer5.norm2.bias: requires_grad=False
# module.features.denseblock2.denselayer5.conv2.weight: requires_grad=False
# module.features.denseblock2.denselayer6.norm1.weight: requires_grad=False
# module.features.denseblock2.denselayer6.norm1.bias: requires_grad=False
# module.features.denseblock2.denselayer6.conv1.weight: requires_grad=False
# module.features.denseblock2.denselayer6.norm2.weight: requires_grad=False
# module.features.denseblock2.denselayer6.norm2.bias: requires_grad=False
# module.features.denseblock2.denselayer6.conv2.weight: requires_grad=False
# module.features.denseblock2.denselayer7.norm1.weight: requires_grad=False
# module.features.denseblock2.denselayer7.norm1.bias: requires_grad=False
# module.features.denseblock2.denselayer7.conv1.weight: requires_grad=False
# module.features.denseblock2.denselayer7.norm2.weight: requires_grad=False
# module.features.denseblock2.denselayer7.norm2.bias: requires_grad=False
# module.features.denseblock2.denselayer7.conv2.weight: requires_grad=False
# module.features.denseblock2.denselayer8.norm1.weight: requires_grad=False
# module.features.denseblock2.denselayer8.norm1.bias: requires_grad=False
# module.features.denseblock2.denselayer8.conv1.weight: requires_grad=False
# module.features.denseblock2.denselayer8.norm2.weight: requires_grad=False
# module.features.denseblock2.denselayer8.norm2.bias: requires_grad=False
# module.features.denseblock2.denselayer8.conv2.weight: requires_grad=False
# module.features.denseblock2.denselayer9.norm1.weight: requires_grad=False
# module.features.denseblock2.denselayer9.norm1.bias: requires_grad=False
# module.features.denseblock2.denselayer9.conv1.weight: requires_grad=False
# module.features.denseblock2.denselayer9.norm2.weight: requires_grad=False
# module.features.denseblock2.denselayer9.norm2.bias: requires_grad=False
# module.features.denseblock2.denselayer9.conv2.weight: requires_grad=False
# module.features.denseblock2.denselayer10.norm1.weight: requires_grad=False
# module.features.denseblock2.denselayer10.norm1.bias: requires_grad=False
# module.features.denseblock2.denselayer10.conv1.weight: requires_grad=False
# module.features.denseblock2.denselayer10.norm2.weight: requires_grad=False
# module.features.denseblock2.denselayer10.norm2.bias: requires_grad=False
# module.features.denseblock2.denselayer10.conv2.weight: requires_grad=False
# module.features.denseblock2.denselayer11.norm1.weight: requires_grad=False
# module.features.denseblock2.denselayer11.norm1.bias: requires_grad=False
# module.features.denseblock2.denselayer11.conv1.weight: requires_grad=False
# module.features.denseblock2.denselayer11.norm2.weight: requires_grad=False
# module.features.denseblock2.denselayer11.norm2.bias: requires_grad=False
# module.features.denseblock2.denselayer11.conv2.weight: requires_grad=False
# module.features.denseblock2.denselayer12.norm1.weight: requires_grad=False
# module.features.denseblock2.denselayer12.norm1.bias: requires_grad=False
# module.features.denseblock2.denselayer12.conv1.weight: requires_grad=False
# module.features.denseblock2.denselayer12.norm2.weight: requires_grad=False
# module.features.denseblock2.denselayer12.norm2.bias: requires_grad=False
# module.features.denseblock2.denselayer12.conv2.weight: requires_grad=False
# module.features.transition2.norm.weight: requires_grad=False
# module.features.transition2.norm.bias: requires_grad=False
# module.features.transition2.conv.weight: requires_grad=False
# module.features.denseblock3.denselayer1.norm1.weight: requires_grad=False
# module.features.denseblock3.denselayer1.norm1.bias: requires_grad=False
# module.features.denseblock3.denselayer1.conv1.weight: requires_grad=False
# module.features.denseblock3.denselayer1.norm2.weight: requires_grad=False
# module.features.denseblock3.denselayer1.norm2.bias: requires_grad=False
# module.features.denseblock3.denselayer1.conv2.weight: requires_grad=False
# module.features.denseblock3.denselayer2.norm1.weight: requires_grad=False
# module.features.denseblock3.denselayer2.norm1.bias: requires_grad=False
# module.features.denseblock3.denselayer2.conv1.weight: requires_grad=False
# module.features.denseblock3.denselayer2.norm2.weight: requires_grad=False
# module.features.denseblock3.denselayer2.norm2.bias: requires_grad=False
# module.features.denseblock3.denselayer2.conv2.weight: requires_grad=False
# module.features.denseblock3.denselayer3.norm1.weight: requires_grad=False
# module.features.denseblock3.denselayer3.norm1.bias: requires_grad=False
# module.features.denseblock3.denselayer3.conv1.weight: requires_grad=False
# module.features.denseblock3.denselayer3.norm2.weight: requires_grad=False
# module.features.denseblock3.denselayer3.norm2.bias: requires_grad=False
# module.features.denseblock3.denselayer3.conv2.weight: requires_grad=False
# module.features.denseblock3.denselayer4.norm1.weight: requires_grad=False
# module.features.denseblock3.denselayer4.norm1.bias: requires_grad=False
# module.features.denseblock3.denselayer4.conv1.weight: requires_grad=False
# module.features.denseblock3.denselayer4.norm2.weight: requires_grad=False
# module.features.denseblock3.denselayer4.norm2.bias: requires_grad=False
# module.features.denseblock3.denselayer4.conv2.weight: requires_grad=False
# module.features.denseblock3.denselayer5.norm1.weight: requires_grad=False
# module.features.denseblock3.denselayer5.norm1.bias: requires_grad=False
# module.features.denseblock3.denselayer5.conv1.weight: requires_grad=False
# module.features.denseblock3.denselayer5.norm2.weight: requires_grad=False
# module.features.denseblock3.denselayer5.norm2.bias: requires_grad=False
# module.features.denseblock3.denselayer5.conv2.weight: requires_grad=False
# module.features.denseblock3.denselayer6.norm1.weight: requires_grad=False
# module.features.denseblock3.denselayer6.norm1.bias: requires_grad=False
# module.features.denseblock3.denselayer6.conv1.weight: requires_grad=False
# module.features.denseblock3.denselayer6.norm2.weight: requires_grad=False
# module.features.denseblock3.denselayer6.norm2.bias: requires_grad=False
# module.features.denseblock3.denselayer6.conv2.weight: requires_grad=False
# module.features.denseblock3.denselayer7.norm1.weight: requires_grad=False
# module.features.denseblock3.denselayer7.norm1.bias: requires_grad=False
# module.features.denseblock3.denselayer7.conv1.weight: requires_grad=False
# module.features.denseblock3.denselayer7.norm2.weight: requires_grad=False
# module.features.denseblock3.denselayer7.norm2.bias: requires_grad=False
# module.features.denseblock3.denselayer7.conv2.weight: requires_grad=False
# module.features.denseblock3.denselayer8.norm1.weight: requires_grad=False
# module.features.denseblock3.denselayer8.norm1.bias: requires_grad=False
# module.features.denseblock3.denselayer8.conv1.weight: requires_grad=False
# module.features.denseblock3.denselayer8.norm2.weight: requires_grad=False
# module.features.denseblock3.denselayer8.norm2.bias: requires_grad=False
# module.features.denseblock3.denselayer8.conv2.weight: requires_grad=False
# module.features.denseblock3.denselayer9.norm1.weight: requires_grad=False
# module.features.denseblock3.denselayer9.norm1.bias: requires_grad=False
# module.features.denseblock3.denselayer9.conv1.weight: requires_grad=False
# module.features.denseblock3.denselayer9.norm2.weight: requires_grad=False
# module.features.denseblock3.denselayer9.norm2.bias: requires_grad=False
# module.features.denseblock3.denselayer9.conv2.weight: requires_grad=False
# module.features.denseblock3.denselayer10.norm1.weight: requires_grad=False
# module.features.denseblock3.denselayer10.norm1.bias: requires_grad=False
# module.features.denseblock3.denselayer10.conv1.weight: requires_grad=False
# module.features.denseblock3.denselayer10.norm2.weight: requires_grad=False
# module.features.denseblock3.denselayer10.norm2.bias: requires_grad=False
# module.features.denseblock3.denselayer10.conv2.weight: requires_grad=False
# module.features.denseblock3.denselayer11.norm1.weight: requires_grad=False
# module.features.denseblock3.denselayer11.norm1.bias: requires_grad=False
# module.features.denseblock3.denselayer11.conv1.weight: requires_grad=False
# module.features.denseblock3.denselayer11.norm2.weight: requires_grad=False
# module.features.denseblock3.denselayer11.norm2.bias: requires_grad=False
# module.features.denseblock3.denselayer11.conv2.weight: requires_grad=False
# module.features.denseblock3.denselayer12.norm1.weight: requires_grad=False
# module.features.denseblock3.denselayer12.norm1.bias: requires_grad=False
# module.features.denseblock3.denselayer12.conv1.weight: requires_grad=False
# module.features.denseblock3.denselayer12.norm2.weight: requires_grad=False
# module.features.denseblock3.denselayer12.norm2.bias: requires_grad=False
# module.features.denseblock3.denselayer12.conv2.weight: requires_grad=False
# module.features.denseblock3.denselayer13.norm1.weight: requires_grad=False
# module.features.denseblock3.denselayer13.norm1.bias: requires_grad=False
# module.features.denseblock3.denselayer13.conv1.weight: requires_grad=False
# module.features.denseblock3.denselayer13.norm2.weight: requires_grad=False
# module.features.denseblock3.denselayer13.norm2.bias: requires_grad=False
# module.features.denseblock3.denselayer13.conv2.weight: requires_grad=False
# module.features.denseblock3.denselayer14.norm1.weight: requires_grad=False
# module.features.denseblock3.denselayer14.norm1.bias: requires_grad=False
# module.features.denseblock3.denselayer14.conv1.weight: requires_grad=False
# module.features.denseblock3.denselayer14.norm2.weight: requires_grad=False
# module.features.denseblock3.denselayer14.norm2.bias: requires_grad=False
# module.features.denseblock3.denselayer14.conv2.weight: requires_grad=False
# module.features.denseblock3.denselayer15.norm1.weight: requires_grad=False
# module.features.denseblock3.denselayer15.norm1.bias: requires_grad=False
# module.features.denseblock3.denselayer15.conv1.weight: requires_grad=False
# module.features.denseblock3.denselayer15.norm2.weight: requires_grad=False
# module.features.denseblock3.denselayer15.norm2.bias: requires_grad=False
# module.features.denseblock3.denselayer15.conv2.weight: requires_grad=False
# module.features.denseblock3.denselayer16.norm1.weight: requires_grad=False
# module.features.denseblock3.denselayer16.norm1.bias: requires_grad=False
# module.features.denseblock3.denselayer16.conv1.weight: requires_grad=False
# module.features.denseblock3.denselayer16.norm2.weight: requires_grad=False
# module.features.denseblock3.denselayer16.norm2.bias: requires_grad=False
# module.features.denseblock3.denselayer16.conv2.weight: requires_grad=False
# module.features.denseblock3.denselayer17.norm1.weight: requires_grad=False
# module.features.denseblock3.denselayer17.norm1.bias: requires_grad=False
# module.features.denseblock3.denselayer17.conv1.weight: requires_grad=False
# module.features.denseblock3.denselayer17.norm2.weight: requires_grad=False
# module.features.denseblock3.denselayer17.norm2.bias: requires_grad=False
# module.features.denseblock3.denselayer17.conv2.weight: requires_grad=False
# module.features.denseblock3.denselayer18.norm1.weight: requires_grad=False
# module.features.denseblock3.denselayer18.norm1.bias: requires_grad=False
# module.features.denseblock3.denselayer18.conv1.weight: requires_grad=False
# module.features.denseblock3.denselayer18.norm2.weight: requires_grad=False
# module.features.denseblock3.denselayer18.norm2.bias: requires_grad=False
# module.features.denseblock3.denselayer18.conv2.weight: requires_grad=False
# module.features.denseblock3.denselayer19.norm1.weight: requires_grad=False
# module.features.denseblock3.denselayer19.norm1.bias: requires_grad=False
# module.features.denseblock3.denselayer19.conv1.weight: requires_grad=False
# module.features.denseblock3.denselayer19.norm2.weight: requires_grad=False
# module.features.denseblock3.denselayer19.norm2.bias: requires_grad=False
# module.features.denseblock3.denselayer19.conv2.weight: requires_grad=False
# module.features.denseblock3.denselayer20.norm1.weight: requires_grad=False
# module.features.denseblock3.denselayer20.norm1.bias: requires_grad=False
# module.features.denseblock3.denselayer20.conv1.weight: requires_grad=False
# module.features.denseblock3.denselayer20.norm2.weight: requires_grad=False
# module.features.denseblock3.denselayer20.norm2.bias: requires_grad=False
# module.features.denseblock3.denselayer20.conv2.weight: requires_grad=False
# module.features.denseblock3.denselayer21.norm1.weight: requires_grad=False
# module.features.denseblock3.denselayer21.norm1.bias: requires_grad=False
# module.features.denseblock3.denselayer21.conv1.weight: requires_grad=False
# module.features.denseblock3.denselayer21.norm2.weight: requires_grad=False
# module.features.denseblock3.denselayer21.norm2.bias: requires_grad=False
# module.features.denseblock3.denselayer21.conv2.weight: requires_grad=False
# module.features.denseblock3.denselayer22.norm1.weight: requires_grad=False
# module.features.denseblock3.denselayer22.norm1.bias: requires_grad=False
# module.features.denseblock3.denselayer22.conv1.weight: requires_grad=False
# module.features.denseblock3.denselayer22.norm2.weight: requires_grad=False
# module.features.denseblock3.denselayer22.norm2.bias: requires_grad=False
# module.features.denseblock3.denselayer22.conv2.weight: requires_grad=False
# module.features.denseblock3.denselayer23.norm1.weight: requires_grad=False
# module.features.denseblock3.denselayer23.norm1.bias: requires_grad=False
# module.features.denseblock3.denselayer23.conv1.weight: requires_grad=False
# module.features.denseblock3.denselayer23.norm2.weight: requires_grad=False
# module.features.denseblock3.denselayer23.norm2.bias: requires_grad=False
# module.features.denseblock3.denselayer23.conv2.weight: requires_grad=False
# module.features.denseblock3.denselayer24.norm1.weight: requires_grad=False
# module.features.denseblock3.denselayer24.norm1.bias: requires_grad=False
# module.features.denseblock3.denselayer24.conv1.weight: requires_grad=False
# module.features.denseblock3.denselayer24.norm2.weight: requires_grad=False
# module.features.denseblock3.denselayer24.norm2.bias: requires_grad=False
# module.features.denseblock3.denselayer24.conv2.weight: requires_grad=False
# module.features.denseblock3.denselayer25.norm1.weight: requires_grad=False
# module.features.denseblock3.denselayer25.norm1.bias: requires_grad=False
# module.features.denseblock3.denselayer25.conv1.weight: requires_grad=False
# module.features.denseblock3.denselayer25.norm2.weight: requires_grad=False
# module.features.denseblock3.denselayer25.norm2.bias: requires_grad=False
# module.features.denseblock3.denselayer25.conv2.weight: requires_grad=False
# module.features.denseblock3.denselayer26.norm1.weight: requires_grad=False
# module.features.denseblock3.denselayer26.norm1.bias: requires_grad=False
# module.features.denseblock3.denselayer26.conv1.weight: requires_grad=False
# module.features.denseblock3.denselayer26.norm2.weight: requires_grad=False
# module.features.denseblock3.denselayer26.norm2.bias: requires_grad=False
# module.features.denseblock3.denselayer26.conv2.weight: requires_grad=False
# module.features.denseblock3.denselayer27.norm1.weight: requires_grad=False
# module.features.denseblock3.denselayer27.norm1.bias: requires_grad=False
# module.features.denseblock3.denselayer27.conv1.weight: requires_grad=False
# module.features.denseblock3.denselayer27.norm2.weight: requires_grad=False
# module.features.denseblock3.denselayer27.norm2.bias: requires_grad=False
# module.features.denseblock3.denselayer27.conv2.weight: requires_grad=False
# module.features.denseblock3.denselayer28.norm1.weight: requires_grad=False
# module.features.denseblock3.denselayer28.norm1.bias: requires_grad=False
# module.features.denseblock3.denselayer28.conv1.weight: requires_grad=False
# module.features.denseblock3.denselayer28.norm2.weight: requires_grad=False
# module.features.denseblock3.denselayer28.norm2.bias: requires_grad=False
# module.features.denseblock3.denselayer28.conv2.weight: requires_grad=False
# module.features.denseblock3.denselayer29.norm1.weight: requires_grad=False
# module.features.denseblock3.denselayer29.norm1.bias: requires_grad=False
# module.features.denseblock3.denselayer29.conv1.weight: requires_grad=False
# module.features.denseblock3.denselayer29.norm2.weight: requires_grad=False
# module.features.denseblock3.denselayer29.norm2.bias: requires_grad=False
# module.features.denseblock3.denselayer29.conv2.weight: requires_grad=False
# module.features.denseblock3.denselayer30.norm1.weight: requires_grad=False
# module.features.denseblock3.denselayer30.norm1.bias: requires_grad=False
# module.features.denseblock3.denselayer30.conv1.weight: requires_grad=False
# module.features.denseblock3.denselayer30.norm2.weight: requires_grad=False
# module.features.denseblock3.denselayer30.norm2.bias: requires_grad=False
# module.features.denseblock3.denselayer30.conv2.weight: requires_grad=False
# module.features.denseblock3.denselayer31.norm1.weight: requires_grad=False
# module.features.denseblock3.denselayer31.norm1.bias: requires_grad=False
# module.features.denseblock3.denselayer31.conv1.weight: requires_grad=False
# module.features.denseblock3.denselayer31.norm2.weight: requires_grad=False
# module.features.denseblock3.denselayer31.norm2.bias: requires_grad=False
# module.features.denseblock3.denselayer31.conv2.weight: requires_grad=False
# module.features.denseblock3.denselayer32.norm1.weight: requires_grad=False
# module.features.denseblock3.denselayer32.norm1.bias: requires_grad=False
# module.features.denseblock3.denselayer32.conv1.weight: requires_grad=False
# module.features.denseblock3.denselayer32.norm2.weight: requires_grad=False
# module.features.denseblock3.denselayer32.norm2.bias: requires_grad=False
# module.features.denseblock3.denselayer32.conv2.weight: requires_grad=False
# module.features.denseblock3.denselayer33.norm1.weight: requires_grad=False
# module.features.denseblock3.denselayer33.norm1.bias: requires_grad=False
# module.features.denseblock3.denselayer33.conv1.weight: requires_grad=False
# module.features.denseblock3.denselayer33.norm2.weight: requires_grad=False
# module.features.denseblock3.denselayer33.norm2.bias: requires_grad=False
# module.features.denseblock3.denselayer33.conv2.weight: requires_grad=False
# module.features.denseblock3.denselayer34.norm1.weight: requires_grad=False
# module.features.denseblock3.denselayer34.norm1.bias: requires_grad=False
# module.features.denseblock3.denselayer34.conv1.weight: requires_grad=False
# module.features.denseblock3.denselayer34.norm2.weight: requires_grad=False
# module.features.denseblock3.denselayer34.norm2.bias: requires_grad=False
# module.features.denseblock3.denselayer34.conv2.weight: requires_grad=False
# module.features.denseblock3.denselayer35.norm1.weight: requires_grad=False
# module.features.denseblock3.denselayer35.norm1.bias: requires_grad=False
# module.features.denseblock3.denselayer35.conv1.weight: requires_grad=False
# module.features.denseblock3.denselayer35.norm2.weight: requires_grad=False
# module.features.denseblock3.denselayer35.norm2.bias: requires_grad=False
# module.features.denseblock3.denselayer35.conv2.weight: requires_grad=False
# module.features.denseblock3.denselayer36.norm1.weight: requires_grad=False
# module.features.denseblock3.denselayer36.norm1.bias: requires_grad=False
# module.features.denseblock3.denselayer36.conv1.weight: requires_grad=False
# module.features.denseblock3.denselayer36.norm2.weight: requires_grad=False
# module.features.denseblock3.denselayer36.norm2.bias: requires_grad=False
# module.features.denseblock3.denselayer36.conv2.weight: requires_grad=False
# module.features.transition3.norm.weight: requires_grad=False
# module.features.transition3.norm.bias: requires_grad=False
# module.features.transition3.conv.weight: requires_grad=False
# module.features.denseblock4.denselayer1.norm1.weight: requires_grad=False
# module.features.denseblock4.denselayer1.norm1.bias: requires_grad=False
# module.features.denseblock4.denselayer1.conv1.weight: requires_grad=False
# module.features.denseblock4.denselayer1.norm2.weight: requires_grad=False
# module.features.denseblock4.denselayer1.norm2.bias: requires_grad=False
# module.features.denseblock4.denselayer1.conv2.weight: requires_grad=False
# module.features.denseblock4.denselayer2.norm1.weight: requires_grad=False
# module.features.denseblock4.denselayer2.norm1.bias: requires_grad=False
# module.features.denseblock4.denselayer2.conv1.weight: requires_grad=False
# module.features.denseblock4.denselayer2.norm2.weight: requires_grad=False
# module.features.denseblock4.denselayer2.norm2.bias: requires_grad=False
# module.features.denseblock4.denselayer2.conv2.weight: requires_grad=False
# module.features.denseblock4.denselayer3.norm1.weight: requires_grad=False
# module.features.denseblock4.denselayer3.norm1.bias: requires_grad=False
# module.features.denseblock4.denselayer3.conv1.weight: requires_grad=False
# module.features.denseblock4.denselayer3.norm2.weight: requires_grad=False
# module.features.denseblock4.denselayer3.norm2.bias: requires_grad=False
# module.features.denseblock4.denselayer3.conv2.weight: requires_grad=False
# module.features.denseblock4.denselayer4.norm1.weight: requires_grad=False
# module.features.denseblock4.denselayer4.norm1.bias: requires_grad=False
# module.features.denseblock4.denselayer4.conv1.weight: requires_grad=False
# module.features.denseblock4.denselayer4.norm2.weight: requires_grad=False
# module.features.denseblock4.denselayer4.norm2.bias: requires_grad=False
# module.features.denseblock4.denselayer4.conv2.weight: requires_grad=False
# module.features.denseblock4.denselayer5.norm1.weight: requires_grad=False
# module.features.denseblock4.denselayer5.norm1.bias: requires_grad=False
# module.features.denseblock4.denselayer5.conv1.weight: requires_grad=False
# module.features.denseblock4.denselayer5.norm2.weight: requires_grad=False
# module.features.denseblock4.denselayer5.norm2.bias: requires_grad=False
# module.features.denseblock4.denselayer5.conv2.weight: requires_grad=False
# module.features.denseblock4.denselayer6.norm1.weight: requires_grad=False
# module.features.denseblock4.denselayer6.norm1.bias: requires_grad=False
# module.features.denseblock4.denselayer6.conv1.weight: requires_grad=False
# module.features.denseblock4.denselayer6.norm2.weight: requires_grad=False
# module.features.denseblock4.denselayer6.norm2.bias: requires_grad=False
# module.features.denseblock4.denselayer6.conv2.weight: requires_grad=False
# module.features.denseblock4.denselayer7.norm1.weight: requires_grad=False
# module.features.denseblock4.denselayer7.norm1.bias: requires_grad=False
# module.features.denseblock4.denselayer7.conv1.weight: requires_grad=False
# module.features.denseblock4.denselayer7.norm2.weight: requires_grad=False
# module.features.denseblock4.denselayer7.norm2.bias: requires_grad=False
# module.features.denseblock4.denselayer7.conv2.weight: requires_grad=False
# module.features.denseblock4.denselayer8.norm1.weight: requires_grad=False
# module.features.denseblock4.denselayer8.norm1.bias: requires_grad=False
# module.features.denseblock4.denselayer8.conv1.weight: requires_grad=False
# module.features.denseblock4.denselayer8.norm2.weight: requires_grad=False
# module.features.denseblock4.denselayer8.norm2.bias: requires_grad=False
# module.features.denseblock4.denselayer8.conv2.weight: requires_grad=False
# module.features.denseblock4.denselayer9.norm1.weight: requires_grad=False
# module.features.denseblock4.denselayer9.norm1.bias: requires_grad=False
# module.features.denseblock4.denselayer9.conv1.weight: requires_grad=False
# module.features.denseblock4.denselayer9.norm2.weight: requires_grad=False
# module.features.denseblock4.denselayer9.norm2.bias: requires_grad=False
# module.features.denseblock4.denselayer9.conv2.weight: requires_grad=False
# module.features.denseblock4.denselayer10.norm1.weight: requires_grad=False
# module.features.denseblock4.denselayer10.norm1.bias: requires_grad=False
# module.features.denseblock4.denselayer10.conv1.weight: requires_grad=False
# module.features.denseblock4.denselayer10.norm2.weight: requires_grad=False
# module.features.denseblock4.denselayer10.norm2.bias: requires_grad=False
# module.features.denseblock4.denselayer10.conv2.weight: requires_grad=False
# module.features.denseblock4.denselayer11.norm1.weight: requires_grad=False
# module.features.denseblock4.denselayer11.norm1.bias: requires_grad=False
# module.features.denseblock4.denselayer11.conv1.weight: requires_grad=False
# module.features.denseblock4.denselayer11.norm2.weight: requires_grad=False
# module.features.denseblock4.denselayer11.norm2.bias: requires_grad=False
# module.features.denseblock4.denselayer11.conv2.weight: requires_grad=False
# module.features.denseblock4.denselayer12.norm1.weight: requires_grad=False
# module.features.denseblock4.denselayer12.norm1.bias: requires_grad=False
# module.features.denseblock4.denselayer12.conv1.weight: requires_grad=False
# module.features.denseblock4.denselayer12.norm2.weight: requires_grad=False
# module.features.denseblock4.denselayer12.norm2.bias: requires_grad=False
# module.features.denseblock4.denselayer12.conv2.weight: requires_grad=False
# module.features.denseblock4.denselayer13.norm1.weight: requires_grad=False
# module.features.denseblock4.denselayer13.norm1.bias: requires_grad=False
# module.features.denseblock4.denselayer13.conv1.weight: requires_grad=False
# module.features.denseblock4.denselayer13.norm2.weight: requires_grad=False
# module.features.denseblock4.denselayer13.norm2.bias: requires_grad=False
# module.features.denseblock4.denselayer13.conv2.weight: requires_grad=False
# module.features.denseblock4.denselayer14.norm1.weight: requires_grad=False
# module.features.denseblock4.denselayer14.norm1.bias: requires_grad=False
# module.features.denseblock4.denselayer14.conv1.weight: requires_grad=False
# module.features.denseblock4.denselayer14.norm2.weight: requires_grad=False
# module.features.denseblock4.denselayer14.norm2.bias: requires_grad=False
# module.features.denseblock4.denselayer14.conv2.weight: requires_grad=False
# module.features.denseblock4.denselayer15.norm1.weight: requires_grad=False
# module.features.denseblock4.denselayer15.norm1.bias: requires_grad=False
# module.features.denseblock4.denselayer15.conv1.weight: requires_grad=False
# module.features.denseblock4.denselayer15.norm2.weight: requires_grad=False
# module.features.denseblock4.denselayer15.norm2.bias: requires_grad=False
# module.features.denseblock4.denselayer15.conv2.weight: requires_grad=False
# module.features.denseblock4.denselayer16.norm1.weight: requires_grad=False
# module.features.denseblock4.denselayer16.norm1.bias: requires_grad=False
# module.features.denseblock4.denselayer16.conv1.weight: requires_grad=False
# module.features.denseblock4.denselayer16.norm2.weight: requires_grad=False
# module.features.denseblock4.denselayer16.norm2.bias: requires_grad=False
# module.features.denseblock4.denselayer16.conv2.weight: requires_grad=False
# module.features.denseblock4.denselayer17.norm1.weight: requires_grad=False
# module.features.denseblock4.denselayer17.norm1.bias: requires_grad=False
# module.features.denseblock4.denselayer17.conv1.weight: requires_grad=False
# module.features.denseblock4.denselayer17.norm2.weight: requires_grad=False
# module.features.denseblock4.denselayer17.norm2.bias: requires_grad=False
# module.features.denseblock4.denselayer17.conv2.weight: requires_grad=False
# module.features.denseblock4.denselayer18.norm1.weight: requires_grad=False
# module.features.denseblock4.denselayer18.norm1.bias: requires_grad=False
# module.features.denseblock4.denselayer18.conv1.weight: requires_grad=False
# module.features.denseblock4.denselayer18.norm2.weight: requires_grad=False
# module.features.denseblock4.denselayer18.norm2.bias: requires_grad=False
# module.features.denseblock4.denselayer18.conv2.weight: requires_grad=False
# module.features.denseblock4.denselayer19.norm1.weight: requires_grad=False
# module.features.denseblock4.denselayer19.norm1.bias: requires_grad=False
# module.features.denseblock4.denselayer19.conv1.weight: requires_grad=False
# module.features.denseblock4.denselayer19.norm2.weight: requires_grad=False
# module.features.denseblock4.denselayer19.norm2.bias: requires_grad=False
# module.features.denseblock4.denselayer19.conv2.weight: requires_grad=False
# module.features.denseblock4.denselayer20.norm1.weight: requires_grad=False
# module.features.denseblock4.denselayer20.norm1.bias: requires_grad=False
# module.features.denseblock4.denselayer20.conv1.weight: requires_grad=False
# module.features.denseblock4.denselayer20.norm2.weight: requires_grad=False
# module.features.denseblock4.denselayer20.norm2.bias: requires_grad=False
# module.features.denseblock4.denselayer20.conv2.weight: requires_grad=False
# module.features.denseblock4.denselayer21.norm1.weight: requires_grad=False
# module.features.denseblock4.denselayer21.norm1.bias: requires_grad=False
# module.features.denseblock4.denselayer21.conv1.weight: requires_grad=False
# module.features.denseblock4.denselayer21.norm2.weight: requires_grad=False
# module.features.denseblock4.denselayer21.norm2.bias: requires_grad=False
# module.features.denseblock4.denselayer21.conv2.weight: requires_grad=False
# module.features.denseblock4.denselayer22.norm1.weight: requires_grad=False
# module.features.denseblock4.denselayer22.norm1.bias: requires_grad=False
# module.features.denseblock4.denselayer22.conv1.weight: requires_grad=False
# module.features.denseblock4.denselayer22.norm2.weight: requires_grad=False
# module.features.denseblock4.denselayer22.norm2.bias: requires_grad=False
# module.features.denseblock4.denselayer22.conv2.weight: requires_grad=False
# module.features.denseblock4.denselayer23.norm1.weight: requires_grad=False
# module.features.denseblock4.denselayer23.norm1.bias: requires_grad=False
# module.features.denseblock4.denselayer23.conv1.weight: requires_grad=False
# module.features.denseblock4.denselayer23.norm2.weight: requires_grad=False
# module.features.denseblock4.denselayer23.norm2.bias: requires_grad=False
# module.features.denseblock4.denselayer23.conv2.weight: requires_grad=False
# module.features.denseblock4.denselayer24.norm1.weight: requires_grad=False
# module.features.denseblock4.denselayer24.norm1.bias: requires_grad=False
# module.features.denseblock4.denselayer24.conv1.weight: requires_grad=False
# module.features.denseblock4.denselayer24.norm2.weight: requires_grad=False
# module.features.denseblock4.denselayer24.norm2.bias: requires_grad=False
# module.features.denseblock4.denselayer24.conv2.weight: requires_grad=False
# module.features.norm5.weight: requires_grad=False
# module.features.norm5.bias: requires_grad=False
# module.classifier.0.weight: requires_grad=True
# module.classifier.0.bias: requires_grad=True

# %% [markdown]
# ### Creating `train_step()` & `test_step()` functions

# %%
def train_step(model: torch.nn.Module,
               dataloader: torch.utils.data.DataLoader,
               loss_fn: torch.nn.Module,
               optimizer: torch.optim.Optimizer):
  # Put the model on the training mode
  model.train()

  # setup train loss and accuracy(evaluation metrics)
  train_loss, train_acc = 0, 0

  # loop through the dataloader
  for batch, (X, y, _) in enumerate(dataloader):
    # send data to the target device
    X, y = X.to(device), y.to(device)

    # 1. Forward pass
    y_pred = model(X)

    # 2. Calculate the loss
    loss = loss_fn(y_pred, y)
    train_loss += loss.item()

    # 3. Optimizer zero grad
    optimizer.zero_grad()

    # 4. backprop
    loss.backward()

    # 5. optimizer step
    optimizer.step()

    # Calculate the accuracy
    y_pred_class = torch.argmax(torch.softmax(y_pred,dim=1),dim=1)
    train_acc += (y_pred_class == y).sum().item() / len(y_pred)

  # Adjust the train_loss and train_acc per batch
  train_loss /= len(dataloader)
  train_acc /= len(dataloader)

  return train_loss, train_acc

# %%
# Create a test step
def test_step(model: torch.nn.Module,
              dataloader: torch.utils.data.DataLoader,
              loss_fn: torch.nn.Module):

  # setup evaluation metrics
  test_loss, test_acc = 0, 0
  cm = ConfusionMatrix(task='multiclass',num_classes=len(class_names)).to(device)

  # set to training mode
  model.eval()
  with torch.inference_mode():
    for batch, (X, y, _) in enumerate(dataloader):
      # put data on target device
      X, y = X.to(device), y.to(device)

      # forward pass
      test_pred_logits = model(X)

      # calculate the loss
      loss = loss_fn(test_pred_logits, y)
      test_loss += loss.item()

      # calculate the accuracy
      test_pred_labels = test_pred_logits.argmax(dim=1)
      test_acc += ((test_pred_labels == y).sum().item()/len(test_pred_labels))
        
      # confusion matrix
      cm.update(test_pred_labels, y)

  # Normalize the confusion matrix
  cm = cm.compute().cpu().numpy()
    
  # Calculate precision, recall, and F1-score
  precision = np.diag(cm) / np.sum(cm, axis=0)
  recall = np.diag(cm) / np.sum(cm, axis=1)
  f1 = 2 * (precision * recall) / (precision + recall)
    
  # Average precision, recall, and F1-score across classes
  avg_precision = np.mean(precision)
  avg_recall = np.mean(recall)
  avg_f1 = np.mean(f1)

  # adjust test_loss and test_acc to batch
  test_loss /= len(dataloader)
  test_acc /= len(dataloader)

  return test_loss, test_acc, cm, avg_precision, avg_recall, avg_f1

# %%
num_classes=len(class_names)

# %%
num_classes
# Out:
# 38

# %%
def plot_confusion_matrix(cm, class_names):
    """
    Plots the confusion matrix using Seaborn's heatmap function.
    
    Parameters:
        cm (numpy.ndarray): Confusion matrix.
        class_names (list): List of class names.
    """
    plt.figure(figsize=(10, 8))
    sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=class_names, yticklabels=class_names)
    plt.xlabel('Predicted Labels')
    plt.ylabel('True Labels')
    plt.title('Confusion Matrix')
    plt.show()

# %% [markdown]
# ### Creating a `train()` function to combine `train_step()` & `test_step()`

# %%
from tqdm.auto import tqdm

def train(model: torch.nn.Module,
          train_dataloader: torch.utils.data.DataLoader,
          test_dataloader: torch.utils.data.DataLoader,
          optimizer: torch.optim.Optimizer,
          loss_fn: torch.nn.Module = nn.CrossEntropyLoss(),
          epochs: int=5):
    
  #scheduler = lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.1, patience=lr_scheduler_patience, verbose=True)

  # Create empty results dictionary
  results = {"train_loss":[],
             "train_acc":[],
             "test_loss":[],
             "test_acc":[]}
  
  test_confusion_matrices = []  # List to store confusion matrices for each epoch

  # loop through train and test loops for no. of epochs
  for epoch in tqdm(range(epochs)):
    train_loss, train_acc = train_step(model=model,
                                       dataloader=train_dataloader,
                                       loss_fn=loss_fn,
                                       optimizer=optimizer)
    test_loss, test_acc, cm, precision, recall, f1  = test_step(model=model,
                                                                dataloader=test_dataloader,
                                                                loss_fn=loss_fn)
    
    
        
    # Update the learning rate based on the test loss
    #scheduler.step(test_loss)
            
    # Print out whats happening
    print(f"Epoch: {epoch+1} | Train loss: {train_loss:.4f} | Train acc: {train_acc:.4f} | Test loss: {test_loss:.4f} | Test acc: {test_acc:.4f} | Test Precision: {precision.mean():.4f} | Test Recall: {recall.mean():.4f} | Test F1 Score: {f1.mean():.4f}")
    
    # update the results dictionary
    results["train_loss"].append(train_loss),
    results["train_acc"].append(train_acc),
    results["test_loss"].append(test_loss),
    results["test_acc"].append(test_acc),
    
    # Store confusion matrix for this epoch
    test_confusion_matrices.append(cm)
    

  # Print the final confusion matrix
  print("Final Test Confusion Matrix:\n")
  plot_confusion_matrix(test_confusion_matrices[-1], class_names)

  # Return filled results at the end of the epoch
  return results

# %%
# set random seeds
torch.manual_seed(42)
torch.cuda.manual_seed(42)

# set the no. of epochs
EPOCHS = 25

# optimizer and loss function are already set way above

# start the timer
from timeit import default_timer as timer
start_time = timer()

# Train model_0
model_0_results = train(model = model,
          train_dataloader = train_dataloader,
          test_dataloader =  test_dataloader,
          optimizer = optimizer,
          loss_fn = loss_fn,
          epochs = EPOCHS)

# End the timer and print how long it took
end_time = timer()
print(f"Total training time: {end_time - start_time: .3f} seconds")
# Out:
#   0%|          | 0/25 [00:00<?, ?it/s]
# Epoch: 1 | Train loss: 0.1943 | Train acc: 0.9402 | Test loss: 0.0797 | Test acc: 0.9760 | Test Precision: 0.9760 | Test Recall: 0.9757 | Test F1 Score: 0.9757
# Epoch: 2 | Train loss: 0.1947 | Train acc: 0.9398 | Test loss: 0.0803 | Test acc: 0.9751 | Test Precision: 0.9750 | Test Recall: 0.9749 | Test F1 Score: 0.9748
# Epoch: 3 | Train loss: 0.1925 | Train acc: 0.9407 | Test loss: 0.0779 | Test acc: 0.9763 | Test Precision: 0.9763 | Test Recall: 0.9761 | Test F1 Score: 0.9761
# Epoch: 4 | Train loss: 0.1942 | Train acc: 0.9399 | Test loss: 0.0801 | Test acc: 0.9748 | Test Precision: 0.9753 | Test Recall: 0.9744 | Test F1 Score: 0.9746
# Epoch: 5 | Train loss: 0.1913 | Train acc: 0.9404 | Test loss: 0.0815 | Test acc: 0.9756 | Test Precision: 0.9759 | Test Recall: 0.9752 | Test F1 Score: 0.9754
# Epoch: 6 | Train loss: 0.1926 | Train acc: 0.9405 | Test loss: 0.0753 | Test acc: 0.9777 | Test Precision: 0.9778 | Test Recall: 0.9774 | Test F1 Score: 0.9775
# Epoch: 7 | Train loss: 0.1912 | Train acc: 0.9405 | Test loss: 0.0770 | Test acc: 0.9761 | Test Precision: 0.9763 | Test Recall: 0.9758 | Test F1 Score: 0.9759
# Epoch: 8 | Train loss: 0.1941 | Train acc: 0.9403 | Test loss: 0.0790 | Test acc: 0.9757 | Test Precision: 0.9759 | Test Recall: 0.9754 | Test F1 Score: 0.9755
# Epoch: 9 | Train loss: 0.1901 | Train acc: 0.9413 | Test loss: 0.0854 | Test acc: 0.9738 | Test Precision: 0.9739 | Test Recall: 0.9736 | Test F1 Score: 0.9736
# Epoch: 10 | Train loss: 0.1911 | Train acc: 0.9411 | Test loss: 0.0786 | Test acc: 0.9765 | Test Precision: 0.9768 | Test Recall: 0.9762 | Test F1 Score: 0.9763
# Epoch: 11 | Train loss: 0.1910 | Train acc: 0.9405 | Test loss: 0.0830 | Test acc: 0.9744 | Test Precision: 0.9746 | Test Recall: 0.9743 | Test F1 Score: 0.9742
# Epoch: 12 | Train loss: 0.1897 | Train acc: 0.9405 | Test loss: 0.0792 | Test acc: 0.9751 | Test Precision: 0.9753 | Test Recall: 0.9747 | Test F1 Score: 0.9748
# Epoch: 13 | Train loss: 0.1888 | Train acc: 0.9420 | Test loss: 0.0729 | Test acc: 0.9778 | Test Precision: 0.9776 | Test Recall: 0.9776 | Test F1 Score: 0.9775
# Epoch: 14 | Train loss: 0.1905 | Train acc: 0.9402 | Test loss: 0.0803 | Test acc: 0.9756 | Test Precision: 0.9759 | Test Recall: 0.9752 | Test F1 Score: 0.9754
# Epoch: 15 | Train loss: 0.1896 | Train acc: 0.9408 | Test loss: 0.0771 | Test acc: 0.9765 | Test Precision: 0.9767 | Test Recall: 0.9761 | Test F1 Score: 0.9763
# Epoch: 16 | Train loss: 0.1905 | Train acc: 0.9406 | Test loss: 0.0744 | Test acc: 0.9772 | Test Precision: 0.9770 | Test Recall: 0.9769 | Test F1 Score: 0.9769
# Epoch: 17 | Train loss: 0.1906 | Train acc: 0.9415 | Test loss: 0.0761 | Test acc: 0.9764 | Test Precision: 0.9764 | Test Recall: 0.9761 | Test F1 Score: 0.9762
# Epoch: 18 | Train loss: 0.1911 | Train acc: 0.9408 | Test loss: 0.0758 | Test acc: 0.9759 | Test Precision: 0.9759 | Test Recall: 0.9757 | Test F1 Score: 0.9757
# Epoch: 19 | Train loss: 0.1894 | Train acc: 0.9403 | Test loss: 0.0830 | Test acc: 0.9741 | Test Precision: 0.9745 | Test Recall: 0.9739 | Test F1 Score: 0.9739
# Epoch: 20 | Train loss: 0.1874 | Train acc: 0.9414 | Test loss: 0.0813 | Test acc: 0.9753 | Test Precision: 0.9754 | Test Recall: 0.9751 | Test F1 Score: 0.9750
# Epoch: 21 | Train loss: 0.1891 | Train acc: 0.9412 | Test loss: 0.0827 | Test acc: 0.9747 | Test Precision: 0.9750 | Test Recall: 0.9743 | Test F1 Score: 0.9744
# Epoch: 22 | Train loss: 0.1863 | Train acc: 0.9411 | Test loss: 0.0811 | Test acc: 0.9745 | Test Precision: 0.9750 | Test Recall: 0.9743 | Test F1 Score: 0.9744
# Epoch: 23 | Train loss: 0.1854 | Train acc: 0.9420 | Test loss: 0.0768 | Test acc: 0.9768 | Test Precision: 0.9770 | Test Recall: 0.9765 | Test F1 Score: 0.9767
# Epoch: 24 | Train loss: 0.1873 | Train acc: 0.9417 | Test loss: 0.0769 | Test acc: 0.9755 | Test Precision: 0.9757 | Test Recall: 0.9751 | Test F1 Score: 0.9752
# Epoch: 25 | Train loss: 0.1861 | Train acc: 0.9426 | Test loss: 0.0826 | Test acc: 0.9743 | Test Precision: 0.9747 | Test Recall: 0.9739 | Test F1 Score: 0.9741
# Final Test Confusion Matrix:
# Total training time:  24457.755 seconds

# %%
for batch_data in train_dataloader:
    inputs, labels, class_labels = batch_data
    print("Input tensor shape:", inputs.shape)
    print("Labels tensor shape:", labels.shape)
    print("Class labels:", class_labels)
    break  # Only print the first batch
# Out:
# Input tensor shape: torch.Size([32, 3, 256, 256])
# Labels tensor shape: torch.Size([32])
# Class labels: ('Strawberry___Leaf_scorch', 'Tomato___Target_Spot', 'Pepper,_bell___Bacterial_spot', 'Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot', 'Orange___Haunglongbing_(Citrus_greening)', 'Tomato___Tomato_mosaic_virus', 'Peach___healthy', 'Corn_(maize)___healthy', 'Apple___healthy', 'Tomato___Early_blight', 'Grape___Leaf_blight_(Isariopsis_Leaf_Spot)', 'Corn_(maize)___Northern_Leaf_Blight', 'Apple___Cedar_apple_rust', 'Tomato___Late_blight', 'Peach___Bacterial_spot', 'Apple___Black_rot', 'Apple___Apple_scab', 'Grape___healthy', 'Grape___Leaf_blight_(Isariopsis_Leaf_Spot)', 'Peach___Bacterial_spot', 'Tomato___Early_blight', 'Corn_(maize)___Common_rust_', 'Tomato___Early_blight', 'Potato___healthy', 'Grape___Leaf_blight_(Isariopsis_Leaf_Spot)', 'Tomato___Early_blight', 'Tomato___Tomato_Yellow_Leaf_Curl_Virus', 'Strawberry___Leaf_scorch', 'Potato___Late_blight', 'Raspberry___healthy', 'Apple___Apple_scab', 'Tomato___healthy')

# %%
def plot_curves(results: Dict[str, List[float]]):
  """  plots training curves of a results dictionary  """
  # Get the loss values of the results dictionary (training and testing)
  loss = results["train_loss"]
  test_loss = results["test_loss"]

  # get the accuract values of the results dictionary
  accuracy = results["train_acc"]
  test_accuracy = results["test_acc"]

  # Figure out how many epochs there were
  epochs = range(len(results["train_loss"]))

  # setup a plot
  plt.figure(figsize=(15,7))

  # plot the loss
  plt.subplot(1,2,1)
  plt.plot(epochs, loss, label="Train loss")
  plt.plot(epochs, test_loss, label="Test loss")
  plt.title("Loss")
  plt.xlabel("Epochs")
  plt.legend()

  # Plot the accuracy
  plt.subplot(1,2,2)
  plt.plot(epochs, accuracy, label="Train Accuracy")
  plt.plot(epochs, test_accuracy, label="Test Accuracy")
  plt.title("Accuracy")
  plt.xlabel("Epochs")
  plt.legend()

# %%
plot_curves(model_0_results)

# %%
model_0_results
# Out:
# {'train_loss': [0.19426149448475677,
#   0.1946630035986989,
#   0.19253425649165917,
#   0.19423140499327107,
#   0.19134075945187284,
#   0.19259270242871915,
#   0.19116968078336147,
#   0.19413754271328937,
#   0.19009912427994655,
#   0.19107109848850753,
#   0.19096431693229204,
#   0.1897412407354816,
#   0.18884780308300383,
#   0.19045708009283896,
#   0.18956236402484222,
#   0.19045737030600954,
#   0.19055944145180229,
#   0.19113874598289682,
#   0.1893777703937579,
#   0.18740785608562383,
#   0.1890619712613411,
#   0.1862649243156704,
#   0.18544977306908453,
#   0.1872812953470703,
#   0.18612228649802773],
#  'train_acc': [0.9402483129168234,
#   0.9397987126714294,
#   0.9407003868912153,
#   0.9399211622568325,
#   0.9403874601729632,
#   0.9405154756486117,
#   0.9404728038233955,
#   0.9402711949100553,
#   0.9412693445607647,
#   0.9411215392531318,
#   0.9404956858166275,
#   0.9405099097583661,
#   0.9420120816924265,
#   0.9401827590983752,
#   0.9408426263086026,
#   0.9406094773505373,
#   0.9414542558033683,
#   0.9407943885931409,
#   0.9403305644060082,
#   0.9414344659713839,
#   0.9411926589618255,
#   0.9411357631948705,
#   0.942040529575904,
#   0.9417473926896361,
#   0.9426094872454533],
#  'test_loss': [0.07972192451488809,
#   0.08028853011338717,
#   0.07791695509584812,
#   0.08012301688883533,
#   0.08150000238228874,
#   0.0752522778442918,
#   0.07702166323075124,
#   0.07903681389294269,
#   0.08544182270499401,
#   0.07862881110944066,
#   0.08298428947029275,
#   0.07924600759241333,
#   0.07287276380672914,
#   0.08028193098002125,
#   0.07710229198495984,
#   0.07444719910111003,
#   0.07612607425177967,
#   0.07582503284463284,
#   0.0829612083717207,
#   0.08129953161460765,
#   0.08267775920664214,
#   0.08105842567792768,
#   0.07683084704765696,
#   0.0768987869585263,
#   0.08262645825552516],
#  'test_acc': [0.9759659090909091,
#   0.9750568181818182,
#   0.9763068181818182,
#   0.9748295454545455,
#   0.9755681818181818,
#   0.9776704545454545,
#   0.9761363636363637,
#   0.9757386363636363,
#   0.9738068181818181,
#   0.9765340909090909,
#   0.9744318181818182,
#   0.9750568181818182,
#   0.9777840909090909,
#   0.975625,
#   0.9764772727272727,
#   0.9771590909090909,
#   0.9763636363636363,
#   0.975909090909091,
#   0.9740909090909091,
#   0.975284090909091,
#   0.9746590909090909,
#   0.9745454545454545,
#   0.9768181818181818,
#   0.9754545454545455,
#   0.9742613636363636]}

# %%
#####################################################################
model_filename = "/kaggle/working/densenet161_model_state_dict_100.pth"

torch.save(model.state_dict(), model_filename)
print("Model state dictionary exported successfully to", model_filename)
#####################################################################
# Out:
# Model state dictionary exported successfully to /kaggle/working/densenet161_model_state_dict_100.pth
