# %% [markdown]
# ### Importing all libraries

# %%
import torch, torchvision, torchmetrics
from torchmetrics import ConfusionMatrix
from torch import nn
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import requests
from sklearn.model_selection import train_test_split
from torchmetrics import Accuracy
from torchvision import transforms
from torchvision import models
from torchvision import datasets
from torchvision.transforms import ToTensor
from torch.utils.data import DataLoader
from torchinfo import summary
from timeit import default_timer as timer
from pathlib import Path
from tqdm.auto import tqdm
from torchmetrics import ConfusionMatrix
from mlxtend.plotting import plot_confusion_matrix
import random
from PIL import Image
import os
import torchinfo
from torchvision.datasets import ImageFolder
import albumentations as A
from typing import Dict, List
import seaborn as sns
import torch.optim.lr_scheduler as lr_scheduler
print("All packages imported!")
# Out:
# All packages imported!

# %%
# GPU information
# !nvidia-smi
# Out:
# Wed May  1 22:53:28 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.129.03             Driver Version: 535.129.03   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   68C    P0              30W /  70W |   1411MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
# |   1  Tesla T4                       Off | 00000000:00:05.0 Off |                    0 |
# | N/A   69C    P0              32W /  70W |   1187MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# +---------------------------------------------------------------------------------------+

# %%
device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')
device
# Out:
# device(type='cuda')

# %% [markdown]
# ### Importing data from our folder

# %%
# Setup path tod data folder
dataset_dir = Path("../input/new-plant-diseases-dataset/New Plant Diseases Dataset(Augmented)/New Plant Diseases Dataset(Augmented)/")

# chek if path exists
if dataset_dir.is_dir():
    print("Dataset directory exists\n")
else:
    print("Dataset directory doesnt exist\n")

file_list = list(dataset_dir.glob("*"))
print("Files in the dataset directory")
for file_path in file_list:
    print(file_path.name)
# Out:
# Dataset directory exists
#
# Files in the dataset directory
# valid
# train

# %% [markdown]
# ### Defining training and testing directories

# %%
train_dir = dataset_dir / "train"
test_dir = dataset_dir / "valid"
train_dir, test_dir
# Out:
# (PosixPath('../input/new-plant-diseases-dataset/New Plant Diseases Dataset(Augmented)/New Plant Diseases Dataset(Augmented)/train'),
#  PosixPath('../input/new-plant-diseases-dataset/New Plant Diseases Dataset(Augmented)/New Plant Diseases Dataset(Augmented)/valid'))

# %%
data ='../input/new-plant-diseases-dataset/'
os.listdir(data)
# Out:
# ['New Plant Diseases Dataset(Augmented)',
#  'new plant diseases dataset(augmented)',
#  'test']

# %% [markdown]
# ### Coverting our train and test directories into datasets

# %%
from albumentations.pytorch import ToTensorV2

# %%
# Custom dataset class with Albumentations transformations
class CustomDataset(torch.utils.data.Dataset):
    def __init__(self, root_dir, transform=None):
        self.root_dir = root_dir
        self.transform = transform
        self.images = []
        self.labels = []
        self.class_names = []  # Store class names
        
        # Iterate through each class folder
        for label, class_name in enumerate(os.listdir(root_dir)):
            class_dir = os.path.join(root_dir, class_name)
            if os.path.isdir(class_dir):
                self.class_names.append(class_name)  # Append class name
                # Iterate through each image in the class folder
                for image_name in os.listdir(class_dir):
                    image_path = os.path.join(class_dir, image_name)
                    self.images.append(image_path)
                    self.labels.append(label)
    
    def __len__(self):
        return len(self.images)
    
    def __getitem__(self, idx):
        image_path = self.images[idx]
        label = self.labels[idx]
        image = Image.open(image_path).convert('RGB')
        
        if self.transform:
            transformed = self.transform(image=np.array(image))
            image = transformed['image']
        
        return image, label, self.class_names[label]

# Define additional transformations
additional_transforms = A.Compose([
    A.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.2, p=0.5),
    A.Blur(blur_limit=3, p=0.2),
    A.ElasticTransform(alpha=120, sigma=120 * 0.05, alpha_affine=120 * 0.03, p=0.2),
    A.GridDistortion(p=0.2),
])

# Define transformations using Albumentations for training data
train_transform = A.Compose([
    A.Resize(width=224, height=224),
    A.HorizontalFlip(p=0.5),
    A.Rotate(limit=30),
    A.RandomBrightnessContrast(p=0.2),
    A.RandomGamma(p=0.2),
    A.GaussNoise(p=0.2),
    additional_transforms,  # Add the new transformations here
    A.Normalize(mean=(0.46738179, 0.46738179, 0.46738179), std=(0.19342914, 0.19342914, 0.19342914)),
    A.pytorch.ToTensorV2(),
])

# Define transformations for validation/test data (no augmentation)
val_transform = A.Compose([
    A.Resize(width=224, height=224),
    A.Normalize(mean=(0.46738179, 0.46738179, 0.46738179), std=(0.19342914, 0.19342914, 0.19342914)),
    A.pytorch.ToTensorV2(),  # Convert the image to PyTorch tensor without augmentation
])

# Create custom datasets
train_data = CustomDataset(root_dir=train_dir, transform=train_transform)
test_data = CustomDataset(root_dir=test_dir, transform=val_transform)

# %%
class_names = train_data.class_names
class_names
# Out:
# ['Tomato___Late_blight',
#  'Tomato___healthy',
#  'Grape___healthy',
#  'Orange___Haunglongbing_(Citrus_greening)',
#  'Soybean___healthy',
#  'Squash___Powdery_mildew',
#  'Potato___healthy',
#  'Corn_(maize)___Northern_Leaf_Blight',
#  'Tomato___Early_blight',
#  'Tomato___Septoria_leaf_spot',
#  'Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot',
#  'Strawberry___Leaf_scorch',
#  'Peach___healthy',
#  'Apple___Apple_scab',
#  'Tomato___Tomato_Yellow_Leaf_Curl_Virus',
#  'Tomato___Bacterial_spot',
#  'Apple___Black_rot',
#  'Blueberry___healthy',
#  'Cherry_(including_sour)___Powdery_mildew',
#  'Peach___Bacterial_spot',
#  'Apple___Cedar_apple_rust',
#  'Tomato___Target_Spot',
#  'Pepper,_bell___healthy',
#  'Grape___Leaf_blight_(Isariopsis_Leaf_Spot)',
#  'Potato___Late_blight',
#  'Tomato___Tomato_mosaic_virus',
#  'Strawberry___healthy',
#  'Apple___healthy',
#  'Grape___Black_rot',
#  'Potato___Early_blight',
#  'Cherry_(including_sour)___healthy',
#  'Corn_(maize)___Common_rust_',
#  'Grape___Esca_(Black_Measles)',
#  'Raspberry___healthy',
#  'Tomato___Leaf_Mold',
#  'Tomato___Spider_mites Two-spotted_spider_mite',
#  'Pepper,_bell___Bacterial_spot',
#  'Corn_(maize)___healthy']

# %%
# Create a dictionary to store class-to-index mapping
class_to_idx = {}

# Assign consecutive indices starting from 0
for idx, class_name in enumerate(class_names):
    class_to_idx[class_name] = idx

# Now you can use the class-to-index mapping
print(class_to_idx)
# Out:
# {'Tomato___Late_blight': 0, 'Tomato___healthy': 1, 'Grape___healthy': 2, 'Orange___Haunglongbing_(Citrus_greening)': 3, 'Soybean___healthy': 4, 'Squash___Powdery_mildew': 5, 'Potato___healthy': 6, 'Corn_(maize)___Northern_Leaf_Blight': 7, 'Tomato___Early_blight': 8, 'Tomato___Septoria_leaf_spot': 9, 'Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot': 10, 'Strawberry___Leaf_scorch': 11, 'Peach___healthy': 12, 'Apple___Apple_scab': 13, 'Tomato___Tomato_Yellow_Leaf_Curl_Virus': 14, 'Tomato___Bacterial_spot': 15, 'Apple___Black_rot': 16, 'Blueberry___healthy': 17, 'Cherry_(including_sour)___Powdery_mildew': 18, 'Peach___Bacterial_spot': 19, 'Apple___Cedar_apple_rust': 20, 'Tomato___Target_Spot': 21, 'Pepper,_bell___healthy': 22, 'Grape___Leaf_blight_(Isariopsis_Leaf_Spot)': 23, 'Potato___Late_blight': 24, 'Tomato___Tomato_mosaic_virus': 25, 'Strawberry___healthy': 26, 'Apple___healthy': 27, 'Grape___Black_rot': 28, 'Potato___Early_blight': 29, 'Cherry_(including_sour)___healthy': 30, 'Corn_(maize)___Common_rust_': 31, 'Grape___Esca_(Black_Measles)': 32, 'Raspberry___healthy': 33, 'Tomato___Leaf_Mold': 34, 'Tomato___Spider_mites Two-spotted_spider_mite': 35, 'Pepper,_bell___Bacterial_spot': 36, 'Corn_(maize)___healthy': 37}

# %%
print(f"Length of train_data: {len(train_data)}\nLength of test_data : {len(test_data)}")
# Out:
# Length of train_data: 70295
# Length of test_data : 17572

# %%
# Number of cores available on the device
os.cpu_count()
# Out:
# 4

# %% [markdown]
# ### Creating train and test dataloaders

# %%
# Setup BATCH_SIZE hyper-parameter
BATCH_SIZE = 32
train_dataloader = DataLoader(dataset = train_data,
                             batch_size = BATCH_SIZE,
                             num_workers = 2,
                             shuffle=True)
test_dataloader = DataLoader(dataset = test_data,
                             batch_size = BATCH_SIZE,
                             num_workers = 2,
                             shuffle=False)

train_dataloader, test_dataloader
# Out:
# (<torch.utils.data.dataloader.DataLoader at 0x7bdd12159a50>,
#  <torch.utils.data.dataloader.DataLoader at 0x7bdd12159f60>)

# %%
print(next(iter(train_dataloader))[0].device)
print(next(iter(test_dataloader))[0].device)
# Out:
# cpu
# cpu

# %%
print(f"Number of train batches: {len(train_dataloader)}\nNumber of test batches : {len(test_dataloader)}")
# Out:
# Number of train batches: 2197
# Number of test batches : 550

# %%
# img, label = next(iter(train_dataloader))

# # Batch size will now be 1, you can change the batch size if you like
# print(f"Image shape: {img.shape} -> [Batch size, color channels, height, width]")
# print(f"Label shape: {label.shape}")

# %% [markdown]
# ### Defining a simple model

# %%
# setting up device agnostic code
torch.manual_seed(42)
torch.cuda.manual_seed(42)

model = models.swin_v2_b(weights='IMAGENET1K_V1')

# %%
model
# Out:
# SwinTransformer(
#   (features): Sequential(
#     (0): Sequential(
#       (0): Conv2d(3, 128, kernel_size=(4, 4), stride=(4, 4))
#       (1): Permute()
#       (2): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#     )
#     (1): Sequential(
#       (0): SwinTransformerBlockV2(
#         (norm1): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#         (attn): ShiftedWindowAttentionV2(
#           (qkv): Linear(in_features=128, out_features=384, bias=True)
#           (proj): Linear(in_features=128, out_features=128, bias=True)
#           (cpb_mlp): Sequential(
#             (0): Linear(in_features=2, out_features=512, bias=True)
#             (1): ReLU(inplace=True)
#             (2): Linear(in_features=512, out_features=4, bias=False)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.0, mode=row)
#         (norm2): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (0): Linear(in_features=128, out_features=512, bias=True)
#           (1): GELU(approximate='none')
#           (2): Dropout(p=0.0, inplace=False)
#           (3): Linear(in_features=512, out_features=128, bias=True)
#           (4): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (1): SwinTransformerBlockV2(
#         (norm1): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#         (attn): ShiftedWindowAttentionV2(
#           (qkv): Linear(in_features=128, out_features=384, bias=True)
#           (proj): Linear(in_features=128, out_features=128, bias=True)
#           (cpb_mlp): Sequential(
#             (0): Linear(in_features=2, out_features=512, bias=True)
#             (1): ReLU(inplace=True)
#             (2): Linear(in_features=512, out_features=4, bias=False)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.021739130434782608, mode=row)
#         (norm2): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (0): Linear(in_features=128, out_features=512, bias=True)
#           (1): GELU(approximate='none')
#           (2): Dropout(p=0.0, inplace=False)
#           (3): Linear(in_features=512, out_features=128, bias=True)
#           (4): Dropout(p=0.0, inplace=False)
#         )
#       )
#     )
#     (2): PatchMergingV2(
#       (reduction): Linear(in_features=512, out_features=256, bias=False)
#       (norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#     )
#     (3): Sequential(
#       (0): SwinTransformerBlockV2(
#         (norm1): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#         (attn): ShiftedWindowAttentionV2(
#           (qkv): Linear(in_features=256, out_features=768, bias=True)
#           (proj): Linear(in_features=256, out_features=256, bias=True)
#           (cpb_mlp): Sequential(
#             (0): Linear(in_features=2, out_features=512, bias=True)
#             (1): ReLU(inplace=True)
#             (2): Linear(in_features=512, out_features=8, bias=False)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.043478260869565216, mode=row)
#         (norm2): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (0): Linear(in_features=256, out_features=1024, bias=True)
#           (1): GELU(approximate='none')
#           (2): Dropout(p=0.0, inplace=False)
#           (3): Linear(in_features=1024, out_features=256, bias=True)
#           (4): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (1): SwinTransformerBlockV2(
#         (norm1): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#         (attn): ShiftedWindowAttentionV2(
#           (qkv): Linear(in_features=256, out_features=768, bias=True)
#           (proj): Linear(in_features=256, out_features=256, bias=True)
#           (cpb_mlp): Sequential(
#             (0): Linear(in_features=2, out_features=512, bias=True)
#             (1): ReLU(inplace=True)
#             (2): Linear(in_features=512, out_features=8, bias=False)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.06521739130434782, mode=row)
#         (norm2): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (0): Linear(in_features=256, out_features=1024, bias=True)
#           (1): GELU(approximate='none')
#           (2): Dropout(p=0.0, inplace=False)
#           (3): Linear(in_features=1024, out_features=256, bias=True)
#           (4): Dropout(p=0.0, inplace=False)
#         )
#       )
#     )
#     (4): PatchMergingV2(
#       (reduction): Linear(in_features=1024, out_features=512, bias=False)
#       (norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#     )
#     (5): Sequential(
#       (0): SwinTransformerBlockV2(
#         (norm1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (attn): ShiftedWindowAttentionV2(
#           (qkv): Linear(in_features=512, out_features=1536, bias=True)
#           (proj): Linear(in_features=512, out_features=512, bias=True)
#           (cpb_mlp): Sequential(
#             (0): Linear(in_features=2, out_features=512, bias=True)
#             (1): ReLU(inplace=True)
#             (2): Linear(in_features=512, out_features=16, bias=False)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.08695652173913043, mode=row)
#         (norm2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (0): Linear(in_features=512, out_features=2048, bias=True)
#           (1): GELU(approximate='none')
#           (2): Dropout(p=0.0, inplace=False)
#           (3): Linear(in_features=2048, out_features=512, bias=True)
#           (4): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (1): SwinTransformerBlockV2(
#         (norm1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (attn): ShiftedWindowAttentionV2(
#           (qkv): Linear(in_features=512, out_features=1536, bias=True)
#           (proj): Linear(in_features=512, out_features=512, bias=True)
#           (cpb_mlp): Sequential(
#             (0): Linear(in_features=2, out_features=512, bias=True)
#             (1): ReLU(inplace=True)
#             (2): Linear(in_features=512, out_features=16, bias=False)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.10869565217391304, mode=row)
#         (norm2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (0): Linear(in_features=512, out_features=2048, bias=True)
#           (1): GELU(approximate='none')
#           (2): Dropout(p=0.0, inplace=False)
#           (3): Linear(in_features=2048, out_features=512, bias=True)
#           (4): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (2): SwinTransformerBlockV2(
#         (norm1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (attn): ShiftedWindowAttentionV2(
#           (qkv): Linear(in_features=512, out_features=1536, bias=True)
#           (proj): Linear(in_features=512, out_features=512, bias=True)
#           (cpb_mlp): Sequential(
#             (0): Linear(in_features=2, out_features=512, bias=True)
#             (1): ReLU(inplace=True)
#             (2): Linear(in_features=512, out_features=16, bias=False)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.13043478260869565, mode=row)
#         (norm2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (0): Linear(in_features=512, out_features=2048, bias=True)
#           (1): GELU(approximate='none')
#           (2): Dropout(p=0.0, inplace=False)
#           (3): Linear(in_features=2048, out_features=512, bias=True)
#           (4): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (3): SwinTransformerBlockV2(
#         (norm1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (attn): ShiftedWindowAttentionV2(
#           (qkv): Linear(in_features=512, out_features=1536, bias=True)
#           (proj): Linear(in_features=512, out_features=512, bias=True)
#           (cpb_mlp): Sequential(
#             (0): Linear(in_features=2, out_features=512, bias=True)
#             (1): ReLU(inplace=True)
#             (2): Linear(in_features=512, out_features=16, bias=False)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.15217391304347827, mode=row)
#         (norm2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (0): Linear(in_features=512, out_features=2048, bias=True)
#           (1): GELU(approximate='none')
#           (2): Dropout(p=0.0, inplace=False)
#           (3): Linear(in_features=2048, out_features=512, bias=True)
#           (4): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (4): SwinTransformerBlockV2(
#         (norm1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (attn): ShiftedWindowAttentionV2(
#           (qkv): Linear(in_features=512, out_features=1536, bias=True)
#           (proj): Linear(in_features=512, out_features=512, bias=True)
#           (cpb_mlp): Sequential(
#             (0): Linear(in_features=2, out_features=512, bias=True)
#             (1): ReLU(inplace=True)
#             (2): Linear(in_features=512, out_features=16, bias=False)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.17391304347826086, mode=row)
#         (norm2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (0): Linear(in_features=512, out_features=2048, bias=True)
#           (1): GELU(approximate='none')
#           (2): Dropout(p=0.0, inplace=False)
#           (3): Linear(in_features=2048, out_features=512, bias=True)
#           (4): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (5): SwinTransformerBlockV2(
#         (norm1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (attn): ShiftedWindowAttentionV2(
#           (qkv): Linear(in_features=512, out_features=1536, bias=True)
#           (proj): Linear(in_features=512, out_features=512, bias=True)
#           (cpb_mlp): Sequential(
#             (0): Linear(in_features=2, out_features=512, bias=True)
#             (1): ReLU(inplace=True)
#             (2): Linear(in_features=512, out_features=16, bias=False)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.1956521739130435, mode=row)
#         (norm2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (0): Linear(in_features=512, out_features=2048, bias=True)
#           (1): GELU(approximate='none')
#           (2): Dropout(p=0.0, inplace=False)
#           (3): Linear(in_features=2048, out_features=512, bias=True)
#           (4): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (6): SwinTransformerBlockV2(
#         (norm1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (attn): ShiftedWindowAttentionV2(
#           (qkv): Linear(in_features=512, out_features=1536, bias=True)
#           (proj): Linear(in_features=512, out_features=512, bias=True)
#           (cpb_mlp): Sequential(
#             (0): Linear(in_features=2, out_features=512, bias=True)
#             (1): ReLU(inplace=True)
#             (2): Linear(in_features=512, out_features=16, bias=False)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.21739130434782608, mode=row)
#         (norm2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (0): Linear(in_features=512, out_features=2048, bias=True)
#           (1): GELU(approximate='none')
#           (2): Dropout(p=0.0, inplace=False)
#           (3): Linear(in_features=2048, out_features=512, bias=True)
#           (4): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (7): SwinTransformerBlockV2(
#         (norm1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (attn): ShiftedWindowAttentionV2(
#           (qkv): Linear(in_features=512, out_features=1536, bias=True)
#           (proj): Linear(in_features=512, out_features=512, bias=True)
#           (cpb_mlp): Sequential(
#             (0): Linear(in_features=2, out_features=512, bias=True)
#             (1): ReLU(inplace=True)
#             (2): Linear(in_features=512, out_features=16, bias=False)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.2391304347826087, mode=row)
#         (norm2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (0): Linear(in_features=512, out_features=2048, bias=True)
#           (1): GELU(approximate='none')
#           (2): Dropout(p=0.0, inplace=False)
#           (3): Linear(in_features=2048, out_features=512, bias=True)
#           (4): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (8): SwinTransformerBlockV2(
#         (norm1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (attn): ShiftedWindowAttentionV2(
#           (qkv): Linear(in_features=512, out_features=1536, bias=True)
#           (proj): Linear(in_features=512, out_features=512, bias=True)
#           (cpb_mlp): Sequential(
#             (0): Linear(in_features=2, out_features=512, bias=True)
#             (1): ReLU(inplace=True)
#             (2): Linear(in_features=512, out_features=16, bias=False)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.2608695652173913, mode=row)
#         (norm2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (0): Linear(in_features=512, out_features=2048, bias=True)
#           (1): GELU(approximate='none')
#           (2): Dropout(p=0.0, inplace=False)
#           (3): Linear(in_features=2048, out_features=512, bias=True)
#           (4): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (9): SwinTransformerBlockV2(
#         (norm1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (attn): ShiftedWindowAttentionV2(
#           (qkv): Linear(in_features=512, out_features=1536, bias=True)
#           (proj): Linear(in_features=512, out_features=512, bias=True)
#           (cpb_mlp): Sequential(
#             (0): Linear(in_features=2, out_features=512, bias=True)
#             (1): ReLU(inplace=True)
#             (2): Linear(in_features=512, out_features=16, bias=False)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.2826086956521739, mode=row)
#         (norm2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (0): Linear(in_features=512, out_features=2048, bias=True)
#           (1): GELU(approximate='none')
#           (2): Dropout(p=0.0, inplace=False)
#           (3): Linear(in_features=2048, out_features=512, bias=True)
#           (4): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (10): SwinTransformerBlockV2(
#         (norm1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (attn): ShiftedWindowAttentionV2(
#           (qkv): Linear(in_features=512, out_features=1536, bias=True)
#           (proj): Linear(in_features=512, out_features=512, bias=True)
#           (cpb_mlp): Sequential(
#             (0): Linear(in_features=2, out_features=512, bias=True)
#             (1): ReLU(inplace=True)
#             (2): Linear(in_features=512, out_features=16, bias=False)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.30434782608695654, mode=row)
#         (norm2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (0): Linear(in_features=512, out_features=2048, bias=True)
#           (1): GELU(approximate='none')
#           (2): Dropout(p=0.0, inplace=False)
#           (3): Linear(in_features=2048, out_features=512, bias=True)
#           (4): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (11): SwinTransformerBlockV2(
#         (norm1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (attn): ShiftedWindowAttentionV2(
#           (qkv): Linear(in_features=512, out_features=1536, bias=True)
#           (proj): Linear(in_features=512, out_features=512, bias=True)
#           (cpb_mlp): Sequential(
#             (0): Linear(in_features=2, out_features=512, bias=True)
#             (1): ReLU(inplace=True)
#             (2): Linear(in_features=512, out_features=16, bias=False)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.32608695652173914, mode=row)
#         (norm2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (0): Linear(in_features=512, out_features=2048, bias=True)
#           (1): GELU(approximate='none')
#           (2): Dropout(p=0.0, inplace=False)
#           (3): Linear(in_features=2048, out_features=512, bias=True)
#           (4): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (12): SwinTransformerBlockV2(
#         (norm1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (attn): ShiftedWindowAttentionV2(
#           (qkv): Linear(in_features=512, out_features=1536, bias=True)
#           (proj): Linear(in_features=512, out_features=512, bias=True)
#           (cpb_mlp): Sequential(
#             (0): Linear(in_features=2, out_features=512, bias=True)
#             (1): ReLU(inplace=True)
#             (2): Linear(in_features=512, out_features=16, bias=False)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.34782608695652173, mode=row)
#         (norm2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (0): Linear(in_features=512, out_features=2048, bias=True)
#           (1): GELU(approximate='none')
#           (2): Dropout(p=0.0, inplace=False)
#           (3): Linear(in_features=2048, out_features=512, bias=True)
#           (4): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (13): SwinTransformerBlockV2(
#         (norm1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (attn): ShiftedWindowAttentionV2(
#           (qkv): Linear(in_features=512, out_features=1536, bias=True)
#           (proj): Linear(in_features=512, out_features=512, bias=True)
#           (cpb_mlp): Sequential(
#             (0): Linear(in_features=2, out_features=512, bias=True)
#             (1): ReLU(inplace=True)
#             (2): Linear(in_features=512, out_features=16, bias=False)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.3695652173913043, mode=row)
#         (norm2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (0): Linear(in_features=512, out_features=2048, bias=True)
#           (1): GELU(approximate='none')
#           (2): Dropout(p=0.0, inplace=False)
#           (3): Linear(in_features=2048, out_features=512, bias=True)
#           (4): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (14): SwinTransformerBlockV2(
#         (norm1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (attn): ShiftedWindowAttentionV2(
#           (qkv): Linear(in_features=512, out_features=1536, bias=True)
#           (proj): Linear(in_features=512, out_features=512, bias=True)
#           (cpb_mlp): Sequential(
#             (0): Linear(in_features=2, out_features=512, bias=True)
#             (1): ReLU(inplace=True)
#             (2): Linear(in_features=512, out_features=16, bias=False)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.391304347826087, mode=row)
#         (norm2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (0): Linear(in_features=512, out_features=2048, bias=True)
#           (1): GELU(approximate='none')
#           (2): Dropout(p=0.0, inplace=False)
#           (3): Linear(in_features=2048, out_features=512, bias=True)
#           (4): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (15): SwinTransformerBlockV2(
#         (norm1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (attn): ShiftedWindowAttentionV2(
#           (qkv): Linear(in_features=512, out_features=1536, bias=True)
#           (proj): Linear(in_features=512, out_features=512, bias=True)
#           (cpb_mlp): Sequential(
#             (0): Linear(in_features=2, out_features=512, bias=True)
#             (1): ReLU(inplace=True)
#             (2): Linear(in_features=512, out_features=16, bias=False)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.41304347826086957, mode=row)
#         (norm2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (0): Linear(in_features=512, out_features=2048, bias=True)
#           (1): GELU(approximate='none')
#           (2): Dropout(p=0.0, inplace=False)
#           (3): Linear(in_features=2048, out_features=512, bias=True)
#           (4): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (16): SwinTransformerBlockV2(
#         (norm1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (attn): ShiftedWindowAttentionV2(
#           (qkv): Linear(in_features=512, out_features=1536, bias=True)
#           (proj): Linear(in_features=512, out_features=512, bias=True)
#           (cpb_mlp): Sequential(
#             (0): Linear(in_features=2, out_features=512, bias=True)
#             (1): ReLU(inplace=True)
#             (2): Linear(in_features=512, out_features=16, bias=False)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.43478260869565216, mode=row)
#         (norm2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (0): Linear(in_features=512, out_features=2048, bias=True)
#           (1): GELU(approximate='none')
#           (2): Dropout(p=0.0, inplace=False)
#           (3): Linear(in_features=2048, out_features=512, bias=True)
#           (4): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (17): SwinTransformerBlockV2(
#         (norm1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (attn): ShiftedWindowAttentionV2(
#           (qkv): Linear(in_features=512, out_features=1536, bias=True)
#           (proj): Linear(in_features=512, out_features=512, bias=True)
#           (cpb_mlp): Sequential(
#             (0): Linear(in_features=2, out_features=512, bias=True)
#             (1): ReLU(inplace=True)
#             (2): Linear(in_features=512, out_features=16, bias=False)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.45652173913043476, mode=row)
#         (norm2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (0): Linear(in_features=512, out_features=2048, bias=True)
#           (1): GELU(approximate='none')
#           (2): Dropout(p=0.0, inplace=False)
#           (3): Linear(in_features=2048, out_features=512, bias=True)
#           (4): Dropout(p=0.0, inplace=False)
#         )
#       )
#     )
#     (6): PatchMergingV2(
#       (reduction): Linear(in_features=2048, out_features=1024, bias=False)
#       (norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#     )
#     (7): Sequential(
#       (0): SwinTransformerBlockV2(
#         (norm1): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         (attn): ShiftedWindowAttentionV2(
#           (qkv): Linear(in_features=1024, out_features=3072, bias=True)
#           (proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (cpb_mlp): Sequential(
#             (0): Linear(in_features=2, out_features=512, bias=True)
#             (1): ReLU(inplace=True)
#             (2): Linear(in_features=512, out_features=32, bias=False)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.4782608695652174, mode=row)
#         (norm2): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (0): Linear(in_features=1024, out_features=4096, bias=True)
#           (1): GELU(approximate='none')
#           (2): Dropout(p=0.0, inplace=False)
#           (3): Linear(in_features=4096, out_features=1024, bias=True)
#           (4): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (1): SwinTransformerBlockV2(
#         (norm1): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         (attn): ShiftedWindowAttentionV2(
#           (qkv): Linear(in_features=1024, out_features=3072, bias=True)
#           (proj): Linear(in_features=1024, out_features=1024, bias=True)
#           (cpb_mlp): Sequential(
#             (0): Linear(in_features=2, out_features=512, bias=True)
#             (1): ReLU(inplace=True)
#             (2): Linear(in_features=512, out_features=32, bias=False)
#           )
#         )
#         (stochastic_depth): StochasticDepth(p=0.5, mode=row)
#         (norm2): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#         (mlp): MLP(
#           (0): Linear(in_features=1024, out_features=4096, bias=True)
#           (1): GELU(approximate='none')
#           (2): Dropout(p=0.0, inplace=False)
#           (3): Linear(in_features=4096, out_features=1024, bias=True)
#           (4): Dropout(p=0.0, inplace=False)
#         )
#       )
#     )
#   )
#   (norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#   (permute): Permute()
#   (avgpool): AdaptiveAvgPool2d(output_size=1)
#   (flatten): Flatten(start_dim=1, end_dim=-1)
#   (head): Linear(in_features=1024, out_features=1000, bias=True)
# )

# %%
summary(model, [1,3,224,224])
# Out:
# =========================================================================================================
# Layer (type:depth-idx)                                  Output Shape              Param #
# =========================================================================================================
# SwinTransformer                                         [1, 1000]                 --
# ├─Sequential: 1-1                                       [1, 7, 7, 1024]           --
# │    └─Sequential: 2-1                                  [1, 56, 56, 128]          --
# │    │    └─Conv2d: 3-1                                 [1, 128, 56, 56]          6,272
# │    │    └─Permute: 3-2                                [1, 56, 56, 128]          --
# │    │    └─LayerNorm: 3-3                              [1, 56, 56, 128]          256
# │    └─Sequential: 2-2                                  [1, 56, 56, 128]          --
# │    │    └─SwinTransformerBlockV2: 3-4                 [1, 56, 56, 128]          201,860
# │    │    └─SwinTransformerBlockV2: 3-5                 [1, 56, 56, 128]          201,860
# │    └─PatchMergingV2: 2-3                              [1, 28, 28, 256]          --
# │    │    └─Linear: 3-6                                 [1, 28, 28, 256]          131,072
# │    │    └─LayerNorm: 3-7                              [1, 28, 28, 256]          512
# │    └─Sequential: 2-4                                  [1, 28, 28, 256]          --
# │    │    └─SwinTransformerBlockV2: 3-8                 [1, 28, 28, 256]          795,400
# │    │    └─SwinTransformerBlockV2: 3-9                 [1, 28, 28, 256]          795,400
# │    └─PatchMergingV2: 2-5                              [1, 14, 14, 512]          --
# │    │    └─Linear: 3-10                                [1, 14, 14, 512]          524,288
# │    │    └─LayerNorm: 3-11                             [1, 14, 14, 512]          1,024
# │    └─Sequential: 2-6                                  [1, 14, 14, 512]          --
# │    │    └─SwinTransformerBlockV2: 3-12                [1, 14, 14, 512]          3,162,128
# │    │    └─SwinTransformerBlockV2: 3-13                [1, 14, 14, 512]          3,162,128
# │    │    └─SwinTransformerBlockV2: 3-14                [1, 14, 14, 512]          3,162,128
# │    │    └─SwinTransformerBlockV2: 3-15                [1, 14, 14, 512]          3,162,128
# │    │    └─SwinTransformerBlockV2: 3-16                [1, 14, 14, 512]          3,162,128
# │    │    └─SwinTransformerBlockV2: 3-17                [1, 14, 14, 512]          3,162,128
# │    │    └─SwinTransformerBlockV2: 3-18                [1, 14, 14, 512]          3,162,128
# │    │    └─SwinTransformerBlockV2: 3-19                [1, 14, 14, 512]          3,162,128
# │    │    └─SwinTransformerBlockV2: 3-20                [1, 14, 14, 512]          3,162,128
# │    │    └─SwinTransformerBlockV2: 3-21                [1, 14, 14, 512]          3,162,128
# │    │    └─SwinTransformerBlockV2: 3-22                [1, 14, 14, 512]          3,162,128
# │    │    └─SwinTransformerBlockV2: 3-23                [1, 14, 14, 512]          3,162,128
# │    │    └─SwinTransformerBlockV2: 3-24                [1, 14, 14, 512]          3,162,128
# │    │    └─SwinTransformerBlockV2: 3-25                [1, 14, 14, 512]          3,162,128
# │    │    └─SwinTransformerBlockV2: 3-26                [1, 14, 14, 512]          3,162,128
# │    │    └─SwinTransformerBlockV2: 3-27                [1, 14, 14, 512]          3,162,128
# │    │    └─SwinTransformerBlockV2: 3-28                [1, 14, 14, 512]          3,162,128
# │    │    └─SwinTransformerBlockV2: 3-29                [1, 14, 14, 512]          3,162,128
# │    └─PatchMergingV2: 2-7                              [1, 7, 7, 1024]           --
# │    │    └─Linear: 3-30                                [1, 7, 7, 1024]           2,097,152
# │    │    └─LayerNorm: 3-31                             [1, 7, 7, 1024]           2,048
# │    └─Sequential: 2-8                                  [1, 7, 7, 1024]           --
# │    │    └─SwinTransformerBlockV2: 3-32                [1, 7, 7, 1024]           12,614,176
# │    │    └─SwinTransformerBlockV2: 3-33                [1, 7, 7, 1024]           12,614,176
# ├─LayerNorm: 1-2                                        [1, 7, 7, 1024]           2,048
# ├─Permute: 1-3                                          [1, 1024, 7, 7]           --
# ├─AdaptiveAvgPool2d: 1-4                                [1, 1024, 1, 1]           --
# ├─Flatten: 1-5                                          [1, 1024]                 --
# ├─Linear: 1-6                                           [1, 1000]                 1,025,000
# =========================================================================================================
# Total params: 87,930,848
# Trainable params: 87,930,848
# Non-trainable params: 0
# Total mult-adds (M): 79.63
# =========================================================================================================
# Input size (MB): 0.60
# Forward/backward pass size (MB): 209.46
# Params size (MB): 239.86
# Estimated Total Size (MB): 449.92
# =========================================================================================================

# %%
# Freeze parameters of pre-trained layers to prevent overwriting during fine-tuning:
for param in model.parameters():
    param.requires_grad = False

# %%
# Replace the final classification head with a new one for 38 classes
num_classes = 38  # Adjust to your actual number of classes

model.head = nn.Linear(in_features=1024, out_features=num_classes, bias=True)
model = torch.nn.DataParallel(model, device_ids = [0,1]).to(device)

# %%
summary(model, [1,3,224,224])
# Out:
# ==============================================================================================================
# Layer (type:depth-idx)                                       Output Shape              Param #
# ==============================================================================================================
# DataParallel                                                 [1, 38]                   --
# ├─SwinTransformer: 1-1                                       [1, 38]                   86,944,798
# ├─SwinTransformer: 1-2                                       --                        --
# │    └─Sequential: 2-1                                       [1, 7, 7, 1024]           86,903,800
# │    └─Sequential: 2-2                                       --                        --
# │    │    └─Sequential: 3-1                                  [1, 56, 56, 128]          (6,528)
# │    │    └─Sequential: 3-2                                  --                        (6,528)
# │    │    └─Sequential: 3-3                                  [1, 56, 56, 128]          (403,720)
# │    │    └─Sequential: 3-4                                  --                        (403,720)
# │    │    └─PatchMergingV2: 3-5                              [1, 28, 28, 256]          (131,584)
# │    │    └─PatchMergingV2: 3-6                              --                        (131,584)
# │    │    └─Sequential: 3-7                                  [1, 28, 28, 256]          (1,590,800)
# │    │    └─Sequential: 3-8                                  --                        (1,590,800)
# │    │    └─PatchMergingV2: 3-9                              [1, 14, 14, 512]          (525,312)
# │    │    └─PatchMergingV2: 3-10                             --                        (525,312)
# │    │    └─Sequential: 3-11                                 [1, 14, 14, 512]          (56,918,304)
# │    │    └─Sequential: 3-12                                 --                        (56,918,304)
# │    │    └─PatchMergingV2: 3-13                             [1, 7, 7, 1024]           (2,099,200)
# │    │    └─PatchMergingV2: 3-14                             --                        (2,099,200)
# │    │    └─Sequential: 3-15                                 [1, 7, 7, 1024]           (25,228,352)
# │    │    └─Sequential: 3-16                                 --                        (25,228,352)
# │    └─LayerNorm: 2-3                                        [1, 7, 7, 1024]           (2,048)
# │    └─Permute: 2-4                                          [1, 1024, 7, 7]           --
# │    └─AdaptiveAvgPool2d: 2-5                                [1, 1024, 1, 1]           --
# │    └─Flatten: 2-6                                          [1, 1024]                 --
# │    └─Linear: 2-7                                           [1, 38]                   38,950
# ==============================================================================================================
# Total params: 515,931,420
# Trainable params: 77,900
# Non-trainable params: 515,853,520
# Total mult-adds (M): 78.64
# ==============================================================================================================
# Input size (MB): 0.60
# Forward/backward pass size (MB): 209.45
# Params size (MB): 235.91
# Estimated Total Size (MB): 445.96
# ==============================================================================================================

# %%
###############################################################################################
model_state_dict_path = "/kaggle/input/stv2100epochs/stv2_model_state_dict_100.pth"  # Adjust the filename if needed

# Check if the state dictionary file exists
if os.path.isfile(model_state_dict_path):
    print("Found state dictionary file:", model_state_dict_path)

    # Load the state dictionary
    try:
        model_state_dict = torch.load(model_state_dict_path)
        model.load_state_dict(model_state_dict)
        print("Loaded state dictionary successfully!")
    except Exception as e:
        print(f"Error loading state dictionary: {e}")
else:
    print("No state dictionary file found at", model_state_dict_path)
    
###############################################################################################
# Out:
# Found state dictionary file: /kaggle/input/stv2100epochs/stv2_model_state_dict_100.pth
# Loaded state dictionary successfully!

# %%
loss_fn = torch.nn.CrossEntropyLoss()  # Common choice for multi-class classification
optimizer = torch.optim.SGD(model.parameters(), lr=0.001, momentum=0.9)  # Only optimize unfrozen layers, By default it will be requires_grad=True

# %%
model
# Out:
# DataParallel(
#   (module): SwinTransformer(
#     (features): Sequential(
#       (0): Sequential(
#         (0): Conv2d(3, 128, kernel_size=(4, 4), stride=(4, 4))
#         (1): Permute()
#         (2): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#       )
#       (1): Sequential(
#         (0): SwinTransformerBlockV2(
#           (norm1): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#           (attn): ShiftedWindowAttentionV2(
#             (qkv): Linear(in_features=128, out_features=384, bias=True)
#             (proj): Linear(in_features=128, out_features=128, bias=True)
#             (cpb_mlp): Sequential(
#               (0): Linear(in_features=2, out_features=512, bias=True)
#               (1): ReLU(inplace=True)
#               (2): Linear(in_features=512, out_features=4, bias=False)
#             )
#           )
#           (stochastic_depth): StochasticDepth(p=0.0, mode=row)
#           (norm2): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#           (mlp): MLP(
#             (0): Linear(in_features=128, out_features=512, bias=True)
#             (1): GELU(approximate='none')
#             (2): Dropout(p=0.0, inplace=False)
#             (3): Linear(in_features=512, out_features=128, bias=True)
#             (4): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (1): SwinTransformerBlockV2(
#           (norm1): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#           (attn): ShiftedWindowAttentionV2(
#             (qkv): Linear(in_features=128, out_features=384, bias=True)
#             (proj): Linear(in_features=128, out_features=128, bias=True)
#             (cpb_mlp): Sequential(
#               (0): Linear(in_features=2, out_features=512, bias=True)
#               (1): ReLU(inplace=True)
#               (2): Linear(in_features=512, out_features=4, bias=False)
#             )
#           )
#           (stochastic_depth): StochasticDepth(p=0.021739130434782608, mode=row)
#           (norm2): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#           (mlp): MLP(
#             (0): Linear(in_features=128, out_features=512, bias=True)
#             (1): GELU(approximate='none')
#             (2): Dropout(p=0.0, inplace=False)
#             (3): Linear(in_features=512, out_features=128, bias=True)
#             (4): Dropout(p=0.0, inplace=False)
#           )
#         )
#       )
#       (2): PatchMergingV2(
#         (reduction): Linear(in_features=512, out_features=256, bias=False)
#         (norm): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#       )
#       (3): Sequential(
#         (0): SwinTransformerBlockV2(
#           (norm1): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (attn): ShiftedWindowAttentionV2(
#             (qkv): Linear(in_features=256, out_features=768, bias=True)
#             (proj): Linear(in_features=256, out_features=256, bias=True)
#             (cpb_mlp): Sequential(
#               (0): Linear(in_features=2, out_features=512, bias=True)
#               (1): ReLU(inplace=True)
#               (2): Linear(in_features=512, out_features=8, bias=False)
#             )
#           )
#           (stochastic_depth): StochasticDepth(p=0.043478260869565216, mode=row)
#           (norm2): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (mlp): MLP(
#             (0): Linear(in_features=256, out_features=1024, bias=True)
#             (1): GELU(approximate='none')
#             (2): Dropout(p=0.0, inplace=False)
#             (3): Linear(in_features=1024, out_features=256, bias=True)
#             (4): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (1): SwinTransformerBlockV2(
#           (norm1): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (attn): ShiftedWindowAttentionV2(
#             (qkv): Linear(in_features=256, out_features=768, bias=True)
#             (proj): Linear(in_features=256, out_features=256, bias=True)
#             (cpb_mlp): Sequential(
#               (0): Linear(in_features=2, out_features=512, bias=True)
#               (1): ReLU(inplace=True)
#               (2): Linear(in_features=512, out_features=8, bias=False)
#             )
#           )
#           (stochastic_depth): StochasticDepth(p=0.06521739130434782, mode=row)
#           (norm2): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#           (mlp): MLP(
#             (0): Linear(in_features=256, out_features=1024, bias=True)
#             (1): GELU(approximate='none')
#             (2): Dropout(p=0.0, inplace=False)
#             (3): Linear(in_features=1024, out_features=256, bias=True)
#             (4): Dropout(p=0.0, inplace=False)
#           )
#         )
#       )
#       (4): PatchMergingV2(
#         (reduction): Linear(in_features=1024, out_features=512, bias=False)
#         (norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#       )
#       (5): Sequential(
#         (0): SwinTransformerBlockV2(
#           (norm1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (attn): ShiftedWindowAttentionV2(
#             (qkv): Linear(in_features=512, out_features=1536, bias=True)
#             (proj): Linear(in_features=512, out_features=512, bias=True)
#             (cpb_mlp): Sequential(
#               (0): Linear(in_features=2, out_features=512, bias=True)
#               (1): ReLU(inplace=True)
#               (2): Linear(in_features=512, out_features=16, bias=False)
#             )
#           )
#           (stochastic_depth): StochasticDepth(p=0.08695652173913043, mode=row)
#           (norm2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (mlp): MLP(
#             (0): Linear(in_features=512, out_features=2048, bias=True)
#             (1): GELU(approximate='none')
#             (2): Dropout(p=0.0, inplace=False)
#             (3): Linear(in_features=2048, out_features=512, bias=True)
#             (4): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (1): SwinTransformerBlockV2(
#           (norm1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (attn): ShiftedWindowAttentionV2(
#             (qkv): Linear(in_features=512, out_features=1536, bias=True)
#             (proj): Linear(in_features=512, out_features=512, bias=True)
#             (cpb_mlp): Sequential(
#               (0): Linear(in_features=2, out_features=512, bias=True)
#               (1): ReLU(inplace=True)
#               (2): Linear(in_features=512, out_features=16, bias=False)
#             )
#           )
#           (stochastic_depth): StochasticDepth(p=0.10869565217391304, mode=row)
#           (norm2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (mlp): MLP(
#             (0): Linear(in_features=512, out_features=2048, bias=True)
#             (1): GELU(approximate='none')
#             (2): Dropout(p=0.0, inplace=False)
#             (3): Linear(in_features=2048, out_features=512, bias=True)
#             (4): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (2): SwinTransformerBlockV2(
#           (norm1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (attn): ShiftedWindowAttentionV2(
#             (qkv): Linear(in_features=512, out_features=1536, bias=True)
#             (proj): Linear(in_features=512, out_features=512, bias=True)
#             (cpb_mlp): Sequential(
#               (0): Linear(in_features=2, out_features=512, bias=True)
#               (1): ReLU(inplace=True)
#               (2): Linear(in_features=512, out_features=16, bias=False)
#             )
#           )
#           (stochastic_depth): StochasticDepth(p=0.13043478260869565, mode=row)
#           (norm2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (mlp): MLP(
#             (0): Linear(in_features=512, out_features=2048, bias=True)
#             (1): GELU(approximate='none')
#             (2): Dropout(p=0.0, inplace=False)
#             (3): Linear(in_features=2048, out_features=512, bias=True)
#             (4): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (3): SwinTransformerBlockV2(
#           (norm1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (attn): ShiftedWindowAttentionV2(
#             (qkv): Linear(in_features=512, out_features=1536, bias=True)
#             (proj): Linear(in_features=512, out_features=512, bias=True)
#             (cpb_mlp): Sequential(
#               (0): Linear(in_features=2, out_features=512, bias=True)
#               (1): ReLU(inplace=True)
#               (2): Linear(in_features=512, out_features=16, bias=False)
#             )
#           )
#           (stochastic_depth): StochasticDepth(p=0.15217391304347827, mode=row)
#           (norm2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (mlp): MLP(
#             (0): Linear(in_features=512, out_features=2048, bias=True)
#             (1): GELU(approximate='none')
#             (2): Dropout(p=0.0, inplace=False)
#             (3): Linear(in_features=2048, out_features=512, bias=True)
#             (4): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (4): SwinTransformerBlockV2(
#           (norm1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (attn): ShiftedWindowAttentionV2(
#             (qkv): Linear(in_features=512, out_features=1536, bias=True)
#             (proj): Linear(in_features=512, out_features=512, bias=True)
#             (cpb_mlp): Sequential(
#               (0): Linear(in_features=2, out_features=512, bias=True)
#               (1): ReLU(inplace=True)
#               (2): Linear(in_features=512, out_features=16, bias=False)
#             )
#           )
#           (stochastic_depth): StochasticDepth(p=0.17391304347826086, mode=row)
#           (norm2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (mlp): MLP(
#             (0): Linear(in_features=512, out_features=2048, bias=True)
#             (1): GELU(approximate='none')
#             (2): Dropout(p=0.0, inplace=False)
#             (3): Linear(in_features=2048, out_features=512, bias=True)
#             (4): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (5): SwinTransformerBlockV2(
#           (norm1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (attn): ShiftedWindowAttentionV2(
#             (qkv): Linear(in_features=512, out_features=1536, bias=True)
#             (proj): Linear(in_features=512, out_features=512, bias=True)
#             (cpb_mlp): Sequential(
#               (0): Linear(in_features=2, out_features=512, bias=True)
#               (1): ReLU(inplace=True)
#               (2): Linear(in_features=512, out_features=16, bias=False)
#             )
#           )
#           (stochastic_depth): StochasticDepth(p=0.1956521739130435, mode=row)
#           (norm2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (mlp): MLP(
#             (0): Linear(in_features=512, out_features=2048, bias=True)
#             (1): GELU(approximate='none')
#             (2): Dropout(p=0.0, inplace=False)
#             (3): Linear(in_features=2048, out_features=512, bias=True)
#             (4): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (6): SwinTransformerBlockV2(
#           (norm1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (attn): ShiftedWindowAttentionV2(
#             (qkv): Linear(in_features=512, out_features=1536, bias=True)
#             (proj): Linear(in_features=512, out_features=512, bias=True)
#             (cpb_mlp): Sequential(
#               (0): Linear(in_features=2, out_features=512, bias=True)
#               (1): ReLU(inplace=True)
#               (2): Linear(in_features=512, out_features=16, bias=False)
#             )
#           )
#           (stochastic_depth): StochasticDepth(p=0.21739130434782608, mode=row)
#           (norm2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (mlp): MLP(
#             (0): Linear(in_features=512, out_features=2048, bias=True)
#             (1): GELU(approximate='none')
#             (2): Dropout(p=0.0, inplace=False)
#             (3): Linear(in_features=2048, out_features=512, bias=True)
#             (4): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (7): SwinTransformerBlockV2(
#           (norm1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (attn): ShiftedWindowAttentionV2(
#             (qkv): Linear(in_features=512, out_features=1536, bias=True)
#             (proj): Linear(in_features=512, out_features=512, bias=True)
#             (cpb_mlp): Sequential(
#               (0): Linear(in_features=2, out_features=512, bias=True)
#               (1): ReLU(inplace=True)
#               (2): Linear(in_features=512, out_features=16, bias=False)
#             )
#           )
#           (stochastic_depth): StochasticDepth(p=0.2391304347826087, mode=row)
#           (norm2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (mlp): MLP(
#             (0): Linear(in_features=512, out_features=2048, bias=True)
#             (1): GELU(approximate='none')
#             (2): Dropout(p=0.0, inplace=False)
#             (3): Linear(in_features=2048, out_features=512, bias=True)
#             (4): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (8): SwinTransformerBlockV2(
#           (norm1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (attn): ShiftedWindowAttentionV2(
#             (qkv): Linear(in_features=512, out_features=1536, bias=True)
#             (proj): Linear(in_features=512, out_features=512, bias=True)
#             (cpb_mlp): Sequential(
#               (0): Linear(in_features=2, out_features=512, bias=True)
#               (1): ReLU(inplace=True)
#               (2): Linear(in_features=512, out_features=16, bias=False)
#             )
#           )
#           (stochastic_depth): StochasticDepth(p=0.2608695652173913, mode=row)
#           (norm2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (mlp): MLP(
#             (0): Linear(in_features=512, out_features=2048, bias=True)
#             (1): GELU(approximate='none')
#             (2): Dropout(p=0.0, inplace=False)
#             (3): Linear(in_features=2048, out_features=512, bias=True)
#             (4): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (9): SwinTransformerBlockV2(
#           (norm1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (attn): ShiftedWindowAttentionV2(
#             (qkv): Linear(in_features=512, out_features=1536, bias=True)
#             (proj): Linear(in_features=512, out_features=512, bias=True)
#             (cpb_mlp): Sequential(
#               (0): Linear(in_features=2, out_features=512, bias=True)
#               (1): ReLU(inplace=True)
#               (2): Linear(in_features=512, out_features=16, bias=False)
#             )
#           )
#           (stochastic_depth): StochasticDepth(p=0.2826086956521739, mode=row)
#           (norm2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (mlp): MLP(
#             (0): Linear(in_features=512, out_features=2048, bias=True)
#             (1): GELU(approximate='none')
#             (2): Dropout(p=0.0, inplace=False)
#             (3): Linear(in_features=2048, out_features=512, bias=True)
#             (4): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (10): SwinTransformerBlockV2(
#           (norm1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (attn): ShiftedWindowAttentionV2(
#             (qkv): Linear(in_features=512, out_features=1536, bias=True)
#             (proj): Linear(in_features=512, out_features=512, bias=True)
#             (cpb_mlp): Sequential(
#               (0): Linear(in_features=2, out_features=512, bias=True)
#               (1): ReLU(inplace=True)
#               (2): Linear(in_features=512, out_features=16, bias=False)
#             )
#           )
#           (stochastic_depth): StochasticDepth(p=0.30434782608695654, mode=row)
#           (norm2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (mlp): MLP(
#             (0): Linear(in_features=512, out_features=2048, bias=True)
#             (1): GELU(approximate='none')
#             (2): Dropout(p=0.0, inplace=False)
#             (3): Linear(in_features=2048, out_features=512, bias=True)
#             (4): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (11): SwinTransformerBlockV2(
#           (norm1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (attn): ShiftedWindowAttentionV2(
#             (qkv): Linear(in_features=512, out_features=1536, bias=True)
#             (proj): Linear(in_features=512, out_features=512, bias=True)
#             (cpb_mlp): Sequential(
#               (0): Linear(in_features=2, out_features=512, bias=True)
#               (1): ReLU(inplace=True)
#               (2): Linear(in_features=512, out_features=16, bias=False)
#             )
#           )
#           (stochastic_depth): StochasticDepth(p=0.32608695652173914, mode=row)
#           (norm2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (mlp): MLP(
#             (0): Linear(in_features=512, out_features=2048, bias=True)
#             (1): GELU(approximate='none')
#             (2): Dropout(p=0.0, inplace=False)
#             (3): Linear(in_features=2048, out_features=512, bias=True)
#             (4): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (12): SwinTransformerBlockV2(
#           (norm1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (attn): ShiftedWindowAttentionV2(
#             (qkv): Linear(in_features=512, out_features=1536, bias=True)
#             (proj): Linear(in_features=512, out_features=512, bias=True)
#             (cpb_mlp): Sequential(
#               (0): Linear(in_features=2, out_features=512, bias=True)
#               (1): ReLU(inplace=True)
#               (2): Linear(in_features=512, out_features=16, bias=False)
#             )
#           )
#           (stochastic_depth): StochasticDepth(p=0.34782608695652173, mode=row)
#           (norm2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (mlp): MLP(
#             (0): Linear(in_features=512, out_features=2048, bias=True)
#             (1): GELU(approximate='none')
#             (2): Dropout(p=0.0, inplace=False)
#             (3): Linear(in_features=2048, out_features=512, bias=True)
#             (4): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (13): SwinTransformerBlockV2(
#           (norm1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (attn): ShiftedWindowAttentionV2(
#             (qkv): Linear(in_features=512, out_features=1536, bias=True)
#             (proj): Linear(in_features=512, out_features=512, bias=True)
#             (cpb_mlp): Sequential(
#               (0): Linear(in_features=2, out_features=512, bias=True)
#               (1): ReLU(inplace=True)
#               (2): Linear(in_features=512, out_features=16, bias=False)
#             )
#           )
#           (stochastic_depth): StochasticDepth(p=0.3695652173913043, mode=row)
#           (norm2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (mlp): MLP(
#             (0): Linear(in_features=512, out_features=2048, bias=True)
#             (1): GELU(approximate='none')
#             (2): Dropout(p=0.0, inplace=False)
#             (3): Linear(in_features=2048, out_features=512, bias=True)
#             (4): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (14): SwinTransformerBlockV2(
#           (norm1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (attn): ShiftedWindowAttentionV2(
#             (qkv): Linear(in_features=512, out_features=1536, bias=True)
#             (proj): Linear(in_features=512, out_features=512, bias=True)
#             (cpb_mlp): Sequential(
#               (0): Linear(in_features=2, out_features=512, bias=True)
#               (1): ReLU(inplace=True)
#               (2): Linear(in_features=512, out_features=16, bias=False)
#             )
#           )
#           (stochastic_depth): StochasticDepth(p=0.391304347826087, mode=row)
#           (norm2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (mlp): MLP(
#             (0): Linear(in_features=512, out_features=2048, bias=True)
#             (1): GELU(approximate='none')
#             (2): Dropout(p=0.0, inplace=False)
#             (3): Linear(in_features=2048, out_features=512, bias=True)
#             (4): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (15): SwinTransformerBlockV2(
#           (norm1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (attn): ShiftedWindowAttentionV2(
#             (qkv): Linear(in_features=512, out_features=1536, bias=True)
#             (proj): Linear(in_features=512, out_features=512, bias=True)
#             (cpb_mlp): Sequential(
#               (0): Linear(in_features=2, out_features=512, bias=True)
#               (1): ReLU(inplace=True)
#               (2): Linear(in_features=512, out_features=16, bias=False)
#             )
#           )
#           (stochastic_depth): StochasticDepth(p=0.41304347826086957, mode=row)
#           (norm2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (mlp): MLP(
#             (0): Linear(in_features=512, out_features=2048, bias=True)
#             (1): GELU(approximate='none')
#             (2): Dropout(p=0.0, inplace=False)
#             (3): Linear(in_features=2048, out_features=512, bias=True)
#             (4): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (16): SwinTransformerBlockV2(
#           (norm1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (attn): ShiftedWindowAttentionV2(
#             (qkv): Linear(in_features=512, out_features=1536, bias=True)
#             (proj): Linear(in_features=512, out_features=512, bias=True)
#             (cpb_mlp): Sequential(
#               (0): Linear(in_features=2, out_features=512, bias=True)
#               (1): ReLU(inplace=True)
#               (2): Linear(in_features=512, out_features=16, bias=False)
#             )
#           )
#           (stochastic_depth): StochasticDepth(p=0.43478260869565216, mode=row)
#           (norm2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (mlp): MLP(
#             (0): Linear(in_features=512, out_features=2048, bias=True)
#             (1): GELU(approximate='none')
#             (2): Dropout(p=0.0, inplace=False)
#             (3): Linear(in_features=2048, out_features=512, bias=True)
#             (4): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (17): SwinTransformerBlockV2(
#           (norm1): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (attn): ShiftedWindowAttentionV2(
#             (qkv): Linear(in_features=512, out_features=1536, bias=True)
#             (proj): Linear(in_features=512, out_features=512, bias=True)
#             (cpb_mlp): Sequential(
#               (0): Linear(in_features=2, out_features=512, bias=True)
#               (1): ReLU(inplace=True)
#               (2): Linear(in_features=512, out_features=16, bias=False)
#             )
#           )
#           (stochastic_depth): StochasticDepth(p=0.45652173913043476, mode=row)
#           (norm2): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#           (mlp): MLP(
#             (0): Linear(in_features=512, out_features=2048, bias=True)
#             (1): GELU(approximate='none')
#             (2): Dropout(p=0.0, inplace=False)
#             (3): Linear(in_features=2048, out_features=512, bias=True)
#             (4): Dropout(p=0.0, inplace=False)
#           )
#         )
#       )
#       (6): PatchMergingV2(
#         (reduction): Linear(in_features=2048, out_features=1024, bias=False)
#         (norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#       )
#       (7): Sequential(
#         (0): SwinTransformerBlockV2(
#           (norm1): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (attn): ShiftedWindowAttentionV2(
#             (qkv): Linear(in_features=1024, out_features=3072, bias=True)
#             (proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (cpb_mlp): Sequential(
#               (0): Linear(in_features=2, out_features=512, bias=True)
#               (1): ReLU(inplace=True)
#               (2): Linear(in_features=512, out_features=32, bias=False)
#             )
#           )
#           (stochastic_depth): StochasticDepth(p=0.4782608695652174, mode=row)
#           (norm2): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (mlp): MLP(
#             (0): Linear(in_features=1024, out_features=4096, bias=True)
#             (1): GELU(approximate='none')
#             (2): Dropout(p=0.0, inplace=False)
#             (3): Linear(in_features=4096, out_features=1024, bias=True)
#             (4): Dropout(p=0.0, inplace=False)
#           )
#         )
#         (1): SwinTransformerBlockV2(
#           (norm1): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (attn): ShiftedWindowAttentionV2(
#             (qkv): Linear(in_features=1024, out_features=3072, bias=True)
#             (proj): Linear(in_features=1024, out_features=1024, bias=True)
#             (cpb_mlp): Sequential(
#               (0): Linear(in_features=2, out_features=512, bias=True)
#               (1): ReLU(inplace=True)
#               (2): Linear(in_features=512, out_features=32, bias=False)
#             )
#           )
#           (stochastic_depth): StochasticDepth(p=0.5, mode=row)
#           (norm2): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#           (mlp): MLP(
#             (0): Linear(in_features=1024, out_features=4096, bias=True)
#             (1): GELU(approximate='none')
#             (2): Dropout(p=0.0, inplace=False)
#             (3): Linear(in_features=4096, out_features=1024, bias=True)
#             (4): Dropout(p=0.0, inplace=False)
#           )
#         )
#       )
#     )
#     (norm): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#     (permute): Permute()
#     (avgpool): AdaptiveAvgPool2d(output_size=1)
#     (flatten): Flatten(start_dim=1, end_dim=-1)
#     (head): Linear(in_features=1024, out_features=38, bias=True)
#   )
# )

# %%
summary(model, [1,3,224,224])
# Out:
# ==============================================================================================================
# Layer (type:depth-idx)                                       Output Shape              Param #
# ==============================================================================================================
# DataParallel                                                 [1, 38]                   --
# ├─SwinTransformer: 1-1                                       [1, 38]                   86,944,798
# ├─SwinTransformer: 1-2                                       --                        --
# │    └─Sequential: 2-1                                       [1, 7, 7, 1024]           86,903,800
# │    └─Sequential: 2-2                                       --                        --
# │    │    └─Sequential: 3-1                                  [1, 56, 56, 128]          (6,528)
# │    │    └─Sequential: 3-2                                  --                        (6,528)
# │    │    └─Sequential: 3-3                                  [1, 56, 56, 128]          (403,720)
# │    │    └─Sequential: 3-4                                  --                        (403,720)
# │    │    └─PatchMergingV2: 3-5                              [1, 28, 28, 256]          (131,584)
# │    │    └─PatchMergingV2: 3-6                              --                        (131,584)
# │    │    └─Sequential: 3-7                                  [1, 28, 28, 256]          (1,590,800)
# │    │    └─Sequential: 3-8                                  --                        (1,590,800)
# │    │    └─PatchMergingV2: 3-9                              [1, 14, 14, 512]          (525,312)
# │    │    └─PatchMergingV2: 3-10                             --                        (525,312)
# │    │    └─Sequential: 3-11                                 [1, 14, 14, 512]          (56,918,304)
# │    │    └─Sequential: 3-12                                 --                        (56,918,304)
# │    │    └─PatchMergingV2: 3-13                             [1, 7, 7, 1024]           (2,099,200)
# │    │    └─PatchMergingV2: 3-14                             --                        (2,099,200)
# │    │    └─Sequential: 3-15                                 [1, 7, 7, 1024]           (25,228,352)
# │    │    └─Sequential: 3-16                                 --                        (25,228,352)
# │    └─LayerNorm: 2-3                                        [1, 7, 7, 1024]           (2,048)
# │    └─Permute: 2-4                                          [1, 1024, 7, 7]           --
# │    └─AdaptiveAvgPool2d: 2-5                                [1, 1024, 1, 1]           --
# │    └─Flatten: 2-6                                          [1, 1024]                 --
# │    └─Linear: 2-7                                           [1, 38]                   38,950
# ==============================================================================================================
# Total params: 515,931,420
# Trainable params: 77,900
# Non-trainable params: 515,853,520
# Total mult-adds (M): 78.64
# ==============================================================================================================
# Input size (MB): 0.60
# Forward/backward pass size (MB): 209.45
# Params size (MB): 235.91
# Estimated Total Size (MB): 445.96
# ==============================================================================================================

# %%
def check_requires_grad(model):
  """
  This function iterates through the model and prints information
  about requires_grad for each module and its parameters.
  """
  for name, param in model.named_parameters():
    if param.requires_grad:
      print(f"{name}: requires_grad=True")
    else:
      print(f"{name}: requires_grad=False")

# Example usage
check_requires_grad(model)
# Out:
# module.features.0.0.weight: requires_grad=False
# module.features.0.0.bias: requires_grad=False
# module.features.0.2.weight: requires_grad=False
# module.features.0.2.bias: requires_grad=False
# module.features.1.0.norm1.weight: requires_grad=False
# module.features.1.0.norm1.bias: requires_grad=False
# module.features.1.0.attn.logit_scale: requires_grad=False
# module.features.1.0.attn.qkv.weight: requires_grad=False
# module.features.1.0.attn.qkv.bias: requires_grad=False
# module.features.1.0.attn.proj.weight: requires_grad=False
# module.features.1.0.attn.proj.bias: requires_grad=False
# module.features.1.0.attn.cpb_mlp.0.weight: requires_grad=False
# module.features.1.0.attn.cpb_mlp.0.bias: requires_grad=False
# module.features.1.0.attn.cpb_mlp.2.weight: requires_grad=False
# module.features.1.0.norm2.weight: requires_grad=False
# module.features.1.0.norm2.bias: requires_grad=False
# module.features.1.0.mlp.0.weight: requires_grad=False
# module.features.1.0.mlp.0.bias: requires_grad=False
# module.features.1.0.mlp.3.weight: requires_grad=False
# module.features.1.0.mlp.3.bias: requires_grad=False
# module.features.1.1.norm1.weight: requires_grad=False
# module.features.1.1.norm1.bias: requires_grad=False
# module.features.1.1.attn.logit_scale: requires_grad=False
# module.features.1.1.attn.qkv.weight: requires_grad=False
# module.features.1.1.attn.qkv.bias: requires_grad=False
# module.features.1.1.attn.proj.weight: requires_grad=False
# module.features.1.1.attn.proj.bias: requires_grad=False
# module.features.1.1.attn.cpb_mlp.0.weight: requires_grad=False
# module.features.1.1.attn.cpb_mlp.0.bias: requires_grad=False
# module.features.1.1.attn.cpb_mlp.2.weight: requires_grad=False
# module.features.1.1.norm2.weight: requires_grad=False
# module.features.1.1.norm2.bias: requires_grad=False
# module.features.1.1.mlp.0.weight: requires_grad=False
# module.features.1.1.mlp.0.bias: requires_grad=False
# module.features.1.1.mlp.3.weight: requires_grad=False
# module.features.1.1.mlp.3.bias: requires_grad=False
# module.features.2.reduction.weight: requires_grad=False
# module.features.2.norm.weight: requires_grad=False
# module.features.2.norm.bias: requires_grad=False
# module.features.3.0.norm1.weight: requires_grad=False
# module.features.3.0.norm1.bias: requires_grad=False
# module.features.3.0.attn.logit_scale: requires_grad=False
# module.features.3.0.attn.qkv.weight: requires_grad=False
# module.features.3.0.attn.qkv.bias: requires_grad=False
# module.features.3.0.attn.proj.weight: requires_grad=False
# module.features.3.0.attn.proj.bias: requires_grad=False
# module.features.3.0.attn.cpb_mlp.0.weight: requires_grad=False
# module.features.3.0.attn.cpb_mlp.0.bias: requires_grad=False
# module.features.3.0.attn.cpb_mlp.2.weight: requires_grad=False
# module.features.3.0.norm2.weight: requires_grad=False
# module.features.3.0.norm2.bias: requires_grad=False
# module.features.3.0.mlp.0.weight: requires_grad=False
# module.features.3.0.mlp.0.bias: requires_grad=False
# module.features.3.0.mlp.3.weight: requires_grad=False
# module.features.3.0.mlp.3.bias: requires_grad=False
# module.features.3.1.norm1.weight: requires_grad=False
# module.features.3.1.norm1.bias: requires_grad=False
# module.features.3.1.attn.logit_scale: requires_grad=False
# module.features.3.1.attn.qkv.weight: requires_grad=False
# module.features.3.1.attn.qkv.bias: requires_grad=False
# module.features.3.1.attn.proj.weight: requires_grad=False
# module.features.3.1.attn.proj.bias: requires_grad=False
# module.features.3.1.attn.cpb_mlp.0.weight: requires_grad=False
# module.features.3.1.attn.cpb_mlp.0.bias: requires_grad=False
# module.features.3.1.attn.cpb_mlp.2.weight: requires_grad=False
# module.features.3.1.norm2.weight: requires_grad=False
# module.features.3.1.norm2.bias: requires_grad=False
# module.features.3.1.mlp.0.weight: requires_grad=False
# module.features.3.1.mlp.0.bias: requires_grad=False
# module.features.3.1.mlp.3.weight: requires_grad=False
# module.features.3.1.mlp.3.bias: requires_grad=False
# module.features.4.reduction.weight: requires_grad=False
# module.features.4.norm.weight: requires_grad=False
# module.features.4.norm.bias: requires_grad=False
# module.features.5.0.norm1.weight: requires_grad=False
# module.features.5.0.norm1.bias: requires_grad=False
# module.features.5.0.attn.logit_scale: requires_grad=False
# module.features.5.0.attn.qkv.weight: requires_grad=False
# module.features.5.0.attn.qkv.bias: requires_grad=False
# module.features.5.0.attn.proj.weight: requires_grad=False
# module.features.5.0.attn.proj.bias: requires_grad=False
# module.features.5.0.attn.cpb_mlp.0.weight: requires_grad=False
# module.features.5.0.attn.cpb_mlp.0.bias: requires_grad=False
# module.features.5.0.attn.cpb_mlp.2.weight: requires_grad=False
# module.features.5.0.norm2.weight: requires_grad=False
# module.features.5.0.norm2.bias: requires_grad=False
# module.features.5.0.mlp.0.weight: requires_grad=False
# module.features.5.0.mlp.0.bias: requires_grad=False
# module.features.5.0.mlp.3.weight: requires_grad=False
# module.features.5.0.mlp.3.bias: requires_grad=False
# module.features.5.1.norm1.weight: requires_grad=False
# module.features.5.1.norm1.bias: requires_grad=False
# module.features.5.1.attn.logit_scale: requires_grad=False
# module.features.5.1.attn.qkv.weight: requires_grad=False
# module.features.5.1.attn.qkv.bias: requires_grad=False
# module.features.5.1.attn.proj.weight: requires_grad=False
# module.features.5.1.attn.proj.bias: requires_grad=False
# module.features.5.1.attn.cpb_mlp.0.weight: requires_grad=False
# module.features.5.1.attn.cpb_mlp.0.bias: requires_grad=False
# module.features.5.1.attn.cpb_mlp.2.weight: requires_grad=False
# module.features.5.1.norm2.weight: requires_grad=False
# module.features.5.1.norm2.bias: requires_grad=False
# module.features.5.1.mlp.0.weight: requires_grad=False
# module.features.5.1.mlp.0.bias: requires_grad=False
# module.features.5.1.mlp.3.weight: requires_grad=False
# module.features.5.1.mlp.3.bias: requires_grad=False
# module.features.5.2.norm1.weight: requires_grad=False
# module.features.5.2.norm1.bias: requires_grad=False
# module.features.5.2.attn.logit_scale: requires_grad=False
# module.features.5.2.attn.qkv.weight: requires_grad=False
# module.features.5.2.attn.qkv.bias: requires_grad=False
# module.features.5.2.attn.proj.weight: requires_grad=False
# module.features.5.2.attn.proj.bias: requires_grad=False
# module.features.5.2.attn.cpb_mlp.0.weight: requires_grad=False
# module.features.5.2.attn.cpb_mlp.0.bias: requires_grad=False
# module.features.5.2.attn.cpb_mlp.2.weight: requires_grad=False
# module.features.5.2.norm2.weight: requires_grad=False
# module.features.5.2.norm2.bias: requires_grad=False
# module.features.5.2.mlp.0.weight: requires_grad=False
# module.features.5.2.mlp.0.bias: requires_grad=False
# module.features.5.2.mlp.3.weight: requires_grad=False
# module.features.5.2.mlp.3.bias: requires_grad=False
# module.features.5.3.norm1.weight: requires_grad=False
# module.features.5.3.norm1.bias: requires_grad=False
# module.features.5.3.attn.logit_scale: requires_grad=False
# module.features.5.3.attn.qkv.weight: requires_grad=False
# module.features.5.3.attn.qkv.bias: requires_grad=False
# module.features.5.3.attn.proj.weight: requires_grad=False
# module.features.5.3.attn.proj.bias: requires_grad=False
# module.features.5.3.attn.cpb_mlp.0.weight: requires_grad=False
# module.features.5.3.attn.cpb_mlp.0.bias: requires_grad=False
# module.features.5.3.attn.cpb_mlp.2.weight: requires_grad=False
# module.features.5.3.norm2.weight: requires_grad=False
# module.features.5.3.norm2.bias: requires_grad=False
# module.features.5.3.mlp.0.weight: requires_grad=False
# module.features.5.3.mlp.0.bias: requires_grad=False
# module.features.5.3.mlp.3.weight: requires_grad=False
# module.features.5.3.mlp.3.bias: requires_grad=False
# module.features.5.4.norm1.weight: requires_grad=False
# module.features.5.4.norm1.bias: requires_grad=False
# module.features.5.4.attn.logit_scale: requires_grad=False
# module.features.5.4.attn.qkv.weight: requires_grad=False
# module.features.5.4.attn.qkv.bias: requires_grad=False
# module.features.5.4.attn.proj.weight: requires_grad=False
# module.features.5.4.attn.proj.bias: requires_grad=False
# module.features.5.4.attn.cpb_mlp.0.weight: requires_grad=False
# module.features.5.4.attn.cpb_mlp.0.bias: requires_grad=False
# module.features.5.4.attn.cpb_mlp.2.weight: requires_grad=False
# module.features.5.4.norm2.weight: requires_grad=False
# module.features.5.4.norm2.bias: requires_grad=False
# module.features.5.4.mlp.0.weight: requires_grad=False
# module.features.5.4.mlp.0.bias: requires_grad=False
# module.features.5.4.mlp.3.weight: requires_grad=False
# module.features.5.4.mlp.3.bias: requires_grad=False
# module.features.5.5.norm1.weight: requires_grad=False
# module.features.5.5.norm1.bias: requires_grad=False
# module.features.5.5.attn.logit_scale: requires_grad=False
# module.features.5.5.attn.qkv.weight: requires_grad=False
# module.features.5.5.attn.qkv.bias: requires_grad=False
# module.features.5.5.attn.proj.weight: requires_grad=False
# module.features.5.5.attn.proj.bias: requires_grad=False
# module.features.5.5.attn.cpb_mlp.0.weight: requires_grad=False
# module.features.5.5.attn.cpb_mlp.0.bias: requires_grad=False
# module.features.5.5.attn.cpb_mlp.2.weight: requires_grad=False
# module.features.5.5.norm2.weight: requires_grad=False
# module.features.5.5.norm2.bias: requires_grad=False
# module.features.5.5.mlp.0.weight: requires_grad=False
# module.features.5.5.mlp.0.bias: requires_grad=False
# module.features.5.5.mlp.3.weight: requires_grad=False
# module.features.5.5.mlp.3.bias: requires_grad=False
# module.features.5.6.norm1.weight: requires_grad=False
# module.features.5.6.norm1.bias: requires_grad=False
# module.features.5.6.attn.logit_scale: requires_grad=False
# module.features.5.6.attn.qkv.weight: requires_grad=False
# module.features.5.6.attn.qkv.bias: requires_grad=False
# module.features.5.6.attn.proj.weight: requires_grad=False
# module.features.5.6.attn.proj.bias: requires_grad=False
# module.features.5.6.attn.cpb_mlp.0.weight: requires_grad=False
# module.features.5.6.attn.cpb_mlp.0.bias: requires_grad=False
# module.features.5.6.attn.cpb_mlp.2.weight: requires_grad=False
# module.features.5.6.norm2.weight: requires_grad=False
# module.features.5.6.norm2.bias: requires_grad=False
# module.features.5.6.mlp.0.weight: requires_grad=False
# module.features.5.6.mlp.0.bias: requires_grad=False
# module.features.5.6.mlp.3.weight: requires_grad=False
# module.features.5.6.mlp.3.bias: requires_grad=False
# module.features.5.7.norm1.weight: requires_grad=False
# module.features.5.7.norm1.bias: requires_grad=False
# module.features.5.7.attn.logit_scale: requires_grad=False
# module.features.5.7.attn.qkv.weight: requires_grad=False
# module.features.5.7.attn.qkv.bias: requires_grad=False
# module.features.5.7.attn.proj.weight: requires_grad=False
# module.features.5.7.attn.proj.bias: requires_grad=False
# module.features.5.7.attn.cpb_mlp.0.weight: requires_grad=False
# module.features.5.7.attn.cpb_mlp.0.bias: requires_grad=False
# module.features.5.7.attn.cpb_mlp.2.weight: requires_grad=False
# module.features.5.7.norm2.weight: requires_grad=False
# module.features.5.7.norm2.bias: requires_grad=False
# module.features.5.7.mlp.0.weight: requires_grad=False
# module.features.5.7.mlp.0.bias: requires_grad=False
# module.features.5.7.mlp.3.weight: requires_grad=False
# module.features.5.7.mlp.3.bias: requires_grad=False
# module.features.5.8.norm1.weight: requires_grad=False
# module.features.5.8.norm1.bias: requires_grad=False
# module.features.5.8.attn.logit_scale: requires_grad=False
# module.features.5.8.attn.qkv.weight: requires_grad=False
# module.features.5.8.attn.qkv.bias: requires_grad=False
# module.features.5.8.attn.proj.weight: requires_grad=False
# module.features.5.8.attn.proj.bias: requires_grad=False
# module.features.5.8.attn.cpb_mlp.0.weight: requires_grad=False
# module.features.5.8.attn.cpb_mlp.0.bias: requires_grad=False
# module.features.5.8.attn.cpb_mlp.2.weight: requires_grad=False
# module.features.5.8.norm2.weight: requires_grad=False
# module.features.5.8.norm2.bias: requires_grad=False
# module.features.5.8.mlp.0.weight: requires_grad=False
# module.features.5.8.mlp.0.bias: requires_grad=False
# module.features.5.8.mlp.3.weight: requires_grad=False
# module.features.5.8.mlp.3.bias: requires_grad=False
# module.features.5.9.norm1.weight: requires_grad=False
# module.features.5.9.norm1.bias: requires_grad=False
# module.features.5.9.attn.logit_scale: requires_grad=False
# module.features.5.9.attn.qkv.weight: requires_grad=False
# module.features.5.9.attn.qkv.bias: requires_grad=False
# module.features.5.9.attn.proj.weight: requires_grad=False
# module.features.5.9.attn.proj.bias: requires_grad=False
# module.features.5.9.attn.cpb_mlp.0.weight: requires_grad=False
# module.features.5.9.attn.cpb_mlp.0.bias: requires_grad=False
# module.features.5.9.attn.cpb_mlp.2.weight: requires_grad=False
# module.features.5.9.norm2.weight: requires_grad=False
# module.features.5.9.norm2.bias: requires_grad=False
# module.features.5.9.mlp.0.weight: requires_grad=False
# module.features.5.9.mlp.0.bias: requires_grad=False
# module.features.5.9.mlp.3.weight: requires_grad=False
# module.features.5.9.mlp.3.bias: requires_grad=False
# module.features.5.10.norm1.weight: requires_grad=False
# module.features.5.10.norm1.bias: requires_grad=False
# module.features.5.10.attn.logit_scale: requires_grad=False
# module.features.5.10.attn.qkv.weight: requires_grad=False
# module.features.5.10.attn.qkv.bias: requires_grad=False
# module.features.5.10.attn.proj.weight: requires_grad=False
# module.features.5.10.attn.proj.bias: requires_grad=False
# module.features.5.10.attn.cpb_mlp.0.weight: requires_grad=False
# module.features.5.10.attn.cpb_mlp.0.bias: requires_grad=False
# module.features.5.10.attn.cpb_mlp.2.weight: requires_grad=False
# module.features.5.10.norm2.weight: requires_grad=False
# module.features.5.10.norm2.bias: requires_grad=False
# module.features.5.10.mlp.0.weight: requires_grad=False
# module.features.5.10.mlp.0.bias: requires_grad=False
# module.features.5.10.mlp.3.weight: requires_grad=False
# module.features.5.10.mlp.3.bias: requires_grad=False
# module.features.5.11.norm1.weight: requires_grad=False
# module.features.5.11.norm1.bias: requires_grad=False
# module.features.5.11.attn.logit_scale: requires_grad=False
# module.features.5.11.attn.qkv.weight: requires_grad=False
# module.features.5.11.attn.qkv.bias: requires_grad=False
# module.features.5.11.attn.proj.weight: requires_grad=False
# module.features.5.11.attn.proj.bias: requires_grad=False
# module.features.5.11.attn.cpb_mlp.0.weight: requires_grad=False
# module.features.5.11.attn.cpb_mlp.0.bias: requires_grad=False
# module.features.5.11.attn.cpb_mlp.2.weight: requires_grad=False
# module.features.5.11.norm2.weight: requires_grad=False
# module.features.5.11.norm2.bias: requires_grad=False
# module.features.5.11.mlp.0.weight: requires_grad=False
# module.features.5.11.mlp.0.bias: requires_grad=False
# module.features.5.11.mlp.3.weight: requires_grad=False
# module.features.5.11.mlp.3.bias: requires_grad=False
# module.features.5.12.norm1.weight: requires_grad=False
# module.features.5.12.norm1.bias: requires_grad=False
# module.features.5.12.attn.logit_scale: requires_grad=False
# module.features.5.12.attn.qkv.weight: requires_grad=False
# module.features.5.12.attn.qkv.bias: requires_grad=False
# module.features.5.12.attn.proj.weight: requires_grad=False
# module.features.5.12.attn.proj.bias: requires_grad=False
# module.features.5.12.attn.cpb_mlp.0.weight: requires_grad=False
# module.features.5.12.attn.cpb_mlp.0.bias: requires_grad=False
# module.features.5.12.attn.cpb_mlp.2.weight: requires_grad=False
# module.features.5.12.norm2.weight: requires_grad=False
# module.features.5.12.norm2.bias: requires_grad=False
# module.features.5.12.mlp.0.weight: requires_grad=False
# module.features.5.12.mlp.0.bias: requires_grad=False
# module.features.5.12.mlp.3.weight: requires_grad=False
# module.features.5.12.mlp.3.bias: requires_grad=False
# module.features.5.13.norm1.weight: requires_grad=False
# module.features.5.13.norm1.bias: requires_grad=False
# module.features.5.13.attn.logit_scale: requires_grad=False
# module.features.5.13.attn.qkv.weight: requires_grad=False
# module.features.5.13.attn.qkv.bias: requires_grad=False
# module.features.5.13.attn.proj.weight: requires_grad=False
# module.features.5.13.attn.proj.bias: requires_grad=False
# module.features.5.13.attn.cpb_mlp.0.weight: requires_grad=False
# module.features.5.13.attn.cpb_mlp.0.bias: requires_grad=False
# module.features.5.13.attn.cpb_mlp.2.weight: requires_grad=False
# module.features.5.13.norm2.weight: requires_grad=False
# module.features.5.13.norm2.bias: requires_grad=False
# module.features.5.13.mlp.0.weight: requires_grad=False
# module.features.5.13.mlp.0.bias: requires_grad=False
# module.features.5.13.mlp.3.weight: requires_grad=False
# module.features.5.13.mlp.3.bias: requires_grad=False
# module.features.5.14.norm1.weight: requires_grad=False
# module.features.5.14.norm1.bias: requires_grad=False
# module.features.5.14.attn.logit_scale: requires_grad=False
# module.features.5.14.attn.qkv.weight: requires_grad=False
# module.features.5.14.attn.qkv.bias: requires_grad=False
# module.features.5.14.attn.proj.weight: requires_grad=False
# module.features.5.14.attn.proj.bias: requires_grad=False
# module.features.5.14.attn.cpb_mlp.0.weight: requires_grad=False
# module.features.5.14.attn.cpb_mlp.0.bias: requires_grad=False
# module.features.5.14.attn.cpb_mlp.2.weight: requires_grad=False
# module.features.5.14.norm2.weight: requires_grad=False
# module.features.5.14.norm2.bias: requires_grad=False
# module.features.5.14.mlp.0.weight: requires_grad=False
# module.features.5.14.mlp.0.bias: requires_grad=False
# module.features.5.14.mlp.3.weight: requires_grad=False
# module.features.5.14.mlp.3.bias: requires_grad=False
# module.features.5.15.norm1.weight: requires_grad=False
# module.features.5.15.norm1.bias: requires_grad=False
# module.features.5.15.attn.logit_scale: requires_grad=False
# module.features.5.15.attn.qkv.weight: requires_grad=False
# module.features.5.15.attn.qkv.bias: requires_grad=False
# module.features.5.15.attn.proj.weight: requires_grad=False
# module.features.5.15.attn.proj.bias: requires_grad=False
# module.features.5.15.attn.cpb_mlp.0.weight: requires_grad=False
# module.features.5.15.attn.cpb_mlp.0.bias: requires_grad=False
# module.features.5.15.attn.cpb_mlp.2.weight: requires_grad=False
# module.features.5.15.norm2.weight: requires_grad=False
# module.features.5.15.norm2.bias: requires_grad=False
# module.features.5.15.mlp.0.weight: requires_grad=False
# module.features.5.15.mlp.0.bias: requires_grad=False
# module.features.5.15.mlp.3.weight: requires_grad=False
# module.features.5.15.mlp.3.bias: requires_grad=False
# module.features.5.16.norm1.weight: requires_grad=False
# module.features.5.16.norm1.bias: requires_grad=False
# module.features.5.16.attn.logit_scale: requires_grad=False
# module.features.5.16.attn.qkv.weight: requires_grad=False
# module.features.5.16.attn.qkv.bias: requires_grad=False
# module.features.5.16.attn.proj.weight: requires_grad=False
# module.features.5.16.attn.proj.bias: requires_grad=False
# module.features.5.16.attn.cpb_mlp.0.weight: requires_grad=False
# module.features.5.16.attn.cpb_mlp.0.bias: requires_grad=False
# module.features.5.16.attn.cpb_mlp.2.weight: requires_grad=False
# module.features.5.16.norm2.weight: requires_grad=False
# module.features.5.16.norm2.bias: requires_grad=False
# module.features.5.16.mlp.0.weight: requires_grad=False
# module.features.5.16.mlp.0.bias: requires_grad=False
# module.features.5.16.mlp.3.weight: requires_grad=False
# module.features.5.16.mlp.3.bias: requires_grad=False
# module.features.5.17.norm1.weight: requires_grad=False
# module.features.5.17.norm1.bias: requires_grad=False
# module.features.5.17.attn.logit_scale: requires_grad=False
# module.features.5.17.attn.qkv.weight: requires_grad=False
# module.features.5.17.attn.qkv.bias: requires_grad=False
# module.features.5.17.attn.proj.weight: requires_grad=False
# module.features.5.17.attn.proj.bias: requires_grad=False
# module.features.5.17.attn.cpb_mlp.0.weight: requires_grad=False
# module.features.5.17.attn.cpb_mlp.0.bias: requires_grad=False
# module.features.5.17.attn.cpb_mlp.2.weight: requires_grad=False
# module.features.5.17.norm2.weight: requires_grad=False
# module.features.5.17.norm2.bias: requires_grad=False
# module.features.5.17.mlp.0.weight: requires_grad=False
# module.features.5.17.mlp.0.bias: requires_grad=False
# module.features.5.17.mlp.3.weight: requires_grad=False
# module.features.5.17.mlp.3.bias: requires_grad=False
# module.features.6.reduction.weight: requires_grad=False
# module.features.6.norm.weight: requires_grad=False
# module.features.6.norm.bias: requires_grad=False
# module.features.7.0.norm1.weight: requires_grad=False
# module.features.7.0.norm1.bias: requires_grad=False
# module.features.7.0.attn.logit_scale: requires_grad=False
# module.features.7.0.attn.qkv.weight: requires_grad=False
# module.features.7.0.attn.qkv.bias: requires_grad=False
# module.features.7.0.attn.proj.weight: requires_grad=False
# module.features.7.0.attn.proj.bias: requires_grad=False
# module.features.7.0.attn.cpb_mlp.0.weight: requires_grad=False
# module.features.7.0.attn.cpb_mlp.0.bias: requires_grad=False
# module.features.7.0.attn.cpb_mlp.2.weight: requires_grad=False
# module.features.7.0.norm2.weight: requires_grad=False
# module.features.7.0.norm2.bias: requires_grad=False
# module.features.7.0.mlp.0.weight: requires_grad=False
# module.features.7.0.mlp.0.bias: requires_grad=False
# module.features.7.0.mlp.3.weight: requires_grad=False
# module.features.7.0.mlp.3.bias: requires_grad=False
# module.features.7.1.norm1.weight: requires_grad=False
# module.features.7.1.norm1.bias: requires_grad=False
# module.features.7.1.attn.logit_scale: requires_grad=False
# module.features.7.1.attn.qkv.weight: requires_grad=False
# module.features.7.1.attn.qkv.bias: requires_grad=False
# module.features.7.1.attn.proj.weight: requires_grad=False
# module.features.7.1.attn.proj.bias: requires_grad=False
# module.features.7.1.attn.cpb_mlp.0.weight: requires_grad=False
# module.features.7.1.attn.cpb_mlp.0.bias: requires_grad=False
# module.features.7.1.attn.cpb_mlp.2.weight: requires_grad=False
# module.features.7.1.norm2.weight: requires_grad=False
# module.features.7.1.norm2.bias: requires_grad=False
# module.features.7.1.mlp.0.weight: requires_grad=False
# module.features.7.1.mlp.0.bias: requires_grad=False
# module.features.7.1.mlp.3.weight: requires_grad=False
# module.features.7.1.mlp.3.bias: requires_grad=False
# module.norm.weight: requires_grad=False
# module.norm.bias: requires_grad=False
# module.head.weight: requires_grad=True
# module.head.bias: requires_grad=True

# %% [markdown]
# ### Creating `train_step()` & `test_step()` functions

# %%
def train_step(model: torch.nn.Module,
               dataloader: torch.utils.data.DataLoader,
               loss_fn: torch.nn.Module,
               optimizer: torch.optim.Optimizer):
  # Put the model on the training mode
  model.train()

  # setup train loss and accuracy(evaluation metrics)
  train_loss, train_acc = 0, 0

  # loop through the dataloader
  for batch, (X, y, _) in enumerate(dataloader):
    # send data to the target device
    X, y = X.to(device), y.to(device)

    # 1. Forward pass
    y_pred = model(X)

    # 2. Calculate the loss
    loss = loss_fn(y_pred, y)
    train_loss += loss.item()

    # 3. Optimizer zero grad
    optimizer.zero_grad()

    # 4. backprop
    loss.backward()

    # 5. optimizer step
    optimizer.step()

    # Calculate the accuracy
    y_pred_class = torch.argmax(torch.softmax(y_pred,dim=1),dim=1)
    train_acc += (y_pred_class == y).sum().item() / len(y_pred)

  # Adjust the train_loss and train_acc per batch
  train_loss /= len(dataloader)
  train_acc /= len(dataloader)

  return train_loss, train_acc

# %%
# Create a test step
def test_step(model: torch.nn.Module,
              dataloader: torch.utils.data.DataLoader,
              loss_fn: torch.nn.Module):

  # setup evaluation metrics
  test_loss, test_acc = 0, 0
  cm = ConfusionMatrix(task='multiclass',num_classes=len(class_names)).to(device)

  # set to training mode
  model.eval()
  with torch.inference_mode():
    for batch, (X, y, _) in enumerate(dataloader):
      # put data on target device
      X, y = X.to(device), y.to(device)

      # forward pass
      test_pred_logits = model(X)

      # calculate the loss
      loss = loss_fn(test_pred_logits, y)
      test_loss += loss.item()

      # calculate the accuracy
      test_pred_labels = test_pred_logits.argmax(dim=1)
      test_acc += ((test_pred_labels == y).sum().item()/len(test_pred_labels))
        
      # confusion matrix
      cm.update(test_pred_labels, y)

  # Normalize the confusion matrix
  cm = cm.compute().cpu().numpy()
    
  # Calculate precision, recall, and F1-score
  precision = np.diag(cm) / np.sum(cm, axis=0)
  recall = np.diag(cm) / np.sum(cm, axis=1)
  f1 = 2 * (precision * recall) / (precision + recall)
    
  # Average precision, recall, and F1-score across classes
  avg_precision = np.mean(precision)
  avg_recall = np.mean(recall)
  avg_f1 = np.mean(f1)

  # adjust test_loss and test_acc to batch
  test_loss /= len(dataloader)
  test_acc /= len(dataloader)

  return test_loss, test_acc, cm, avg_precision, avg_recall, avg_f1

# %%
num_classes=len(class_names)

# %%
num_classes
# Out:
# 38

# %%
def plot_confusion_matrix(cm, class_names):
    """
    Plots the confusion matrix using Seaborn's heatmap function.
    
    Parameters:
        cm (numpy.ndarray): Confusion matrix.
        class_names (list): List of class names.
    """
    plt.figure(figsize=(10, 8))
    sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=class_names, yticklabels=class_names)
    plt.xlabel('Predicted Labels')
    plt.ylabel('True Labels')
    plt.title('Confusion Matrix')
    plt.show()

# %% [markdown]
# ### Creating a `train()` function to combine `train_step()` & `test_step()`

# %%
from tqdm.auto import tqdm

def train(model: torch.nn.Module,
          train_dataloader: torch.utils.data.DataLoader,
          test_dataloader: torch.utils.data.DataLoader,
          optimizer: torch.optim.Optimizer,
          loss_fn: torch.nn.Module = nn.CrossEntropyLoss(),
          epochs: int=5):
    
  #scheduler = lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.1, patience=lr_scheduler_patience, verbose=True)

  # Create empty results dictionary
  results = {"train_loss":[],
             "train_acc":[],
             "test_loss":[],
             "test_acc":[]}
  
  test_confusion_matrices = []  # List to store confusion matrices for each epoch

  # loop through train and test loops for no. of epochs
  for epoch in tqdm(range(epochs)):
    train_loss, train_acc = train_step(model=model,
                                       dataloader=train_dataloader,
                                       loss_fn=loss_fn,
                                       optimizer=optimizer)
    test_loss, test_acc, cm, precision, recall, f1  = test_step(model=model,
                                                                dataloader=test_dataloader,
                                                                loss_fn=loss_fn)
    
    
        
    # Update the learning rate based on the test loss
    #scheduler.step(test_loss)
            
    # Print out whats happening
    print(f"Epoch: {epoch+1} | Train loss: {train_loss:.4f} | Train acc: {train_acc:.4f} | Test loss: {test_loss:.4f} | Test acc: {test_acc:.4f} | Test Precision: {precision.mean():.4f} | Test Recall: {recall.mean():.4f} | Test F1 Score: {f1.mean():.4f}")
    
    # update the results dictionary
    results["train_loss"].append(train_loss),
    results["train_acc"].append(train_acc),
    results["test_loss"].append(test_loss),
    results["test_acc"].append(test_acc),
    
    # Store confusion matrix for this epoch
    test_confusion_matrices.append(cm)
    

  # Print the final confusion matrix
  print("Final Test Confusion Matrix:\n")
  plot_confusion_matrix(test_confusion_matrices[-1], class_names)

  # Return filled results at the end of the epoch
  return results

# %%
# set random seeds
torch.manual_seed(42)
torch.cuda.manual_seed(42)

# set the no. of epochs
EPOCHS = 25

# optimizer and loss function are already set way above

# start the timer
from timeit import default_timer as timer
start_time = timer()

# Train model_0
model_0_results = train(model = model,
          train_dataloader = train_dataloader,
          test_dataloader =  test_dataloader,
          optimizer = optimizer,
          loss_fn = loss_fn,
          epochs = EPOCHS)

# End the timer and print how long it took
end_time = timer()
print(f"Total training time: {end_time - start_time: .3f} seconds")
# Out:
#   0%|          | 0/25 [00:00<?, ?it/s]
# Epoch: 1 | Train loss: 0.2336 | Train acc: 0.9335 | Test loss: 0.0861 | Test acc: 0.9803 | Test Precision: 0.9806 | Test Recall: 0.9800 | Test F1 Score: 0.9801
# Epoch: 2 | Train loss: 0.2320 | Train acc: 0.9336 | Test loss: 0.0846 | Test acc: 0.9811 | Test Precision: 0.9812 | Test Recall: 0.9809 | Test F1 Score: 0.9809
# Epoch: 3 | Train loss: 0.2295 | Train acc: 0.9338 | Test loss: 0.0845 | Test acc: 0.9809 | Test Precision: 0.9808 | Test Recall: 0.9807 | Test F1 Score: 0.9806
# Epoch: 4 | Train loss: 0.2324 | Train acc: 0.9338 | Test loss: 0.0848 | Test acc: 0.9803 | Test Precision: 0.9806 | Test Recall: 0.9801 | Test F1 Score: 0.9802
# Epoch: 5 | Train loss: 0.2315 | Train acc: 0.9331 | Test loss: 0.0837 | Test acc: 0.9811 | Test Precision: 0.9812 | Test Recall: 0.9808 | Test F1 Score: 0.9809
# Epoch: 6 | Train loss: 0.2334 | Train acc: 0.9339 | Test loss: 0.0843 | Test acc: 0.9808 | Test Precision: 0.9810 | Test Recall: 0.9805 | Test F1 Score: 0.9806
# Epoch: 7 | Train loss: 0.2298 | Train acc: 0.9343 | Test loss: 0.0841 | Test acc: 0.9807 | Test Precision: 0.9810 | Test Recall: 0.9805 | Test F1 Score: 0.9806
# Epoch: 8 | Train loss: 0.2300 | Train acc: 0.9334 | Test loss: 0.0838 | Test acc: 0.9805 | Test Precision: 0.9807 | Test Recall: 0.9802 | Test F1 Score: 0.9803
# Epoch: 9 | Train loss: 0.2266 | Train acc: 0.9354 | Test loss: 0.0844 | Test acc: 0.9803 | Test Precision: 0.9806 | Test Recall: 0.9802 | Test F1 Score: 0.9802
# Epoch: 10 | Train loss: 0.2294 | Train acc: 0.9344 | Test loss: 0.0831 | Test acc: 0.9809 | Test Precision: 0.9809 | Test Recall: 0.9806 | Test F1 Score: 0.9806
# Epoch: 11 | Train loss: 0.2308 | Train acc: 0.9337 | Test loss: 0.0832 | Test acc: 0.9812 | Test Precision: 0.9814 | Test Recall: 0.9810 | Test F1 Score: 0.9810
# Epoch: 12 | Train loss: 0.2282 | Train acc: 0.9348 | Test loss: 0.0832 | Test acc: 0.9808 | Test Precision: 0.9810 | Test Recall: 0.9805 | Test F1 Score: 0.9806
# Epoch: 13 | Train loss: 0.2265 | Train acc: 0.9356 | Test loss: 0.0822 | Test acc: 0.9812 | Test Precision: 0.9813 | Test Recall: 0.9810 | Test F1 Score: 0.9810
# Epoch: 14 | Train loss: 0.2303 | Train acc: 0.9338 | Test loss: 0.0817 | Test acc: 0.9809 | Test Precision: 0.9812 | Test Recall: 0.9806 | Test F1 Score: 0.9807
# Epoch: 15 | Train loss: 0.2287 | Train acc: 0.9341 | Test loss: 0.0822 | Test acc: 0.9810 | Test Precision: 0.9812 | Test Recall: 0.9807 | Test F1 Score: 0.9808
# Epoch: 16 | Train loss: 0.2317 | Train acc: 0.9333 | Test loss: 0.0823 | Test acc: 0.9810 | Test Precision: 0.9810 | Test Recall: 0.9808 | Test F1 Score: 0.9807
# Epoch: 17 | Train loss: 0.2269 | Train acc: 0.9341 | Test loss: 0.0807 | Test acc: 0.9819 | Test Precision: 0.9819 | Test Recall: 0.9817 | Test F1 Score: 0.9817
# Epoch: 18 | Train loss: 0.2263 | Train acc: 0.9352 | Test loss: 0.0809 | Test acc: 0.9816 | Test Precision: 0.9816 | Test Recall: 0.9814 | Test F1 Score: 0.9814
# Epoch: 19 | Train loss: 0.2262 | Train acc: 0.9348 | Test loss: 0.0805 | Test acc: 0.9817 | Test Precision: 0.9818 | Test Recall: 0.9815 | Test F1 Score: 0.9815
# Epoch: 20 | Train loss: 0.2263 | Train acc: 0.9347 | Test loss: 0.0808 | Test acc: 0.9812 | Test Precision: 0.9812 | Test Recall: 0.9811 | Test F1 Score: 0.9810
# Epoch: 21 | Train loss: 0.2283 | Train acc: 0.9333 | Test loss: 0.0807 | Test acc: 0.9812 | Test Precision: 0.9814 | Test Recall: 0.9810 | Test F1 Score: 0.9810
# Epoch: 22 | Train loss: 0.2238 | Train acc: 0.9347 | Test loss: 0.0812 | Test acc: 0.9815 | Test Precision: 0.9817 | Test Recall: 0.9813 | Test F1 Score: 0.9813
# Epoch: 23 | Train loss: 0.2235 | Train acc: 0.9354 | Test loss: 0.0806 | Test acc: 0.9808 | Test Precision: 0.9811 | Test Recall: 0.9805 | Test F1 Score: 0.9806
# Epoch: 24 | Train loss: 0.2282 | Train acc: 0.9338 | Test loss: 0.0797 | Test acc: 0.9819 | Test Precision: 0.9819 | Test Recall: 0.9817 | Test F1 Score: 0.9817
# Epoch: 25 | Train loss: 0.2262 | Train acc: 0.9349 | Test loss: 0.0805 | Test acc: 0.9815 | Test Precision: 0.9817 | Test Recall: 0.9812 | Test F1 Score: 0.9813
# Final Test Confusion Matrix:
# Total training time:  21839.518 seconds

# %%
for batch_data in train_dataloader:
    inputs, labels, class_labels = batch_data
    print("Input tensor shape:", inputs.shape)
    print("Labels tensor shape:", labels.shape)
    print("Class labels:", class_labels)
    break  # Only print the first batch
# Out:
# Input tensor shape: torch.Size([32, 3, 224, 224])
# Labels tensor shape: torch.Size([32])
# Class labels: ('Strawberry___Leaf_scorch', 'Tomato___Target_Spot', 'Pepper,_bell___Bacterial_spot', 'Corn_(maize)___Cercospora_leaf_spot Gray_leaf_spot', 'Orange___Haunglongbing_(Citrus_greening)', 'Tomato___Tomato_mosaic_virus', 'Peach___healthy', 'Corn_(maize)___healthy', 'Apple___healthy', 'Tomato___Early_blight', 'Grape___Leaf_blight_(Isariopsis_Leaf_Spot)', 'Corn_(maize)___Northern_Leaf_Blight', 'Apple___Cedar_apple_rust', 'Tomato___Late_blight', 'Peach___Bacterial_spot', 'Apple___Black_rot', 'Apple___Apple_scab', 'Grape___healthy', 'Grape___Leaf_blight_(Isariopsis_Leaf_Spot)', 'Peach___Bacterial_spot', 'Tomato___Early_blight', 'Corn_(maize)___Common_rust_', 'Tomato___Early_blight', 'Potato___healthy', 'Grape___Leaf_blight_(Isariopsis_Leaf_Spot)', 'Tomato___Early_blight', 'Tomato___Tomato_Yellow_Leaf_Curl_Virus', 'Strawberry___Leaf_scorch', 'Potato___Late_blight', 'Raspberry___healthy', 'Apple___Apple_scab', 'Tomato___healthy')

# %%
def plot_curves(results: Dict[str, List[float]]):
  """  plots training curves of a results dictionary  """
  # Get the loss values of the results dictionary (training and testing)
  loss = results["train_loss"]
  test_loss = results["test_loss"]

  # get the accuract values of the results dictionary
  accuracy = results["train_acc"]
  test_accuracy = results["test_acc"]

  # Figure out how many epochs there were
  epochs = range(len(results["train_loss"]))

  # setup a plot
  plt.figure(figsize=(15,7))

  # plot the loss
  plt.subplot(1,2,1)
  plt.plot(epochs, loss, label="Train loss")
  plt.plot(epochs, test_loss, label="Test loss")
  plt.title("Loss")
  plt.xlabel("Epochs")
  plt.legend()

  # Plot the accuracy
  plt.subplot(1,2,2)
  plt.plot(epochs, accuracy, label="Train Accuracy")
  plt.plot(epochs, test_accuracy, label="Test Accuracy")
  plt.title("Accuracy")
  plt.xlabel("Epochs")
  plt.legend()

# %%
plot_curves(model_0_results)

# %%
model_0_results
# Out:
# {'train_loss': [0.23358737859276407,
#   0.2320428566984293,
#   0.2295408531587654,
#   0.23235859721136,
#   0.23152894956815578,
#   0.23338676360849092,
#   0.22981422941099122,
#   0.23004417703942678,
#   0.22660382257153025,
#   0.22940002243438523,
#   0.23075755637412076,
#   0.2282472472174986,
#   0.22648462908860495,
#   0.23034012778443833,
#   0.22870119972833597,
#   0.23171177207931884,
#   0.22686116260543812,
#   0.22629814834915132,
#   0.2262309220953114,
#   0.22633469878226642,
#   0.2282604993336686,
#   0.22383189713773155,
#   0.22354343869334659,
#   0.22819323485151685,
#   0.2261787254124215],
#  'train_acc': [0.9334548346559538,
#   0.9335544022481249,
#   0.9337962092576835,
#   0.9338419732441472,
#   0.9330509983970237,
#   0.933924224733332,
#   0.9342798232768004,
#   0.933429478933724,
#   0.9354035146741605,
#   0.9344449446874197,
#   0.9337337476004829,
#   0.9347547792444242,
#   0.9356168738002415,
#   0.9337764194256991,
#   0.9341177940274288,
#   0.9333410431220439,
#   0.9341122281371832,
#   0.9351672735548475,
#   0.9347894114503967,
#   0.9347207654707012,
#   0.933261265361857,
#   0.9346694355939918,
#   0.9354121727256536,
#   0.9337708535354535,
#   0.9348827947200729],
#  'test_loss': [0.08607517097653312,
#   0.0845937992867601,
#   0.0845288328393045,
#   0.08475867298577214,
#   0.08366506709529362,
#   0.08425058207371462,
#   0.08412873148436616,
#   0.0838105926643766,
#   0.08437308961888035,
#   0.08312441225261533,
#   0.08321506507681492,
#   0.08318581111533356,
#   0.08215559961348348,
#   0.08170536537654698,
#   0.08220005706383911,
#   0.08232328519229089,
#   0.08066494940401753,
#   0.08094389170635788,
#   0.08050832739541709,
#   0.080807301476148,
#   0.0806964232976051,
#   0.08120345247513878,
#   0.08058021318430705,
#   0.07966949346767664,
#   0.08046970805122824],
#  'test_acc': [0.9803409090909091,
#   0.9811363636363636,
#   0.9808522727272727,
#   0.9803409090909091,
#   0.9810795454545455,
#   0.9807954545454546,
#   0.9807386363636363,
#   0.9804545454545455,
#   0.9803409090909091,
#   0.9808522727272727,
#   0.98125,
#   0.9807954545454546,
#   0.98125,
#   0.980909090909091,
#   0.9809659090909091,
#   0.9809659090909091,
#   0.981875,
#   0.9815909090909091,
#   0.9817045454545454,
#   0.98125,
#   0.9811931818181818,
#   0.9814772727272727,
#   0.9807954545454546,
#   0.981875,
#   0.9814772727272727]}

# %%
plot_curves(model_0_results)

# %%
#####################################################################
model_filename = "/kaggle/working/stv2_model_state_dict_125.pth"

torch.save(model.state_dict(), model_filename)
print("Model state dictionary exported successfully to", model_filename)
#####################################################################
# Out:
# Model state dictionary exported successfully to /kaggle/working/stv2_model_state_dict_125.pth
